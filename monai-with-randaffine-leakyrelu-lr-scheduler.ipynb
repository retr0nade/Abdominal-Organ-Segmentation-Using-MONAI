# %%
# ==============================================================================
# KAGGLE PIPELINE: RandAffine + LeakyReLU + LR Scheduler
# ==============================================================================

print("▶️ Step 1: Installing MONAI...")
# !pip install -q "monai[nibabel, tqdm]"
print("✅ Installation complete.")

print("\n▶️ Step 2: Importing libraries and setting up...")
import os
import shutil
import time
from glob import glob

import torch
import monai
import numpy as np
from monai.config import print_config
from monai.data import DataLoader, Dataset, decollate_batch
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.metrics import DiceMetric
from monai.networks.nets import UNet
from monai.transforms import (
    Activations,
    AsDiscrete,
    Compose,
    EnsureChannelFirstd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    RandRotate90d,
    RandGaussianNoised,
    ScaleIntensityRanged,
    Spacingd,
    SpatialPadD,
    EnsureTyped,
    RandAffined,
)
import matplotlib.pyplot as plt

print_config()
print("✅ Setup complete.")

# ==============================================================================
# 2. PREPARE DATASET (WITH DATA INTEGRITY CHECK)
# ==============================================================================
print("\n▶️ Step 3: Preparing Data...")
try:
    output_dir = "/kaggle/working/"
    os.makedirs(output_dir, exist_ok=True)
    print(f"Model checkpoints will be saved to: {output_dir}")

    drive_data_path = "/kaggle/input/flare22train/FLARE22Train"
    images_path = os.path.join(drive_data_path, "images")
    labels_path = os.path.join(drive_data_path, "labels")

    all_images = sorted(glob(os.path.join(images_path, "*.nii")))
    all_labels = sorted(glob(os.path.join(labels_path, "*.nii")))

    print("Verifying data integrity...")
    data_dicts = []
    for img_path, lbl_path in zip(all_images, all_labels):
        if os.path.exists(img_path) and os.path.exists(lbl_path) and os.path.getsize(img_path) > 0 and os.path.getsize(lbl_path) > 0:
            data_dicts.append({"image": img_path, "label": lbl_path})
        else:
            print(f"WARNING: Skipping corrupted or empty file pair: {os.path.basename(img_path)} and {os.path.basename(lbl_path)}")

    if len(data_dicts) == 0:
        raise FileNotFoundError(f"No valid, non-empty image/label pairs found.")

    num_total = len(data_dicts)
    num_train = int(num_total * 0.8)
    train_files, val_files = data_dicts[:num_train], data_dicts[num_train:]
    
    print(f"✅ Data prepared: Found {len(data_dicts)} valid pairs.")
    print(f"   --> {len(train_files)} training files, {len(val_files)} validation files.")
except Exception as e:
    print(f"❌ FATAL ERROR in Data Preparation: {e}")
    raise e

# ==============================================================================
# 3. DEFINE TRANSFORMS, DATASET, AND DATALOADER
# ==============================================================================
print("\n▶️ Step 4: Defining MONAI transforms and dataloaders...")
roi_size = (96, 96, 96)
train_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-175, a_max=250, b_min=0.0, b_max=1.0, clip=True),
    SpatialPadD(keys=["image", "label"], spatial_size=roi_size, method="end"),
    RandCropByPosNegLabeld(
        keys=["image", "label"], label_key="label", spatial_size=roi_size,
        pos=1, neg=1, num_samples=4, image_key="image", image_threshold=0,
    ),
    # --- TWEAK 1: RandAffine Augmentation ---
    RandAffined(
        keys=['image', 'label'],
        mode=('bilinear', 'nearest'),
        prob=0.2, 
        rotate_range=(0, 0, np.pi/15),
        scale_range=(0.1, 0.1, 0.1),
        padding_mode="border",
    ),
    RandRotate90d(keys=["image", "label"], prob=0.10, max_k=3),
    RandGaussianNoised(keys="image", prob=0.10, mean=0.0, std=0.1),
    EnsureTyped(keys=["image", "label"]),
])
val_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-175, a_max=250, b_min=0.0, b_max=1.0, clip=True),
    EnsureTyped(keys=["image", "label"]),
])

train_ds = Dataset(data=train_files, transform=train_transforms)
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=2)
val_ds = Dataset(data=val_files, transform=val_transforms)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=2)
print("✅ Dataloaders ready.")


# ==============================================================================
# 4. SET UP MODEL, LOSS, AND OPTIMIZER
# ==============================================================================
print("\n▶️ Step 5: Setting up Model, Loss, and Optimizer...")
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = UNet(
    spatial_dims=3, in_channels=1, out_channels=14,
    channels=(16, 32, 64, 128, 256), strides=(2, 2, 2, 2),
    num_res_units=2,
    # --- TWEAK 2: LeakyReLU Activation ---
    act="leakyrelu",
).to(device)

loss_function = DiceLoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4)

# --- TWEAK 3: Learning Rate Scheduler ---
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)

dice_metric = DiceMetric(include_background=False, reduction="mean_batch")
organ_names = [
    "Spleen", "Right Kidney", "Left Kidney", "Gallbladder", "Liver", "Stomach",
    "Aorta", "Inferior Vena Cava", "Pancreas", "Right Adrenal Gland",
    "Left Adrenal Gland", "Duodenum", "Bladder"
]
print("✅ Model setup complete.")


# ==============================================================================
# 5. TRAINING LOOP
# ==============================================================================
print("\n▶️ Step 6: Starting Training...")
max_epochs = 100
val_interval = 2
best_metric = -1
best_metric_epoch = -1
post_pred = Compose([Activations(softmax=True), AsDiscrete(argmax=True, to_onehot=14)])
post_label = Compose([AsDiscrete(to_onehot=14)])

for epoch in range(max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    if len(train_loader) == 0: break
    for batch_data in train_loader:
        step += 1
        inputs, labels = (batch_data["image"].to(device), batch_data["label"].to(device))
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print(f"{step*train_loader.batch_size}/{len(train_ds)}, train_loss: {loss.item():.4f}", end="\r")

    epoch_loss /= step
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0 and len(val_loader) > 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (val_data["image"].to(device), val_data["label"].to(device))
                val_outputs = sliding_window_inference(val_inputs, roi_size, 4, model)
                val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                dice_metric(y_pred=val_outputs, y=val_labels)

            metric_batch = dice_metric.aggregate()
            metric = metric_batch.mean().item()
            dice_metric.reset()

            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(output_dir, "best_metric_model.pth"))
                print("saved new best metric model")
            print(f"current epoch: {epoch + 1} current mean dice: {metric:.4f}")
            print("Per-organ Dice scores:")
            for i, name in enumerate(organ_names):
                print(f"  - {name:<22}: {metric_batch[i].item():.4f}")
            print(f"best mean dice: {best_metric:.4f} at epoch: {best_metric_epoch}")
    
    scheduler.step()

print(f"\n✅ Training complete. Best mean dice: {best_metric:.4f} at epoch {best_metric_epoch}")


# ==============================================================================
# 6. ENHANCED VISUALIZATION
# ==============================================================================
print("\n▶️ Step 7: Evaluating and Visualizing Results...")
best_model_path = os.path.join(output_dir, "best_metric_model.pth")

if os.path.exists(best_model_path):
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()

    validation_mean_scores = {}
    validation_organ_scores = {}

    with torch.no_grad():
        for i, val_data in enumerate(val_loader):
            val_inputs = val_data["image"].to(device)
            val_labels = val_data["label"].to(device)
            val_outputs = sliding_window_inference(val_inputs, roi_size, 4, model)
            val_outputs_post = [post_pred(i) for i in decollate_batch(val_outputs)]
            val_labels_post = [post_label(i) for i in decollate_batch(val_labels)]
            dice_metric(y_pred=val_outputs_post, y=val_labels_post)
            organ_scores = dice_metric.aggregate()
            mean_score = organ_scores.mean().item()
            dice_metric.reset()
            case_name = os.path.basename(val_files[i]['image'])
            validation_mean_scores[case_name] = mean_score
            validation_organ_scores[case_name] = organ_scores.cpu().numpy()

    sorted_scores = sorted(validation_mean_scores.items(), key=lambda item: item[1])
    best_case_name, best_score = sorted_scores[-1]
    worst_case_name, worst_score = sorted_scores[0]

    def plot_and_report_case(case_dict, title, mean_dice, organ_dice):
        case_name = os.path.basename(case_dict['image'])
        print("-" * 30)
        print(f"📊 {title}: {case_name}")
        print(f"Mean Dice: {mean_dice:.4f}")
        print("Per-Organ Dice Scores:")
        for i, name in enumerate(organ_names):
            print(f"  - {name:<22}: {organ_dice[i]:.4f}")

        with torch.no_grad():
            transformed_data = val_transforms(case_dict)
            val_input = transformed_data['image'].unsqueeze(0).to(device)
            val_output = sliding_window_inference(val_input, roi_size, 4, model)
            val_output_processed = torch.argmax(val_output, dim=1).detach().cpu().numpy()[0, :, :, :]
            
            ground_truth = transformed_data['label'][0, :, :, :].numpy()
            original_image = transformed_data['image'][0, :, :, :].numpy()
            slice_idx = np.argmax(np.sum(ground_truth, axis=(0, 1)))

            fig, axes = plt.subplots(1, 3, figsize=(18, 6))
            fig.suptitle(f"{title}\n{case_name}\nMean Dice: {mean_dice:.4f}", fontsize=16)
            axes[0].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[0].set_title("Original Image"); axes[0].axis('off')
            axes[1].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[1].imshow(np.rot90(ground_truth[:, :, slice_idx]), cmap="jet", alpha=0.6); axes[1].set_title("Ground Truth"); axes[1].axis('off')
            axes[2].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[2].imshow(np.rot90(val_output_processed[:, :, slice_idx]), cmap="jet", alpha=0.6); axes[2].set_title("MONAI Prediction"); axes[2].axis('off')
            plt.show()

    best_case_dict = next(item for item in val_files if best_case_name in item["image"])
    worst_case_dict = next(item for item in val_files if worst_case_name in item["image"])
    
    best_organ_scores = validation_organ_scores[best_case_name]
    worst_organ_scores = validation_organ_scores[worst_case_name]

    plot_and_report_case(best_case_dict, "Best Performing Case", best_score, best_organ_scores)
    plot_and_report_case(worst_case_dict, "Worst Performing Case", worst_score, worst_organ_scores)
else:
    print("Evaluation skipped because no model was saved.")

print("\n✅ Pipeline complete!")
# Out:
# ▶️ Step 1: Installing MONAI...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 89.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 25.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 66.2 MB/s eta 0:00:00
# ✅ Installation complete.
#
# ▶️ Step 2: Importing libraries and setting up...
# <frozen importlib._bootstrap_external>:1241: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# 2025-08-13 02:27:04.616303: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755052024.987578      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755052025.099105      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# MONAI version: 1.5.0
# Numpy version: 1.26.4
# Pytorch version: 2.6.0+cu124
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: d388d1c6fec8cb3a0eebee5b5a0b9776ca59ca83
# MONAI __file__: /usr/local/lib/python3.11/dist-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.5.2
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 5.3.2
# scikit-image version: 0.25.2
# scipy version: 1.15.3
# Pillow version: 11.2.1
# Tensorboard version: 2.18.0
# gdown version: 5.2.0
# TorchVision version: 0.21.0+cu124
# tqdm version: 4.67.1
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 7.0.0
# pandas version: 2.2.3
# einops version: 0.8.1
# transformers version: 4.52.4
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies
#
# ✅ Setup complete.
#
# ▶️ Step 3: Preparing Data...
# Model checkpoints will be saved to: /kaggle/working/
# Verifying data integrity...
# ✅ Data prepared: Found 50 valid pairs.
#    --> 40 training files, 10 validation files.
#
# ▶️ Step 4: Defining MONAI transforms and dataloaders...
# ✅ Dataloaders ready.
#
# ▶️ Step 5: Setting up Model, Loss, and Optimizer...
# ✅ Model setup complete.
#
# ▶️ Step 6: Starting Training...
# ----------
# epoch 1/100
# epoch 1 average loss: 0.9690
# ----------
# epoch 2/100
# epoch 2 average loss: 0.9534
# saved new best metric model
# current epoch: 2 current mean dice: 0.0410
# Per-organ Dice scores:
#   - Spleen                : 0.3937
#   - Right Kidney          : 0.0154
#   - Left Kidney           : 0.0418
#   - Gallbladder           : 0.0065
#   - Liver                 : 0.0034
#   - Stomach               : 0.0011
#   - Aorta                 : 0.0003
#   - Inferior Vena Cava    : 0.0002
#   - Pancreas              : 0.0016
#   - Right Adrenal Gland   : 0.0008
#   - Left Adrenal Gland    : 0.0172
#   - Duodenum              : 0.0019
#   - Bladder               : 0.0489
# best mean dice: 0.0410 at epoch: 2
# ----------
# epoch 3/100
# epoch 3 average loss: 0.9341
# ----------
# epoch 4/100
# epoch 4 average loss: 0.9208
# saved new best metric model
# current epoch: 4 current mean dice: 0.0621
# Per-organ Dice scores:
#   - Spleen                : 0.4557
#   - Right Kidney          : 0.1390
#   - Left Kidney           : 0.0676
#   - Gallbladder           : 0.0038
#   - Liver                 : 0.0040
#   - Stomach               : 0.0040
#   - Aorta                 : 0.0005
#   - Inferior Vena Cava    : 0.0003
#   - Pancreas              : 0.0004
#   - Right Adrenal Gland   : 0.0006
#   - Left Adrenal Gland    : 0.0186
#   - Duodenum              : 0.0080
#   - Bladder               : 0.1048
# best mean dice: 0.0621 at epoch: 4
# ----------
# epoch 5/100
# epoch 5 average loss: 0.9057
# ----------
# epoch 6/100
# epoch 6 average loss: 0.8916
# saved new best metric model
# current epoch: 6 current mean dice: 0.0924
# Per-organ Dice scores:
#   - Spleen                : 0.5782
#   - Right Kidney          : 0.2732
#   - Left Kidney           : 0.0852
#   - Gallbladder           : 0.0047
#   - Liver                 : 0.0242
#   - Stomach               : 0.0063
#   - Aorta                 : 0.0002
#   - Inferior Vena Cava    : 0.0008
#   - Pancreas              : 0.0002
#   - Right Adrenal Gland   : 0.0008
#   - Left Adrenal Gland    : 0.0132
#   - Duodenum              : 0.0127
#   - Bladder               : 0.2016
# best mean dice: 0.0924 at epoch: 6
# ----------
# epoch 7/100
# epoch 7 average loss: 0.8809
# ----------
# epoch 8/100
# epoch 8 average loss: 0.8735
# saved new best metric model
# current epoch: 8 current mean dice: 0.1134
# Per-organ Dice scores:
#   - Spleen                : 0.6353
#   - Right Kidney          : 0.3625
#   - Left Kidney           : 0.0846
#   - Gallbladder           : 0.0001
#   - Liver                 : 0.0344
#   - Stomach               : 0.0000
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0000
#   - Right Adrenal Gland   : 0.0008
#   - Left Adrenal Gland    : 0.0117
#   - Duodenum              : 0.0008
#   - Bladder               : 0.3439
# best mean dice: 0.1134 at epoch: 8
# ----------
# epoch 9/100
# epoch 9 average loss: 0.8660
# ----------
# epoch 10/100
# epoch 10 average loss: 0.8538
# saved new best metric model
# current epoch: 10 current mean dice: 0.1285
# Per-organ Dice scores:
#   - Spleen                : 0.7489
#   - Right Kidney          : 0.3922
#   - Left Kidney           : 0.0945
#   - Gallbladder           : 0.0000
#   - Liver                 : 0.0347
#   - Stomach               : 0.0000
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0000
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.0016
#   - Duodenum              : 0.0000
#   - Bladder               : 0.3982
# best mean dice: 0.1285 at epoch: 10
# ----------
# epoch 11/100
# epoch 11 average loss: 0.8580
# ----------
# epoch 12/100
# epoch 12 average loss: 0.8525
# saved new best metric model
# current epoch: 12 current mean dice: 0.1519
# Per-organ Dice scores:
#   - Spleen                : 0.7602
#   - Right Kidney          : 0.4047
#   - Left Kidney           : 0.3649
#   - Gallbladder           : 0.0002
#   - Liver                 : 0.0380
#   - Stomach               : 0.0000
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0000
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.0019
#   - Duodenum              : 0.0000
#   - Bladder               : 0.4052
# best mean dice: 0.1519 at epoch: 12
# ----------
# epoch 13/100
# epoch 13 average loss: 0.8463
# ----------
# epoch 14/100
# epoch 14 average loss: 0.8416
# saved new best metric model
# current epoch: 14 current mean dice: 0.1633
# Per-organ Dice scores:
#   - Spleen                : 0.8179
#   - Right Kidney          : 0.4045
#   - Left Kidney           : 0.4218
#   - Gallbladder           : 0.0129
#   - Liver                 : 0.0432
#   - Stomach               : 0.0018
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0000
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.0067
#   - Duodenum              : 0.0008
#   - Bladder               : 0.4135
# best mean dice: 0.1633 at epoch: 14
# ----------
# epoch 15/100
# epoch 15 average loss: 0.8371
# ----------
# epoch 16/100
# epoch 16 average loss: 0.8343
# saved new best metric model
# current epoch: 16 current mean dice: 0.1965
# Per-organ Dice scores:
#   - Spleen                : 0.8646
#   - Right Kidney          : 0.3931
#   - Left Kidney           : 0.5577
#   - Gallbladder           : 0.1535
#   - Liver                 : 0.0642
#   - Stomach               : 0.0451
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0002
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.0066
#   - Duodenum              : 0.0704
#   - Bladder               : 0.3997
# best mean dice: 0.1965 at epoch: 16
# ----------
# epoch 17/100
# epoch 17 average loss: 0.8217
# ----------
# epoch 18/100
# epoch 18 average loss: 0.8125
# saved new best metric model
# current epoch: 18 current mean dice: 0.2342
# Per-organ Dice scores:
#   - Spleen                : 0.8504
#   - Right Kidney          : 0.4106
#   - Left Kidney           : 0.7461
#   - Gallbladder           : 0.2393
#   - Liver                 : 0.1542
#   - Stomach               : 0.0541
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0007
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.0127
#   - Duodenum              : 0.1613
#   - Bladder               : 0.4154
# best mean dice: 0.2342 at epoch: 18
# ----------
# epoch 19/100
# epoch 19 average loss: 0.8139
# ----------
# epoch 20/100
# epoch 20 average loss: 0.7971
# saved new best metric model
# current epoch: 20 current mean dice: 0.2590
# Per-organ Dice scores:
#   - Spleen                : 0.8860
#   - Right Kidney          : 0.4061
#   - Left Kidney           : 0.7726
#   - Gallbladder           : 0.2732
#   - Liver                 : 0.2171
#   - Stomach               : 0.1464
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0050
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.0469
#   - Duodenum              : 0.1927
#   - Bladder               : 0.4210
# best mean dice: 0.2590 at epoch: 20
# ----------
# epoch 21/100
# epoch 21 average loss: 0.7961
# ----------
# epoch 22/100
# epoch 22 average loss: 0.7790
# saved new best metric model
# current epoch: 22 current mean dice: 0.3156
# Per-organ Dice scores:
#   - Spleen                : 0.9096
#   - Right Kidney          : 0.3867
#   - Left Kidney           : 0.8296
#   - Gallbladder           : 0.3768
#   - Liver                 : 0.3985
#   - Stomach               : 0.4339
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0132
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.0742
#   - Duodenum              : 0.2731
#   - Bladder               : 0.4075
# best mean dice: 0.3156 at epoch: 22
# ----------
# epoch 23/100
# epoch 23 average loss: 0.7748
# ----------
# epoch 24/100
# epoch 24 average loss: 0.7603
# saved new best metric model
# current epoch: 24 current mean dice: 0.3439
# Per-organ Dice scores:
#   - Spleen                : 0.9074
#   - Right Kidney          : 0.3820
#   - Left Kidney           : 0.8080
#   - Gallbladder           : 0.4911
#   - Liver                 : 0.4504
#   - Stomach               : 0.5211
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0090
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.2259
#   - Duodenum              : 0.2725
#   - Bladder               : 0.4028
# best mean dice: 0.3439 at epoch: 24
# ----------
# epoch 25/100
# epoch 25 average loss: 0.7553
# ----------
# epoch 26/100
# epoch 26 average loss: 0.7483
# saved new best metric model
# current epoch: 26 current mean dice: 0.3535
# Per-organ Dice scores:
#   - Spleen                : 0.8929
#   - Right Kidney          : 0.3428
#   - Left Kidney           : 0.8144
#   - Gallbladder           : 0.4838
#   - Liver                 : 0.4342
#   - Stomach               : 0.5748
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0084
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3649
#   - Duodenum              : 0.2970
#   - Bladder               : 0.3823
# best mean dice: 0.3535 at epoch: 26
# ----------
# epoch 27/100
# epoch 27 average loss: 0.7260
# ----------
# epoch 28/100
# epoch 28 average loss: 0.7363
# saved new best metric model
# current epoch: 28 current mean dice: 0.3938
# Per-organ Dice scores:
#   - Spleen                : 0.9129
#   - Right Kidney          : 0.3667
#   - Left Kidney           : 0.8145
#   - Gallbladder           : 0.5707
#   - Liver                 : 0.4895
#   - Stomach               : 0.7282
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0164
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5098
#   - Duodenum              : 0.3084
#   - Bladder               : 0.4024
# best mean dice: 0.3938 at epoch: 28
# ----------
# epoch 29/100
# epoch 29 average loss: 0.7375
# ----------
# epoch 30/100
# epoch 30 average loss: 0.7301
# saved new best metric model
# current epoch: 30 current mean dice: 0.4077
# Per-organ Dice scores:
#   - Spleen                : 0.9194
#   - Right Kidney          : 0.3807
#   - Left Kidney           : 0.8029
#   - Gallbladder           : 0.6086
#   - Liver                 : 0.5071
#   - Stomach               : 0.7393
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0607
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5297
#   - Duodenum              : 0.3491
#   - Bladder               : 0.4031
# best mean dice: 0.4077 at epoch: 30
# ----------
# epoch 31/100
# epoch 31 average loss: 0.7199
# ----------
# epoch 32/100
# epoch 32 average loss: 0.7142
# saved new best metric model
# current epoch: 32 current mean dice: 0.4171
# Per-organ Dice scores:
#   - Spleen                : 0.9291
#   - Right Kidney          : 0.3793
#   - Left Kidney           : 0.8503
#   - Gallbladder           : 0.5844
#   - Liver                 : 0.5193
#   - Stomach               : 0.7568
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0789
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5913
#   - Duodenum              : 0.3280
#   - Bladder               : 0.4047
# best mean dice: 0.4171 at epoch: 32
# ----------
# epoch 33/100
# epoch 33 average loss: 0.7132
# ----------
# epoch 34/100
# epoch 34 average loss: 0.7237
# saved new best metric model
# current epoch: 34 current mean dice: 0.4237
# Per-organ Dice scores:
#   - Spleen                : 0.9301
#   - Right Kidney          : 0.3600
#   - Left Kidney           : 0.8458
#   - Gallbladder           : 0.5863
#   - Liver                 : 0.5165
#   - Stomach               : 0.7600
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.1414
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5975
#   - Duodenum              : 0.3743
#   - Bladder               : 0.3961
# best mean dice: 0.4237 at epoch: 34
# ----------
# epoch 35/100
# epoch 35 average loss: 0.6966
# ----------
# epoch 36/100
# epoch 36 average loss: 0.6995
# saved new best metric model
# current epoch: 36 current mean dice: 0.4361
# Per-organ Dice scores:
#   - Spleen                : 0.9347
#   - Right Kidney          : 0.3773
#   - Left Kidney           : 0.8452
#   - Gallbladder           : 0.6289
#   - Liver                 : 0.5295
#   - Stomach               : 0.7736
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.2196
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6050
#   - Duodenum              : 0.3605
#   - Bladder               : 0.3949
# best mean dice: 0.4361 at epoch: 36
# ----------
# epoch 37/100
# epoch 37 average loss: 0.7124
# ----------
# epoch 38/100
# epoch 38 average loss: 0.6954
# saved new best metric model
# current epoch: 38 current mean dice: 0.4427
# Per-organ Dice scores:
#   - Spleen                : 0.9211
#   - Right Kidney          : 0.3761
#   - Left Kidney           : 0.8055
#   - Gallbladder           : 0.6367
#   - Liver                 : 0.5229
#   - Stomach               : 0.7710
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.2930
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6725
#   - Duodenum              : 0.3577
#   - Bladder               : 0.3990
# best mean dice: 0.4427 at epoch: 38
# ----------
# epoch 39/100
# epoch 39 average loss: 0.6943
# ----------
# epoch 40/100
# epoch 40 average loss: 0.6952
# saved new best metric model
# current epoch: 40 current mean dice: 0.4566
# Per-organ Dice scores:
#   - Spleen                : 0.9328
#   - Right Kidney          : 0.3777
#   - Left Kidney           : 0.8413
#   - Gallbladder           : 0.6126
#   - Liver                 : 0.5230
#   - Stomach               : 0.7833
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.4198
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6527
#   - Duodenum              : 0.3864
#   - Bladder               : 0.4057
# best mean dice: 0.4566 at epoch: 40
# ----------
# epoch 41/100
# epoch 41 average loss: 0.6996
# ----------
# epoch 42/100
# epoch 42 average loss: 0.6892
# saved new best metric model
# current epoch: 42 current mean dice: 0.4657
# Per-organ Dice scores:
#   - Spleen                : 0.9279
#   - Right Kidney          : 0.3782
#   - Left Kidney           : 0.8458
#   - Gallbladder           : 0.6254
#   - Liver                 : 0.5335
#   - Stomach               : 0.7354
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5483
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6987
#   - Duodenum              : 0.3603
#   - Bladder               : 0.4003
# best mean dice: 0.4657 at epoch: 42
# ----------
# epoch 43/100
# epoch 43 average loss: 0.6909
# ----------
# epoch 44/100
# epoch 44 average loss: 0.6745
# saved new best metric model
# current epoch: 44 current mean dice: 0.4857
# Per-organ Dice scores:
#   - Spleen                : 0.9425
#   - Right Kidney          : 0.3871
#   - Left Kidney           : 0.8889
#   - Gallbladder           : 0.6618
#   - Liver                 : 0.5382
#   - Stomach               : 0.7866
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6225
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6975
#   - Duodenum              : 0.3893
#   - Bladder               : 0.4002
# best mean dice: 0.4857 at epoch: 44
# ----------
# epoch 45/100
# epoch 45 average loss: 0.6699
# ----------
# epoch 46/100
# epoch 46 average loss: 0.6608
# current epoch: 46 current mean dice: 0.4830
# Per-organ Dice scores:
#   - Spleen                : 0.9407
#   - Right Kidney          : 0.3785
#   - Left Kidney           : 0.8877
#   - Gallbladder           : 0.6395
#   - Liver                 : 0.5458
#   - Stomach               : 0.7846
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6145
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6996
#   - Duodenum              : 0.3881
#   - Bladder               : 0.3997
# best mean dice: 0.4857 at epoch: 44
# ----------
# epoch 47/100
# epoch 47 average loss: 0.6629
# ----------
# epoch 48/100
# epoch 48 average loss: 0.6746
# current epoch: 48 current mean dice: 0.4794
# Per-organ Dice scores:
#   - Spleen                : 0.9393
#   - Right Kidney          : 0.3812
#   - Left Kidney           : 0.8354
#   - Gallbladder           : 0.6386
#   - Liver                 : 0.5423
#   - Stomach               : 0.7883
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6101
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7035
#   - Duodenum              : 0.3917
#   - Bladder               : 0.4015
# best mean dice: 0.4857 at epoch: 44
# ----------
# epoch 49/100
# epoch 49 average loss: 0.6850
# ----------
# epoch 50/100
# epoch 50 average loss: 0.6638
# saved new best metric model
# current epoch: 50 current mean dice: 0.4875
# Per-organ Dice scores:
#   - Spleen                : 0.9397
#   - Right Kidney          : 0.3722
#   - Left Kidney           : 0.8738
#   - Gallbladder           : 0.6730
#   - Liver                 : 0.5420
#   - Stomach               : 0.7982
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6157
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7409
#   - Duodenum              : 0.3867
#   - Bladder               : 0.3951
# best mean dice: 0.4875 at epoch: 50
# ----------
# epoch 51/100
# epoch 51 average loss: 0.6648
# ----------
# epoch 52/100
# epoch 52 average loss: 0.6698
# saved new best metric model
# current epoch: 52 current mean dice: 0.4926
# Per-organ Dice scores:
#   - Spleen                : 0.9400
#   - Right Kidney          : 0.3860
#   - Left Kidney           : 0.8756
#   - Gallbladder           : 0.6631
#   - Liver                 : 0.5434
#   - Stomach               : 0.8063
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6522
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7376
#   - Duodenum              : 0.3984
#   - Bladder               : 0.4009
# best mean dice: 0.4926 at epoch: 52
# ----------
# epoch 53/100
# epoch 53 average loss: 0.6697
# ----------
# epoch 54/100
# epoch 54 average loss: 0.6625
# current epoch: 54 current mean dice: 0.4874
# Per-organ Dice scores:
#   - Spleen                : 0.9271
#   - Right Kidney          : 0.3762
#   - Left Kidney           : 0.8704
#   - Gallbladder           : 0.6794
#   - Liver                 : 0.5506
#   - Stomach               : 0.7829
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6661
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7143
#   - Duodenum              : 0.3739
#   - Bladder               : 0.3954
# best mean dice: 0.4926 at epoch: 52
# ----------
# epoch 55/100
# epoch 55 average loss: 0.6639
# ----------
# epoch 56/100
# epoch 56 average loss: 0.6644
# current epoch: 56 current mean dice: 0.4886
# Per-organ Dice scores:
#   - Spleen                : 0.9408
#   - Right Kidney          : 0.3740
#   - Left Kidney           : 0.8923
#   - Gallbladder           : 0.6707
#   - Liver                 : 0.5450
#   - Stomach               : 0.7888
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6575
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7206
#   - Duodenum              : 0.3661
#   - Bladder               : 0.3959
# best mean dice: 0.4926 at epoch: 52
# ----------
# epoch 57/100
# epoch 57 average loss: 0.6578
# ----------
# epoch 58/100
# epoch 58 average loss: 0.6585
# saved new best metric model
# current epoch: 58 current mean dice: 0.4930
# Per-organ Dice scores:
#   - Spleen                : 0.9399
#   - Right Kidney          : 0.3804
#   - Left Kidney           : 0.8886
#   - Gallbladder           : 0.6523
#   - Liver                 : 0.5457
#   - Stomach               : 0.7991
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6802
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7519
#   - Duodenum              : 0.3693
#   - Bladder               : 0.4019
# best mean dice: 0.4930 at epoch: 58
# ----------
# epoch 59/100
# epoch 59 average loss: 0.6400
# ----------
# epoch 60/100
# epoch 60 average loss: 0.6699
# saved new best metric model
# current epoch: 60 current mean dice: 0.4957
# Per-organ Dice scores:
#   - Spleen                : 0.9447
#   - Right Kidney          : 0.3724
#   - Left Kidney           : 0.8905
#   - Gallbladder           : 0.6798
#   - Liver                 : 0.5479
#   - Stomach               : 0.7958
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6451
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7597
#   - Duodenum              : 0.4042
#   - Bladder               : 0.4039
# best mean dice: 0.4957 at epoch: 60
# ----------
# epoch 61/100
# epoch 61 average loss: 0.6661
# ----------
# epoch 62/100
# epoch 62 average loss: 0.6629
# current epoch: 62 current mean dice: 0.4948
# Per-organ Dice scores:
#   - Spleen                : 0.9395
#   - Right Kidney          : 0.3801
#   - Left Kidney           : 0.8652
#   - Gallbladder           : 0.6680
#   - Liver                 : 0.5558
#   - Stomach               : 0.8133
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6551
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7616
#   - Duodenum              : 0.3942
#   - Bladder               : 0.3995
# best mean dice: 0.4957 at epoch: 60
# ----------
# epoch 63/100
# epoch 63 average loss: 0.6539
# ----------
# epoch 64/100
# epoch 64 average loss: 0.6572
# current epoch: 64 current mean dice: 0.4947
# Per-organ Dice scores:
#   - Spleen                : 0.9419
#   - Right Kidney          : 0.3778
#   - Left Kidney           : 0.8848
#   - Gallbladder           : 0.6567
#   - Liver                 : 0.5574
#   - Stomach               : 0.8004
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6520
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7562
#   - Duodenum              : 0.4034
#   - Bladder               : 0.4010
# best mean dice: 0.4957 at epoch: 60
# ----------
# epoch 65/100
# epoch 65 average loss: 0.6503
# ----------
# epoch 66/100
# epoch 66 average loss: 0.6758
# saved new best metric model
# current epoch: 66 current mean dice: 0.4968
# Per-organ Dice scores:
#   - Spleen                : 0.9445
#   - Right Kidney          : 0.3821
#   - Left Kidney           : 0.8956
#   - Gallbladder           : 0.6763
#   - Liver                 : 0.5561
#   - Stomach               : 0.8068
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6243
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7725
#   - Duodenum              : 0.3984
#   - Bladder               : 0.4014
# best mean dice: 0.4968 at epoch: 66
# ----------
# epoch 67/100
# epoch 67 average loss: 0.6653
# ----------
# epoch 68/100
# epoch 68 average loss: 0.6519
# saved new best metric model
# current epoch: 68 current mean dice: 0.5000
# Per-organ Dice scores:
#   - Spleen                : 0.9444
#   - Right Kidney          : 0.3826
#   - Left Kidney           : 0.8906
#   - Gallbladder           : 0.6837
#   - Liver                 : 0.5502
#   - Stomach               : 0.8100
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6537
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7792
#   - Duodenum              : 0.4044
#   - Bladder               : 0.4007
# best mean dice: 0.5000 at epoch: 68
# ----------
# epoch 69/100
# epoch 69 average loss: 0.6532
# ----------
# epoch 70/100
# epoch 70 average loss: 0.6641
# saved new best metric model
# current epoch: 70 current mean dice: 0.5017
# Per-organ Dice scores:
#   - Spleen                : 0.9448
#   - Right Kidney          : 0.3842
#   - Left Kidney           : 0.8919
#   - Gallbladder           : 0.6782
#   - Liver                 : 0.5543
#   - Stomach               : 0.8090
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6680
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7756
#   - Duodenum              : 0.4168
#   - Bladder               : 0.3992
# best mean dice: 0.5017 at epoch: 70
# ----------
# epoch 71/100
# epoch 71 average loss: 0.6611
# ----------
# epoch 72/100
# epoch 72 average loss: 0.6570
# current epoch: 72 current mean dice: 0.4970
# Per-organ Dice scores:
#   - Spleen                : 0.9404
#   - Right Kidney          : 0.3813
#   - Left Kidney           : 0.8782
#   - Gallbladder           : 0.6892
#   - Liver                 : 0.5497
#   - Stomach               : 0.8048
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6547
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7625
#   - Duodenum              : 0.3993
#   - Bladder               : 0.4006
# best mean dice: 0.5017 at epoch: 70
# ----------
# epoch 73/100
# epoch 73 average loss: 0.6471
# ----------
# epoch 74/100
# epoch 74 average loss: 0.6425
# current epoch: 74 current mean dice: 0.5007
# Per-organ Dice scores:
#   - Spleen                : 0.9441
#   - Right Kidney          : 0.3879
#   - Left Kidney           : 0.8929
#   - Gallbladder           : 0.6804
#   - Liver                 : 0.5608
#   - Stomach               : 0.8113
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6559
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7712
#   - Duodenum              : 0.4029
#   - Bladder               : 0.4022
# best mean dice: 0.5017 at epoch: 70
# ----------
# epoch 75/100
# epoch 75 average loss: 0.6580
# ----------
# epoch 76/100
# epoch 76 average loss: 0.6582
# current epoch: 76 current mean dice: 0.5012
# Per-organ Dice scores:
#   - Spleen                : 0.9434
#   - Right Kidney          : 0.3846
#   - Left Kidney           : 0.8904
#   - Gallbladder           : 0.6804
#   - Liver                 : 0.5555
#   - Stomach               : 0.8056
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6768
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7714
#   - Duodenum              : 0.4069
#   - Bladder               : 0.4011
# best mean dice: 0.5017 at epoch: 70
# ----------
# epoch 77/100
# epoch 77 average loss: 0.6642
# ----------
# epoch 78/100
# epoch 78 average loss: 0.6448
# current epoch: 78 current mean dice: 0.4996
# Per-organ Dice scores:
#   - Spleen                : 0.9439
#   - Right Kidney          : 0.3810
#   - Left Kidney           : 0.8887
#   - Gallbladder           : 0.6667
#   - Liver                 : 0.5558
#   - Stomach               : 0.8087
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6744
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7699
#   - Duodenum              : 0.4041
#   - Bladder               : 0.4018
# best mean dice: 0.5017 at epoch: 70
# ----------
# epoch 79/100
# epoch 79 average loss: 0.6496
# ----------
# epoch 80/100
# epoch 80 average loss: 0.6502
# saved new best metric model
# current epoch: 80 current mean dice: 0.5031
# Per-organ Dice scores:
#   - Spleen                : 0.9461
#   - Right Kidney          : 0.3816
#   - Left Kidney           : 0.8966
#   - Gallbladder           : 0.6861
#   - Liver                 : 0.5549
#   - Stomach               : 0.8121
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6715
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7774
#   - Duodenum              : 0.4121
#   - Bladder               : 0.4016
# best mean dice: 0.5031 at epoch: 80
# ----------
# epoch 81/100
# epoch 81 average loss: 0.6555
# ----------
# epoch 82/100
# epoch 82 average loss: 0.6442
# current epoch: 82 current mean dice: 0.5028
# Per-organ Dice scores:
#   - Spleen                : 0.9437
#   - Right Kidney          : 0.3833
#   - Left Kidney           : 0.8834
#   - Gallbladder           : 0.6874
#   - Liver                 : 0.5576
#   - Stomach               : 0.8123
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6809
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7748
#   - Duodenum              : 0.4124
#   - Bladder               : 0.4009
# best mean dice: 0.5031 at epoch: 80
# ----------
# epoch 83/100
# epoch 83 average loss: 0.6583
# ----------
# epoch 84/100
# epoch 84 average loss: 0.6415
# current epoch: 84 current mean dice: 0.5028
# Per-organ Dice scores:
#   - Spleen                : 0.9442
#   - Right Kidney          : 0.3827
#   - Left Kidney           : 0.8860
#   - Gallbladder           : 0.6930
#   - Liver                 : 0.5557
#   - Stomach               : 0.8102
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6808
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7697
#   - Duodenum              : 0.4127
#   - Bladder               : 0.4008
# best mean dice: 0.5031 at epoch: 80
# ----------
# epoch 85/100
# epoch 85 average loss: 0.6349
# ----------
# epoch 86/100
# epoch 86 average loss: 0.6468
# saved new best metric model
# current epoch: 86 current mean dice: 0.5041
# Per-organ Dice scores:
#   - Spleen                : 0.9458
#   - Right Kidney          : 0.3833
#   - Left Kidney           : 0.8943
#   - Gallbladder           : 0.6906
#   - Liver                 : 0.5570
#   - Stomach               : 0.8132
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6838
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7764
#   - Duodenum              : 0.4090
#   - Bladder               : 0.3998
# best mean dice: 0.5041 at epoch: 86
# ----------
# epoch 87/100
# epoch 87 average loss: 0.6547
# ----------
# epoch 88/100
# epoch 88 average loss: 0.6544
# current epoch: 88 current mean dice: 0.5041
# Per-organ Dice scores:
#   - Spleen                : 0.9448
#   - Right Kidney          : 0.3837
#   - Left Kidney           : 0.8886
#   - Gallbladder           : 0.6908
#   - Liver                 : 0.5574
#   - Stomach               : 0.8135
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6849
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7785
#   - Duodenum              : 0.4115
#   - Bladder               : 0.3996
# best mean dice: 0.5041 at epoch: 86
# ----------
# epoch 89/100
# epoch 89 average loss: 0.6337
# ----------
# epoch 90/100
# epoch 90 average loss: 0.6425
# saved new best metric model
# current epoch: 90 current mean dice: 0.5048
# Per-organ Dice scores:
#   - Spleen                : 0.9450
#   - Right Kidney          : 0.3835
#   - Left Kidney           : 0.8883
#   - Gallbladder           : 0.6943
#   - Liver                 : 0.5575
#   - Stomach               : 0.8134
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6892
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7781
#   - Duodenum              : 0.4136
#   - Bladder               : 0.3997
# best mean dice: 0.5048 at epoch: 90
# ----------
# epoch 91/100
# epoch 91 average loss: 0.6354
# ----------
# epoch 92/100
# epoch 92 average loss: 0.6416
# current epoch: 92 current mean dice: 0.5043
# Per-organ Dice scores:
#   - Spleen                : 0.9449
#   - Right Kidney          : 0.3827
#   - Left Kidney           : 0.8873
#   - Gallbladder           : 0.6917
#   - Liver                 : 0.5557
#   - Stomach               : 0.8118
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6910
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7778
#   - Duodenum              : 0.4133
#   - Bladder               : 0.4002
# best mean dice: 0.5048 at epoch: 90
# ----------
# epoch 93/100
# epoch 93 average loss: 0.6528
# ----------
# epoch 94/100
# epoch 94 average loss: 0.6588
# current epoch: 94 current mean dice: 0.5043
# Per-organ Dice scores:
#   - Spleen                : 0.9454
#   - Right Kidney          : 0.3824
#   - Left Kidney           : 0.8882
#   - Gallbladder           : 0.6920
#   - Liver                 : 0.5554
#   - Stomach               : 0.8115
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6864
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7792
#   - Duodenum              : 0.4147
#   - Bladder               : 0.4004
# best mean dice: 0.5048 at epoch: 90
# ----------
# epoch 95/100
# epoch 95 average loss: 0.6332
# ----------
# epoch 96/100
# epoch 96 average loss: 0.6586
# current epoch: 96 current mean dice: 0.5041
# Per-organ Dice scores:
#   - Spleen                : 0.9454
#   - Right Kidney          : 0.3827
#   - Left Kidney           : 0.8888
#   - Gallbladder           : 0.6906
#   - Liver                 : 0.5564
#   - Stomach               : 0.8112
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6843
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7781
#   - Duodenum              : 0.4149
#   - Bladder               : 0.4005
# best mean dice: 0.5048 at epoch: 90
# ----------
# epoch 97/100
# epoch 97 average loss: 0.6472
# ----------
# epoch 98/100
# epoch 98 average loss: 0.6506
# current epoch: 98 current mean dice: 0.5041
# Per-organ Dice scores:
#   - Spleen                : 0.9454
#   - Right Kidney          : 0.3826
#   - Left Kidney           : 0.8885
#   - Gallbladder           : 0.6907
#   - Liver                 : 0.5564
#   - Stomach               : 0.8112
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6853
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7782
#   - Duodenum              : 0.4146
#   - Bladder               : 0.4004
# best mean dice: 0.5048 at epoch: 90
# ----------
# epoch 99/100
# epoch 99 average loss: 0.6687
# ----------
# epoch 100/100
# epoch 100 average loss: 0.6437
# current epoch: 100 current mean dice: 0.5041
# Per-organ Dice scores:
#   - Spleen                : 0.9454
#   - Right Kidney          : 0.3826
#   - Left Kidney           : 0.8886
#   - Gallbladder           : 0.6908
#   - Liver                 : 0.5564
#   - Stomach               : 0.8113
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6853
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7782
#   - Duodenum              : 0.4146
#   - Bladder               : 0.4004
# best mean dice: 0.5048 at epoch: 90
#
# ✅ Training complete. Best mean dice: 0.5048 at epoch 90
#
# ▶️ Step 7: Evaluating and Visualizing Results...
# ------------------------------
# 📊 Best Performing Case: FLARE22_Tr_0042_0000.nii
# Mean Dice: 0.5649
# Per-Organ Dice Scores:
#   - Spleen                : 0.9646
#   - Right Kidney          : 0.4704
#   - Left Kidney           : 0.9554
#   - Gallbladder           : 0.8389
#   - Liver                 : 0.6054
#   - Stomach               : 0.8627
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7726
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.8578
#   - Duodenum              : 0.5301
#   - Bladder               : 0.4857
# ------------------------------
# 📊 Worst Performing Case: FLARE22_Tr_0047_0000.nii
# Mean Dice: 0.4409
# Per-Organ Dice Scores:
#   - Spleen                : 0.9415
#   - Right Kidney          : 0.1004
#   - Left Kidney           : 0.9233
#   - Gallbladder           : 0.7017
#   - Liver                 : 0.4298
#   - Stomach               : 0.7375
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7015
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7081
#   - Duodenum              : 0.4250
#   - Bladder               : 0.0631
# ✅ Pipeline complete!
