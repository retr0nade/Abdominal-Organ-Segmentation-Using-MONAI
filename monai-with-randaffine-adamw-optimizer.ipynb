# %%
# ==============================================================================
# KAGGLE PIPELINE: RandAffine + AdamW Optimizer
# ==============================================================================

print("▶️ Step 1: Installing MONAI...")
# !pip install -q "monai[nibabel, tqdm]"
print("✅ Installation complete.")

print("\n▶️ Step 2: Importing libraries and setting up...")
import os
import shutil
import time
from glob import glob

import torch
import monai
import numpy as np
from monai.config import print_config
from monai.data import DataLoader, Dataset, decollate_batch
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.metrics import DiceMetric
from monai.networks.nets import UNet
from monai.transforms import (
    Activations,
    AsDiscrete,
    Compose,
    EnsureChannelFirstd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    RandRotate90d,
    RandGaussianNoised,
    ScaleIntensityRanged,
    Spacingd,
    SpatialPadD,
    EnsureTyped,
    RandAffined,
)
import matplotlib.pyplot as plt

print_config()
print("✅ Setup complete.")

# ==============================================================================
# 2. PREPARE DATASET (WITH DATA INTEGRITY CHECK)
# ==============================================================================
print("\n▶️ Step 3: Preparing Data...")
try:
    output_dir = "/kaggle/working/"
    os.makedirs(output_dir, exist_ok=True)
    print(f"Model checkpoints will be saved to: {output_dir}")

    drive_data_path = "/kaggle/input/flare22train/FLARE22Train"
    images_path = os.path.join(drive_data_path, "images")
    labels_path = os.path.join(drive_data_path, "labels")

    all_images = sorted(glob(os.path.join(images_path, "*.nii")))
    all_labels = sorted(glob(os.path.join(labels_path, "*.nii")))

    print("Verifying data integrity...")
    data_dicts = []
    for img_path, lbl_path in zip(all_images, all_labels):
        if os.path.exists(img_path) and os.path.exists(lbl_path) and os.path.getsize(img_path) > 0 and os.path.getsize(lbl_path) > 0:
            data_dicts.append({"image": img_path, "label": lbl_path})
        else:
            print(f"WARNING: Skipping corrupted or empty file pair: {os.path.basename(img_path)} and {os.path.basename(lbl_path)}")

    if len(data_dicts) == 0:
        raise FileNotFoundError(f"No valid, non-empty image/label pairs found.")

    num_total = len(data_dicts)
    num_train = int(num_total * 0.8)
    train_files, val_files = data_dicts[:num_train], data_dicts[num_train:]
    
    print(f"✅ Data prepared: Found {len(data_dicts)} valid pairs.")
    print(f"   --> {len(train_files)} training files, {len(val_files)} validation files.")
except Exception as e:
    print(f"❌ FATAL ERROR in Data Preparation: {e}")
    raise e

# ==============================================================================
# 3. DEFINE TRANSFORMS, DATASET, AND DATALOADER
# ==============================================================================
print("\n▶️ Step 4: Defining MONAI transforms and dataloaders...")
roi_size = (96, 96, 96)
train_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-175, a_max=250, b_min=0.0, b_max=1.0, clip=True),
    SpatialPadD(keys=["image", "label"], spatial_size=roi_size, method="end"),
    RandCropByPosNegLabeld(
        keys=["image", "label"], label_key="label", spatial_size=roi_size,
        pos=1, neg=1, num_samples=4, image_key="image", image_threshold=0,
    ),
    # --- TWEAK 1: RandAffine Augmentation ---
    RandAffined(
        keys=['image', 'label'],
        mode=('bilinear', 'nearest'),
        prob=0.2, 
        rotate_range=(0, 0, np.pi/15),
        scale_range=(0.1, 0.1, 0.1),
        padding_mode="border",
    ),
    RandRotate90d(keys=["image", "label"], prob=0.10, max_k=3),
    RandGaussianNoised(keys="image", prob=0.10, mean=0.0, std=0.1),
    EnsureTyped(keys=["image", "label"]),
])
val_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-175, a_max=250, b_min=0.0, b_max=1.0, clip=True),
    EnsureTyped(keys=["image", "label"]),
])

train_ds = Dataset(data=train_files, transform=train_transforms)
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=2)
val_ds = Dataset(data=val_files, transform=val_transforms)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=2)
print("✅ Dataloaders ready.")


# ==============================================================================
# 4. SET UP MODEL, LOSS, AND OPTIMIZER
# ==============================================================================
print("\n▶️ Step 5: Setting up Model, Loss, and Optimizer...")
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = UNet(
    spatial_dims=3, in_channels=1, out_channels=14,
    channels=(16, 32, 64, 128, 256), strides=(2, 2, 2, 2),
    num_res_units=2,
).to(device)

loss_function = DiceLoss(to_onehot_y=True, softmax=True)

# --- TWEAK 2: AdamW Optimizer + Weight Decay ---
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-5)

dice_metric = DiceMetric(include_background=False, reduction="mean_batch")
organ_names = [
    "Spleen", "Right Kidney", "Left Kidney", "Gallbladder", "Liver", "Stomach",
    "Aorta", "Inferior Vena Cava", "Pancreas", "Right Adrenal Gland",
    "Left Adrenal Gland", "Duodenum", "Bladder"
]
print("✅ Model setup complete.")


# ==============================================================================
# 5. TRAINING LOOP
# ==============================================================================
print("\n▶️ Step 6: Starting Training...")
max_epochs = 100
val_interval = 2
best_metric = -1
best_metric_epoch = -1
post_pred = Compose([Activations(softmax=True), AsDiscrete(argmax=True, to_onehot=14)])
post_label = Compose([AsDiscrete(to_onehot=14)])

for epoch in range(max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    if len(train_loader) == 0: break
    for batch_data in train_loader:
        step += 1
        inputs, labels = (batch_data["image"].to(device), batch_data["label"].to(device))
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print(f"{step*train_loader.batch_size}/{len(train_ds)}, train_loss: {loss.item():.4f}", end="\r")

    epoch_loss /= step
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0 and len(val_loader) > 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (val_data["image"].to(device), val_data["label"].to(device))
                val_outputs = sliding_window_inference(val_inputs, roi_size, 4, model)
                val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                dice_metric(y_pred=val_outputs, y=val_labels)

            metric_batch = dice_metric.aggregate()
            metric = metric_batch.mean().item()
            dice_metric.reset()

            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(output_dir, "best_metric_model.pth"))
                print("saved new best metric model")
            print(f"current epoch: {epoch + 1} current mean dice: {metric:.4f}")
            print("Per-organ Dice scores:")
            for i, name in enumerate(organ_names):
                print(f"  - {name:<22}: {metric_batch[i].item():.4f}")
            print(f"best mean dice: {best_metric:.4f} at epoch: {best_metric_epoch}")

print(f"\n✅ Training complete. Best mean dice: {best_metric:.4f} at epoch {best_metric_epoch}")


# ==============================================================================
# 6. ENHANCED VISUALIZATION
# ==============================================================================
print("\n▶️ Step 7: Evaluating and Visualizing Results...")
best_model_path = os.path.join(output_dir, "best_metric_model.pth")

if os.path.exists(best_model_path):
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()

    validation_mean_scores = {}
    validation_organ_scores = {}

    with torch.no_grad():
        for i, val_data in enumerate(val_loader):
            val_inputs = val_data["image"].to(device)
            val_labels = val_data["label"].to(device)
            val_outputs = sliding_window_inference(val_inputs, roi_size, 4, model)
            val_outputs_post = [post_pred(i) for i in decollate_batch(val_outputs)]
            val_labels_post = [post_label(i) for i in decollate_batch(val_labels)]
            dice_metric(y_pred=val_outputs_post, y=val_labels_post)
            organ_scores = dice_metric.aggregate()
            mean_score = organ_scores.mean().item()
            dice_metric.reset()
            case_name = os.path.basename(val_files[i]['image'])
            validation_mean_scores[case_name] = mean_score
            validation_organ_scores[case_name] = organ_scores.cpu().numpy()

    sorted_scores = sorted(validation_mean_scores.items(), key=lambda item: item[1])
    best_case_name, best_score = sorted_scores[-1]
    worst_case_name, worst_score = sorted_scores[0]

    def plot_and_report_case(case_dict, title, mean_dice, organ_dice):
        case_name = os.path.basename(case_dict['image'])
        print("-" * 30)
        print(f"📊 {title}: {case_name}")
        print(f"Mean Dice: {mean_dice:.4f}")
        print("Per-Organ Dice Scores:")
        for i, name in enumerate(organ_names):
            print(f"  - {name:<22}: {organ_dice[i]:.4f}")

        with torch.no_grad():
            transformed_data = val_transforms(case_dict)
            val_input = transformed_data['image'].unsqueeze(0).to(device)
            val_output = sliding_window_inference(val_input, roi_size, 4, model)
            val_output_processed = torch.argmax(val_output, dim=1).detach().cpu().numpy()[0, :, :, :]
            
            ground_truth = transformed_data['label'][0, :, :, :].numpy()
            original_image = transformed_data['image'][0, :, :, :].numpy()
            slice_idx = np.argmax(np.sum(ground_truth, axis=(0, 1)))

            fig, axes = plt.subplots(1, 3, figsize=(18, 6))
            fig.suptitle(f"{title}\n{case_name}\nMean Dice: {mean_dice:.4f}", fontsize=16)
            axes[0].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[0].set_title("Original Image"); axes[0].axis('off')
            axes[1].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[1].imshow(np.rot90(ground_truth[:, :, slice_idx]), cmap="jet", alpha=0.6); axes[1].set_title("Ground Truth"); axes[1].axis('off')
            axes[2].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[2].imshow(np.rot90(val_output_processed[:, :, slice_idx]), cmap="jet", alpha=0.6); axes[2].set_title("MONAI Prediction"); axes[2].axis('off')
            plt.show()

    best_case_dict = next(item for item in val_files if best_case_name in item["image"])
    worst_case_dict = next(item for item in val_files if worst_case_name in item["image"])
    
    best_organ_scores = validation_organ_scores[best_case_name]
    worst_organ_scores = validation_organ_scores[worst_case_name]

    plot_and_report_case(best_case_dict, "Best Performing Case", best_score, best_organ_scores)
    plot_and_report_case(worst_case_dict, "Worst Performing Case", worst_score, worst_organ_scores)
else:
    print("Evaluation skipped because no model was saved.")

print("\n✅ Pipeline complete!")
# Out:
# ▶️ Step 1: Installing MONAI...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 75.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 26.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 58.8 MB/s eta 0:00:00
# ✅ Installation complete.
#
# ▶️ Step 2: Importing libraries and setting up...
# <frozen importlib._bootstrap_external>:1241: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# 2025-08-13 02:41:04.741147: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755052865.092159      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755052865.193106      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# MONAI version: 1.5.0
# Numpy version: 1.26.4
# Pytorch version: 2.6.0+cu124
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: d388d1c6fec8cb3a0eebee5b5a0b9776ca59ca83
# MONAI __file__: /usr/local/lib/python3.11/dist-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.5.2
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 5.3.2
# scikit-image version: 0.25.2
# scipy version: 1.15.3
# Pillow version: 11.2.1
# Tensorboard version: 2.18.0
# gdown version: 5.2.0
# TorchVision version: 0.21.0+cu124
# tqdm version: 4.67.1
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 7.0.0
# pandas version: 2.2.3
# einops version: 0.8.1
# transformers version: 4.52.4
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies
#
# ✅ Setup complete.
#
# ▶️ Step 3: Preparing Data...
# Model checkpoints will be saved to: /kaggle/working/
# Verifying data integrity...
# ✅ Data prepared: Found 50 valid pairs.
#    --> 40 training files, 10 validation files.
#
# ▶️ Step 4: Defining MONAI transforms and dataloaders...
# ✅ Dataloaders ready.
#
# ▶️ Step 5: Setting up Model, Loss, and Optimizer...
# ✅ Model setup complete.
#
# ▶️ Step 6: Starting Training...
# ----------
# epoch 1/100
# epoch 1 average loss: 0.9707
# ----------
# epoch 2/100
# epoch 2 average loss: 0.9554
# saved new best metric model
# current epoch: 2 current mean dice: 0.0379
# Per-organ Dice scores:
#   - Spleen                : 0.3563
#   - Right Kidney          : 0.0366
#   - Left Kidney           : 0.0088
#   - Gallbladder           : 0.0096
#   - Liver                 : 0.0150
#   - Stomach               : 0.0067
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0004
#   - Pancreas              : 0.0009
#   - Right Adrenal Gland   : 0.0009
#   - Left Adrenal Gland    : 0.0114
#   - Duodenum              : 0.0061
#   - Bladder               : 0.0400
# best mean dice: 0.0379 at epoch: 2
# ----------
# epoch 3/100
# epoch 3 average loss: 0.9414
# ----------
# epoch 4/100
# epoch 4 average loss: 0.9207
# saved new best metric model
# current epoch: 4 current mean dice: 0.0530
# Per-organ Dice scores:
#   - Spleen                : 0.3769
#   - Right Kidney          : 0.0836
#   - Left Kidney           : 0.0332
#   - Gallbladder           : 0.0181
#   - Liver                 : 0.0200
#   - Stomach               : 0.0151
#   - Aorta                 : 0.0001
#   - Inferior Vena Cava    : 0.0001
#   - Pancreas              : 0.0004
#   - Right Adrenal Gland   : 0.0010
#   - Left Adrenal Gland    : 0.0350
#   - Duodenum              : 0.0045
#   - Bladder               : 0.1015
# best mean dice: 0.0530 at epoch: 4
# ----------
# epoch 5/100
# epoch 5 average loss: 0.9061
# ----------
# epoch 6/100
# epoch 6 average loss: 0.8906
# saved new best metric model
# current epoch: 6 current mean dice: 0.0779
# Per-organ Dice scores:
#   - Spleen                : 0.4324
#   - Right Kidney          : 0.1846
#   - Left Kidney           : 0.0765
#   - Gallbladder           : 0.0208
#   - Liver                 : 0.0600
#   - Stomach               : 0.0116
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0004
#   - Right Adrenal Gland   : 0.0001
#   - Left Adrenal Gland    : 0.0449
#   - Duodenum              : 0.0027
#   - Bladder               : 0.1787
# best mean dice: 0.0779 at epoch: 6
# ----------
# epoch 7/100
# epoch 7 average loss: 0.8742
# ----------
# epoch 8/100
# epoch 8 average loss: 0.8729
# saved new best metric model
# current epoch: 8 current mean dice: 0.1070
# Per-organ Dice scores:
#   - Spleen                : 0.4743
#   - Right Kidney          : 0.3586
#   - Left Kidney           : 0.0631
#   - Gallbladder           : 0.0303
#   - Liver                 : 0.0666
#   - Stomach               : 0.0086
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0002
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.0706
#   - Duodenum              : 0.0042
#   - Bladder               : 0.3146
# best mean dice: 0.1070 at epoch: 8
# ----------
# epoch 9/100
# epoch 9 average loss: 0.8619
# ----------
# epoch 10/100
# epoch 10 average loss: 0.8523
# saved new best metric model
# current epoch: 10 current mean dice: 0.1506
# Per-organ Dice scores:
#   - Spleen                : 0.5391
#   - Right Kidney          : 0.5189
#   - Left Kidney           : 0.0850
#   - Gallbladder           : 0.0419
#   - Liver                 : 0.0863
#   - Stomach               : 0.0053
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0198
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.1460
#   - Duodenum              : 0.0158
#   - Bladder               : 0.5000
# best mean dice: 0.1506 at epoch: 10
# ----------
# epoch 11/100
# epoch 11 average loss: 0.8374
# ----------
# epoch 12/100
# epoch 12 average loss: 0.8250
# saved new best metric model
# current epoch: 12 current mean dice: 0.1813
# Per-organ Dice scores:
#   - Spleen                : 0.5542
#   - Right Kidney          : 0.6285
#   - Left Kidney           : 0.0448
#   - Gallbladder           : 0.1006
#   - Liver                 : 0.1338
#   - Stomach               : 0.0131
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0382
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.2386
#   - Duodenum              : 0.0139
#   - Bladder               : 0.5908
# best mean dice: 0.1813 at epoch: 12
# ----------
# epoch 13/100
# epoch 13 average loss: 0.8209
# ----------
# epoch 14/100
# epoch 14 average loss: 0.8129
# saved new best metric model
# current epoch: 14 current mean dice: 0.2371
# Per-organ Dice scores:
#   - Spleen                : 0.6111
#   - Right Kidney          : 0.6774
#   - Left Kidney           : 0.2646
#   - Gallbladder           : 0.2256
#   - Liver                 : 0.2404
#   - Stomach               : 0.0411
#   - Aorta                 : 0.0007
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.1088
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.2692
#   - Duodenum              : 0.0240
#   - Bladder               : 0.6189
# best mean dice: 0.2371 at epoch: 14
# ----------
# epoch 15/100
# epoch 15 average loss: 0.8004
# ----------
# epoch 16/100
# epoch 16 average loss: 0.7767
# saved new best metric model
# current epoch: 16 current mean dice: 0.3007
# Per-organ Dice scores:
#   - Spleen                : 0.6138
#   - Right Kidney          : 0.7056
#   - Left Kidney           : 0.3780
#   - Gallbladder           : 0.2851
#   - Liver                 : 0.5197
#   - Stomach               : 0.0486
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.2253
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3647
#   - Duodenum              : 0.0739
#   - Bladder               : 0.6947
# best mean dice: 0.3007 at epoch: 16
# ----------
# epoch 17/100
# epoch 17 average loss: 0.7564
# ----------
# epoch 18/100
# epoch 18 average loss: 0.7749
# saved new best metric model
# current epoch: 18 current mean dice: 0.3382
# Per-organ Dice scores:
#   - Spleen                : 0.7918
#   - Right Kidney          : 0.7842
#   - Left Kidney           : 0.3982
#   - Gallbladder           : 0.2699
#   - Liver                 : 0.6310
#   - Stomach               : 0.0738
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.3178
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3193
#   - Duodenum              : 0.0681
#   - Bladder               : 0.7431
# best mean dice: 0.3382 at epoch: 18
# ----------
# epoch 19/100
# epoch 19 average loss: 0.7398
# ----------
# epoch 20/100
# epoch 20 average loss: 0.7406
# saved new best metric model
# current epoch: 20 current mean dice: 0.3683
# Per-organ Dice scores:
#   - Spleen                : 0.7517
#   - Right Kidney          : 0.8082
#   - Left Kidney           : 0.3767
#   - Gallbladder           : 0.3761
#   - Liver                 : 0.6522
#   - Stomach               : 0.1334
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.3943
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4457
#   - Duodenum              : 0.1340
#   - Bladder               : 0.7152
# best mean dice: 0.3683 at epoch: 20
# ----------
# epoch 21/100
# epoch 21 average loss: 0.7322
# ----------
# epoch 22/100
# epoch 22 average loss: 0.7290
# saved new best metric model
# current epoch: 22 current mean dice: 0.3776
# Per-organ Dice scores:
#   - Spleen                : 0.8532
#   - Right Kidney          : 0.8095
#   - Left Kidney           : 0.3948
#   - Gallbladder           : 0.4440
#   - Liver                 : 0.5373
#   - Stomach               : 0.2708
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.2427
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4049
#   - Duodenum              : 0.1703
#   - Bladder               : 0.7819
# best mean dice: 0.3776 at epoch: 22
# ----------
# epoch 23/100
# epoch 23 average loss: 0.7104
# ----------
# epoch 24/100
# epoch 24 average loss: 0.7053
# saved new best metric model
# current epoch: 24 current mean dice: 0.4237
# Per-organ Dice scores:
#   - Spleen                : 0.8366
#   - Right Kidney          : 0.7949
#   - Left Kidney           : 0.4254
#   - Gallbladder           : 0.4628
#   - Liver                 : 0.6863
#   - Stomach               : 0.3448
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.4606
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4675
#   - Duodenum              : 0.2132
#   - Bladder               : 0.8155
# best mean dice: 0.4237 at epoch: 24
# ----------
# epoch 25/100
# epoch 25 average loss: 0.6903
# ----------
# epoch 26/100
# epoch 26 average loss: 0.6911
# current epoch: 26 current mean dice: 0.4131
# Per-organ Dice scores:
#   - Spleen                : 0.8811
#   - Right Kidney          : 0.8216
#   - Left Kidney           : 0.4682
#   - Gallbladder           : 0.3478
#   - Liver                 : 0.6988
#   - Stomach               : 0.2685
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.4564
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4429
#   - Duodenum              : 0.1764
#   - Bladder               : 0.8089
# best mean dice: 0.4237 at epoch: 24
# ----------
# epoch 27/100
# epoch 27 average loss: 0.6900
# ----------
# epoch 28/100
# epoch 28 average loss: 0.7038
# saved new best metric model
# current epoch: 28 current mean dice: 0.4402
# Per-organ Dice scores:
#   - Spleen                : 0.8946
#   - Right Kidney          : 0.8315
#   - Left Kidney           : 0.4685
#   - Gallbladder           : 0.5217
#   - Liver                 : 0.7677
#   - Stomach               : 0.3495
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.3252
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5331
#   - Duodenum              : 0.2307
#   - Bladder               : 0.8006
# best mean dice: 0.4402 at epoch: 28
# ----------
# epoch 29/100
# epoch 29 average loss: 0.6933
# ----------
# epoch 30/100
# epoch 30 average loss: 0.6795
# saved new best metric model
# current epoch: 30 current mean dice: 0.4865
# Per-organ Dice scores:
#   - Spleen                : 0.8903
#   - Right Kidney          : 0.8646
#   - Left Kidney           : 0.4785
#   - Gallbladder           : 0.5497
#   - Liver                 : 0.7735
#   - Stomach               : 0.4020
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5488
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6039
#   - Duodenum              : 0.4019
#   - Bladder               : 0.8116
# best mean dice: 0.4865 at epoch: 30
# ----------
# epoch 31/100
# epoch 31 average loss: 0.6935
# ----------
# epoch 32/100
# epoch 32 average loss: 0.6696
# saved new best metric model
# current epoch: 32 current mean dice: 0.4866
# Per-organ Dice scores:
#   - Spleen                : 0.8888
#   - Right Kidney          : 0.8380
#   - Left Kidney           : 0.4779
#   - Gallbladder           : 0.5783
#   - Liver                 : 0.7877
#   - Stomach               : 0.4446
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5210
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5940
#   - Duodenum              : 0.4344
#   - Bladder               : 0.7614
# best mean dice: 0.4866 at epoch: 32
# ----------
# epoch 33/100
# epoch 33 average loss: 0.6850
# ----------
# epoch 34/100
# epoch 34 average loss: 0.6576
# saved new best metric model
# current epoch: 34 current mean dice: 0.5039
# Per-organ Dice scores:
#   - Spleen                : 0.9054
#   - Right Kidney          : 0.8242
#   - Left Kidney           : 0.5044
#   - Gallbladder           : 0.5873
#   - Liver                 : 0.8165
#   - Stomach               : 0.4226
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5943
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6049
#   - Duodenum              : 0.4767
#   - Bladder               : 0.8147
# best mean dice: 0.5039 at epoch: 34
# ----------
# epoch 35/100
# epoch 35 average loss: 0.6659
# ----------
# epoch 36/100
# epoch 36 average loss: 0.6686
# current epoch: 36 current mean dice: 0.4952
# Per-organ Dice scores:
#   - Spleen                : 0.9013
#   - Right Kidney          : 0.8039
#   - Left Kidney           : 0.4970
#   - Gallbladder           : 0.5940
#   - Liver                 : 0.7783
#   - Stomach               : 0.4849
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5137
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6068
#   - Duodenum              : 0.4534
#   - Bladder               : 0.8047
# best mean dice: 0.5039 at epoch: 34
# ----------
# epoch 37/100
# epoch 37 average loss: 0.6620
# ----------
# epoch 38/100
# epoch 38 average loss: 0.6657
# saved new best metric model
# current epoch: 38 current mean dice: 0.5298
# Per-organ Dice scores:
#   - Spleen                : 0.9156
#   - Right Kidney          : 0.8551
#   - Left Kidney           : 0.5721
#   - Gallbladder           : 0.6129
#   - Liver                 : 0.8446
#   - Stomach               : 0.4685
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6335
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6729
#   - Duodenum              : 0.4735
#   - Bladder               : 0.8387
# best mean dice: 0.5298 at epoch: 38
# ----------
# epoch 39/100
# epoch 39 average loss: 0.6606
# ----------
# epoch 40/100
# epoch 40 average loss: 0.6348
# saved new best metric model
# current epoch: 40 current mean dice: 0.5334
# Per-organ Dice scores:
#   - Spleen                : 0.9031
#   - Right Kidney          : 0.8316
#   - Left Kidney           : 0.6865
#   - Gallbladder           : 0.5760
#   - Liver                 : 0.7949
#   - Stomach               : 0.5497
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6404
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6509
#   - Duodenum              : 0.4670
#   - Bladder               : 0.8339
# best mean dice: 0.5334 at epoch: 40
# ----------
# epoch 41/100
# epoch 41 average loss: 0.6462
# ----------
# epoch 42/100
# epoch 42 average loss: 0.6557
# saved new best metric model
# current epoch: 42 current mean dice: 0.5381
# Per-organ Dice scores:
#   - Spleen                : 0.9140
#   - Right Kidney          : 0.8638
#   - Left Kidney           : 0.6988
#   - Gallbladder           : 0.5932
#   - Liver                 : 0.8096
#   - Stomach               : 0.5521
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6455
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6292
#   - Duodenum              : 0.4712
#   - Bladder               : 0.8175
# best mean dice: 0.5381 at epoch: 42
# ----------
# epoch 43/100
# epoch 43 average loss: 0.6490
# ----------
# epoch 44/100
# epoch 44 average loss: 0.6420
# saved new best metric model
# current epoch: 44 current mean dice: 0.5515
# Per-organ Dice scores:
#   - Spleen                : 0.9133
#   - Right Kidney          : 0.8590
#   - Left Kidney           : 0.6986
#   - Gallbladder           : 0.6422
#   - Liver                 : 0.7847
#   - Stomach               : 0.5659
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6649
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6976
#   - Duodenum              : 0.5094
#   - Bladder               : 0.8341
# best mean dice: 0.5515 at epoch: 44
# ----------
# epoch 45/100
# epoch 45 average loss: 0.6328
# ----------
# epoch 46/100
# epoch 46 average loss: 0.6355
# current epoch: 46 current mean dice: 0.5436
# Per-organ Dice scores:
#   - Spleen                : 0.9155
#   - Right Kidney          : 0.8349
#   - Left Kidney           : 0.6908
#   - Gallbladder           : 0.5983
#   - Liver                 : 0.8294
#   - Stomach               : 0.5494
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6775
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6617
#   - Duodenum              : 0.4921
#   - Bladder               : 0.8172
# best mean dice: 0.5515 at epoch: 44
# ----------
# epoch 47/100
# epoch 47 average loss: 0.6470
# ----------
# epoch 48/100
# epoch 48 average loss: 0.6303
# saved new best metric model
# current epoch: 48 current mean dice: 0.5785
# Per-organ Dice scores:
#   - Spleen                : 0.9172
#   - Right Kidney          : 0.8608
#   - Left Kidney           : 0.8017
#   - Gallbladder           : 0.6251
#   - Liver                 : 0.8712
#   - Stomach               : 0.7629
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6760
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6328
#   - Duodenum              : 0.5381
#   - Bladder               : 0.8351
# best mean dice: 0.5785 at epoch: 48
# ----------
# epoch 49/100
# epoch 49 average loss: 0.6347
# ----------
# epoch 50/100
# epoch 50 average loss: 0.6346
# current epoch: 50 current mean dice: 0.5728
# Per-organ Dice scores:
#   - Spleen                : 0.9196
#   - Right Kidney          : 0.8537
#   - Left Kidney           : 0.8321
#   - Gallbladder           : 0.6123
#   - Liver                 : 0.8063
#   - Stomach               : 0.6934
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6530
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7098
#   - Duodenum              : 0.5196
#   - Bladder               : 0.8461
# best mean dice: 0.5785 at epoch: 48
# ----------
# epoch 51/100
# epoch 51 average loss: 0.6230
# ----------
# epoch 52/100
# epoch 52 average loss: 0.6193
# current epoch: 52 current mean dice: 0.5706
# Per-organ Dice scores:
#   - Spleen                : 0.9196
#   - Right Kidney          : 0.8572
#   - Left Kidney           : 0.7379
#   - Gallbladder           : 0.6239
#   - Liver                 : 0.8445
#   - Stomach               : 0.6613
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6811
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7042
#   - Duodenum              : 0.5685
#   - Bladder               : 0.8193
# best mean dice: 0.5785 at epoch: 48
# ----------
# epoch 53/100
# epoch 53 average loss: 0.6458
# ----------
# epoch 54/100
# epoch 54 average loss: 0.6162
# saved new best metric model
# current epoch: 54 current mean dice: 0.5826
# Per-organ Dice scores:
#   - Spleen                : 0.9228
#   - Right Kidney          : 0.8436
#   - Left Kidney           : 0.8474
#   - Gallbladder           : 0.6236
#   - Liver                 : 0.8348
#   - Stomach               : 0.7258
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6537
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7094
#   - Duodenum              : 0.5785
#   - Bladder               : 0.8342
# best mean dice: 0.5826 at epoch: 54
# ----------
# epoch 55/100
# epoch 55 average loss: 0.6250
# ----------
# epoch 56/100
# epoch 56 average loss: 0.6585
# saved new best metric model
# current epoch: 56 current mean dice: 0.5830
# Per-organ Dice scores:
#   - Spleen                : 0.9314
#   - Right Kidney          : 0.8343
#   - Left Kidney           : 0.8673
#   - Gallbladder           : 0.6353
#   - Liver                 : 0.8326
#   - Stomach               : 0.7228
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6293
#   - Right Adrenal Gland   : 0.0013
#   - Left Adrenal Gland    : 0.7215
#   - Duodenum              : 0.5616
#   - Bladder               : 0.8415
# best mean dice: 0.5830 at epoch: 56
# ----------
# epoch 57/100
# epoch 57 average loss: 0.6233
# ----------
# epoch 58/100
# epoch 58 average loss: 0.6331
# saved new best metric model
# current epoch: 58 current mean dice: 0.5912
# Per-organ Dice scores:
#   - Spleen                : 0.9233
#   - Right Kidney          : 0.8676
#   - Left Kidney           : 0.8339
#   - Gallbladder           : 0.6459
#   - Liver                 : 0.8762
#   - Stomach               : 0.7350
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6775
#   - Right Adrenal Gland   : 0.0075
#   - Left Adrenal Gland    : 0.7343
#   - Duodenum              : 0.5630
#   - Bladder               : 0.8219
# best mean dice: 0.5912 at epoch: 58
# ----------
# epoch 59/100
# epoch 59 average loss: 0.6201
# ----------
# epoch 60/100
# epoch 60 average loss: 0.6189
# saved new best metric model
# current epoch: 60 current mean dice: 0.5945
# Per-organ Dice scores:
#   - Spleen                : 0.9259
#   - Right Kidney          : 0.8710
#   - Left Kidney           : 0.8471
#   - Gallbladder           : 0.6676
#   - Liver                 : 0.8587
#   - Stomach               : 0.7288
#   - Aorta                 : 0.0004
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6841
#   - Right Adrenal Gland   : 0.1034
#   - Left Adrenal Gland    : 0.7288
#   - Duodenum              : 0.5413
#   - Bladder               : 0.7720
# best mean dice: 0.5945 at epoch: 60
# ----------
# epoch 61/100
# epoch 61 average loss: 0.6021
# ----------
# epoch 62/100
# epoch 62 average loss: 0.6033
# saved new best metric model
# current epoch: 62 current mean dice: 0.6060
# Per-organ Dice scores:
#   - Spleen                : 0.9337
#   - Right Kidney          : 0.8585
#   - Left Kidney           : 0.8729
#   - Gallbladder           : 0.6233
#   - Liver                 : 0.8047
#   - Stomach               : 0.7026
#   - Aorta                 : 0.0037
#   - Inferior Vena Cava    : 0.0001
#   - Pancreas              : 0.6817
#   - Right Adrenal Gland   : 0.2350
#   - Left Adrenal Gland    : 0.7372
#   - Duodenum              : 0.5651
#   - Bladder               : 0.8590
# best mean dice: 0.6060 at epoch: 62
# ----------
# epoch 63/100
# epoch 63 average loss: 0.6256
# ----------
# epoch 64/100
# epoch 64 average loss: 0.6147
# saved new best metric model
# current epoch: 64 current mean dice: 0.6311
# Per-organ Dice scores:
#   - Spleen                : 0.9299
#   - Right Kidney          : 0.8604
#   - Left Kidney           : 0.8686
#   - Gallbladder           : 0.6771
#   - Liver                 : 0.8658
#   - Stomach               : 0.7645
#   - Aorta                 : 0.0271
#   - Inferior Vena Cava    : 0.0030
#   - Pancreas              : 0.6717
#   - Right Adrenal Gland   : 0.3788
#   - Left Adrenal Gland    : 0.7435
#   - Duodenum              : 0.5633
#   - Bladder               : 0.8511
# best mean dice: 0.6311 at epoch: 64
# ----------
# epoch 65/100
# epoch 65 average loss: 0.6181
# ----------
# epoch 66/100
# epoch 66 average loss: 0.6163
# saved new best metric model
# current epoch: 66 current mean dice: 0.6491
# Per-organ Dice scores:
#   - Spleen                : 0.9340
#   - Right Kidney          : 0.8505
#   - Left Kidney           : 0.8050
#   - Gallbladder           : 0.6870
#   - Liver                 : 0.8812
#   - Stomach               : 0.7740
#   - Aorta                 : 0.1129
#   - Inferior Vena Cava    : 0.0128
#   - Pancreas              : 0.7136
#   - Right Adrenal Gland   : 0.4906
#   - Left Adrenal Gland    : 0.7452
#   - Duodenum              : 0.6007
#   - Bladder               : 0.8309
# best mean dice: 0.6491 at epoch: 66
# ----------
# epoch 67/100
# epoch 67 average loss: 0.6219
# ----------
# epoch 68/100
# epoch 68 average loss: 0.5945
# saved new best metric model
# current epoch: 68 current mean dice: 0.6724
# Per-organ Dice scores:
#   - Spleen                : 0.9337
#   - Right Kidney          : 0.8669
#   - Left Kidney           : 0.8452
#   - Gallbladder           : 0.7005
#   - Liver                 : 0.8570
#   - Stomach               : 0.7451
#   - Aorta                 : 0.2778
#   - Inferior Vena Cava    : 0.0843
#   - Pancreas              : 0.7007
#   - Right Adrenal Gland   : 0.5089
#   - Left Adrenal Gland    : 0.7492
#   - Duodenum              : 0.6165
#   - Bladder               : 0.8553
# best mean dice: 0.6724 at epoch: 68
# ----------
# epoch 69/100
# epoch 69 average loss: 0.5873
# ----------
# epoch 70/100
# epoch 70 average loss: 0.5721
# saved new best metric model
# current epoch: 70 current mean dice: 0.6829
# Per-organ Dice scores:
#   - Spleen                : 0.9266
#   - Right Kidney          : 0.8729
#   - Left Kidney           : 0.8608
#   - Gallbladder           : 0.6482
#   - Liver                 : 0.8473
#   - Stomach               : 0.7260
#   - Aorta                 : 0.3875
#   - Inferior Vena Cava    : 0.2157
#   - Pancreas              : 0.7185
#   - Right Adrenal Gland   : 0.5140
#   - Left Adrenal Gland    : 0.7314
#   - Duodenum              : 0.5978
#   - Bladder               : 0.8310
# best mean dice: 0.6829 at epoch: 70
# ----------
# epoch 71/100
# epoch 71 average loss: 0.5776
# ----------
# epoch 72/100
# epoch 72 average loss: 0.5901
# saved new best metric model
# current epoch: 72 current mean dice: 0.7036
# Per-organ Dice scores:
#   - Spleen                : 0.9276
#   - Right Kidney          : 0.8442
#   - Left Kidney           : 0.8011
#   - Gallbladder           : 0.6686
#   - Liver                 : 0.8693
#   - Stomach               : 0.7469
#   - Aorta                 : 0.4325
#   - Inferior Vena Cava    : 0.4009
#   - Pancreas              : 0.7128
#   - Right Adrenal Gland   : 0.5776
#   - Left Adrenal Gland    : 0.7510
#   - Duodenum              : 0.5907
#   - Bladder               : 0.8234
# best mean dice: 0.7036 at epoch: 72
# ----------
# epoch 73/100
# epoch 73 average loss: 0.5834
# ----------
# epoch 74/100
# epoch 74 average loss: 0.6034
# saved new best metric model
# current epoch: 74 current mean dice: 0.7214
# Per-organ Dice scores:
#   - Spleen                : 0.9348
#   - Right Kidney          : 0.8640
#   - Left Kidney           : 0.8732
#   - Gallbladder           : 0.6885
#   - Liver                 : 0.8461
#   - Stomach               : 0.7908
#   - Aorta                 : 0.4681
#   - Inferior Vena Cava    : 0.4645
#   - Pancreas              : 0.7137
#   - Right Adrenal Gland   : 0.5495
#   - Left Adrenal Gland    : 0.7511
#   - Duodenum              : 0.5937
#   - Bladder               : 0.8405
# best mean dice: 0.7214 at epoch: 74
# ----------
# epoch 75/100
# epoch 75 average loss: 0.5548
# ----------
# epoch 76/100
# epoch 76 average loss: 0.5833
# current epoch: 76 current mean dice: 0.7098
# Per-organ Dice scores:
#   - Spleen                : 0.9334
#   - Right Kidney          : 0.8494
#   - Left Kidney           : 0.8438
#   - Gallbladder           : 0.6935
#   - Liver                 : 0.8316
#   - Stomach               : 0.7790
#   - Aorta                 : 0.4454
#   - Inferior Vena Cava    : 0.4089
#   - Pancreas              : 0.7132
#   - Right Adrenal Gland   : 0.5351
#   - Left Adrenal Gland    : 0.7531
#   - Duodenum              : 0.6181
#   - Bladder               : 0.8227
# best mean dice: 0.7214 at epoch: 74
# ----------
# epoch 77/100
# epoch 77 average loss: 0.5720
# ----------
# epoch 78/100
# epoch 78 average loss: 0.5503
# current epoch: 78 current mean dice: 0.7199
# Per-organ Dice scores:
#   - Spleen                : 0.9317
#   - Right Kidney          : 0.8392
#   - Left Kidney           : 0.8136
#   - Gallbladder           : 0.7049
#   - Liver                 : 0.8391
#   - Stomach               : 0.7612
#   - Aorta                 : 0.4910
#   - Inferior Vena Cava    : 0.4515
#   - Pancreas              : 0.7191
#   - Right Adrenal Gland   : 0.5980
#   - Left Adrenal Gland    : 0.7756
#   - Duodenum              : 0.5960
#   - Bladder               : 0.8373
# best mean dice: 0.7214 at epoch: 74
# ----------
# epoch 79/100
# epoch 79 average loss: 0.5575
# ----------
# epoch 80/100
# epoch 80 average loss: 0.5609
# current epoch: 80 current mean dice: 0.7195
# Per-organ Dice scores:
#   - Spleen                : 0.9266
#   - Right Kidney          : 0.8618
#   - Left Kidney           : 0.8656
#   - Gallbladder           : 0.6750
#   - Liver                 : 0.8185
#   - Stomach               : 0.7445
#   - Aorta                 : 0.5084
#   - Inferior Vena Cava    : 0.4523
#   - Pancreas              : 0.6811
#   - Right Adrenal Gland   : 0.6093
#   - Left Adrenal Gland    : 0.7656
#   - Duodenum              : 0.6049
#   - Bladder               : 0.8394
# best mean dice: 0.7214 at epoch: 74
# ----------
# epoch 81/100
# epoch 81 average loss: 0.5415
# ----------
# epoch 82/100
# epoch 82 average loss: 0.5496
# saved new best metric model
# current epoch: 82 current mean dice: 0.7394
# Per-organ Dice scores:
#   - Spleen                : 0.9408
#   - Right Kidney          : 0.8331
#   - Left Kidney           : 0.8705
#   - Gallbladder           : 0.7117
#   - Liver                 : 0.8668
#   - Stomach               : 0.7678
#   - Aorta                 : 0.5843
#   - Inferior Vena Cava    : 0.5108
#   - Pancreas              : 0.6788
#   - Right Adrenal Gland   : 0.6037
#   - Left Adrenal Gland    : 0.7987
#   - Duodenum              : 0.6134
#   - Bladder               : 0.8318
# best mean dice: 0.7394 at epoch: 82
# ----------
# epoch 83/100
# epoch 83 average loss: 0.5349
# ----------
# epoch 84/100
# epoch 84 average loss: 0.5696
# current epoch: 84 current mean dice: 0.7327
# Per-organ Dice scores:
#   - Spleen                : 0.9260
#   - Right Kidney          : 0.8604
#   - Left Kidney           : 0.8520
#   - Gallbladder           : 0.6762
#   - Liver                 : 0.8326
#   - Stomach               : 0.7666
#   - Aorta                 : 0.5650
#   - Inferior Vena Cava    : 0.5255
#   - Pancreas              : 0.7154
#   - Right Adrenal Gland   : 0.5929
#   - Left Adrenal Gland    : 0.7762
#   - Duodenum              : 0.6024
#   - Bladder               : 0.8334
# best mean dice: 0.7394 at epoch: 82
# ----------
# epoch 85/100
# epoch 85 average loss: 0.5842
# ----------
# epoch 86/100
# epoch 86 average loss: 0.5682
# current epoch: 86 current mean dice: 0.7350
# Per-organ Dice scores:
#   - Spleen                : 0.9359
#   - Right Kidney          : 0.8590
#   - Left Kidney           : 0.8317
#   - Gallbladder           : 0.6716
#   - Liver                 : 0.8509
#   - Stomach               : 0.7710
#   - Aorta                 : 0.5666
#   - Inferior Vena Cava    : 0.4522
#   - Pancreas              : 0.7378
#   - Right Adrenal Gland   : 0.6449
#   - Left Adrenal Gland    : 0.7890
#   - Duodenum              : 0.6129
#   - Bladder               : 0.8309
# best mean dice: 0.7394 at epoch: 82
# ----------
# epoch 87/100
# epoch 87 average loss: 0.5732
# ----------
# epoch 88/100
# epoch 88 average loss: 0.5947
# saved new best metric model
# current epoch: 88 current mean dice: 0.7430
# Per-organ Dice scores:
#   - Spleen                : 0.9296
#   - Right Kidney          : 0.8647
#   - Left Kidney           : 0.8414
#   - Gallbladder           : 0.6729
#   - Liver                 : 0.8863
#   - Stomach               : 0.7764
#   - Aorta                 : 0.5930
#   - Inferior Vena Cava    : 0.5244
#   - Pancreas              : 0.6892
#   - Right Adrenal Gland   : 0.6620
#   - Left Adrenal Gland    : 0.7889
#   - Duodenum              : 0.5905
#   - Bladder               : 0.8394
# best mean dice: 0.7430 at epoch: 88
# ----------
# epoch 89/100
# epoch 89 average loss: 0.5354
# ----------
# epoch 90/100
# epoch 90 average loss: 0.5357
# saved new best metric model
# current epoch: 90 current mean dice: 0.7508
# Per-organ Dice scores:
#   - Spleen                : 0.9441
#   - Right Kidney          : 0.8387
#   - Left Kidney           : 0.8668
#   - Gallbladder           : 0.6871
#   - Liver                 : 0.8795
#   - Stomach               : 0.7796
#   - Aorta                 : 0.5751
#   - Inferior Vena Cava    : 0.5228
#   - Pancreas              : 0.7079
#   - Right Adrenal Gland   : 0.6805
#   - Left Adrenal Gland    : 0.8081
#   - Duodenum              : 0.6304
#   - Bladder               : 0.8401
# best mean dice: 0.7508 at epoch: 90
# ----------
# epoch 91/100
# epoch 91 average loss: 0.5490
# ----------
# epoch 92/100
# epoch 92 average loss: 0.5248
# current epoch: 92 current mean dice: 0.7461
# Per-organ Dice scores:
#   - Spleen                : 0.9433
#   - Right Kidney          : 0.8496
#   - Left Kidney           : 0.8760
#   - Gallbladder           : 0.6992
#   - Liver                 : 0.8779
#   - Stomach               : 0.7966
#   - Aorta                 : 0.5968
#   - Inferior Vena Cava    : 0.5058
#   - Pancreas              : 0.7250
#   - Right Adrenal Gland   : 0.6438
#   - Left Adrenal Gland    : 0.7806
#   - Duodenum              : 0.5645
#   - Bladder               : 0.8403
# best mean dice: 0.7508 at epoch: 90
# ----------
# epoch 93/100
# epoch 93 average loss: 0.5416
# ----------
# epoch 94/100
# epoch 94 average loss: 0.5756
# current epoch: 94 current mean dice: 0.7455
# Per-organ Dice scores:
#   - Spleen                : 0.9341
#   - Right Kidney          : 0.8475
#   - Left Kidney           : 0.8246
#   - Gallbladder           : 0.6923
#   - Liver                 : 0.8856
#   - Stomach               : 0.7978
#   - Aorta                 : 0.6135
#   - Inferior Vena Cava    : 0.5084
#   - Pancreas              : 0.6753
#   - Right Adrenal Gland   : 0.6575
#   - Left Adrenal Gland    : 0.7953
#   - Duodenum              : 0.6238
#   - Bladder               : 0.8355
# best mean dice: 0.7508 at epoch: 90
# ----------
# epoch 95/100
# epoch 95 average loss: 0.5384
# ----------
# epoch 96/100
# epoch 96 average loss: 0.5710
# current epoch: 96 current mean dice: 0.7491
# Per-organ Dice scores:
#   - Spleen                : 0.9386
#   - Right Kidney          : 0.8343
#   - Left Kidney           : 0.8598
#   - Gallbladder           : 0.6902
#   - Liver                 : 0.8697
#   - Stomach               : 0.7858
#   - Aorta                 : 0.6115
#   - Inferior Vena Cava    : 0.5392
#   - Pancreas              : 0.7497
#   - Right Adrenal Gland   : 0.6173
#   - Left Adrenal Gland    : 0.7912
#   - Duodenum              : 0.6290
#   - Bladder               : 0.8225
# best mean dice: 0.7508 at epoch: 90
# ----------
# epoch 97/100
# epoch 97 average loss: 0.5397
# ----------
# epoch 98/100
# epoch 98 average loss: 0.5545
# current epoch: 98 current mean dice: 0.7473
# Per-organ Dice scores:
#   - Spleen                : 0.9458
#   - Right Kidney          : 0.8189
#   - Left Kidney           : 0.8721
#   - Gallbladder           : 0.6860
#   - Liver                 : 0.8712
#   - Stomach               : 0.7702
#   - Aorta                 : 0.5761
#   - Inferior Vena Cava    : 0.5285
#   - Pancreas              : 0.6971
#   - Right Adrenal Gland   : 0.6817
#   - Left Adrenal Gland    : 0.7961
#   - Duodenum              : 0.6438
#   - Bladder               : 0.8281
# best mean dice: 0.7508 at epoch: 90
# ----------
# epoch 99/100
# epoch 99 average loss: 0.5583
# ----------
# epoch 100/100
# epoch 100 average loss: 0.5391
# saved new best metric model
# current epoch: 100 current mean dice: 0.7566
# Per-organ Dice scores:
#   - Spleen                : 0.9413
#   - Right Kidney          : 0.8490
#   - Left Kidney           : 0.8582
#   - Gallbladder           : 0.7017
#   - Liver                 : 0.8854
#   - Stomach               : 0.7974
#   - Aorta                 : 0.6326
#   - Inferior Vena Cava    : 0.5289
#   - Pancreas              : 0.6970
#   - Right Adrenal Gland   : 0.6639
#   - Left Adrenal Gland    : 0.8138
#   - Duodenum              : 0.6470
#   - Bladder               : 0.8200
# best mean dice: 0.7566 at epoch: 100
#
# ✅ Training complete. Best mean dice: 0.7566 at epoch 100
#
# ▶️ Step 7: Evaluating and Visualizing Results...
# ------------------------------
# 📊 Best Performing Case: FLARE22_Tr_0042_0000.nii
# Mean Dice: 0.8540
# Per-Organ Dice Scores:
#   - Spleen                : 0.9595
#   - Right Kidney          : 0.9563
#   - Left Kidney           : 0.9326
#   - Gallbladder           : 0.8207
#   - Liver                 : 0.8951
#   - Stomach               : 0.8478
#   - Aorta                 : 0.7452
#   - Inferior Vena Cava    : 0.7491
#   - Pancreas              : 0.8366
#   - Right Adrenal Gland   : 0.7199
#   - Left Adrenal Gland    : 0.8886
#   - Duodenum              : 0.7960
#   - Bladder               : 0.9540
# ------------------------------
# 📊 Worst Performing Case: FLARE22_Tr_0045_0000.nii
# Mean Dice: 0.6208
# Per-Organ Dice Scores:
#   - Spleen                : 0.9460
#   - Right Kidney          : 0.2889
#   - Left Kidney           : 0.8824
#   - Gallbladder           : 0.6008
#   - Liver                 : 0.7920
#   - Stomach               : 0.7271
#   - Aorta                 : 0.3801
#   - Inferior Vena Cava    : 0.2933
#   - Pancreas              : 0.8185
#   - Right Adrenal Gland   : 0.7131
#   - Left Adrenal Gland    : 0.7963
#   - Duodenum              : 0.7618
#   - Bladder               : 0.0700
# ✅ Pipeline complete!
