# %%
# ==============================================================================
# KAGGLE PIPELINE: EXPERIMENT 2 - ADDING ONLY LeakyReLU
# ==============================================================================

print("▶️ Step 1: Installing MONAI...")
# !pip install -q "monai[nibabel, tqdm]"
print("✅ Installation complete.")

print("\n▶️ Step 2: Importing libraries and setting up...")
import os
import shutil
import time
from glob import glob

import torch
import monai
import numpy as np
from monai.config import print_config
from monai.data import DataLoader, Dataset, decollate_batch
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.metrics import DiceMetric
from monai.networks.nets import UNet
from monai.transforms import (
    Activations,
    AsDiscrete,
    Compose,
    EnsureChannelFirstd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    RandRotate90d,
    RandGaussianNoised,
    ScaleIntensityRanged,
    Spacingd,
    SpatialPadD,
    EnsureTyped,
)
import matplotlib.pyplot as plt

print_config()
print("✅ Setup complete.")

# ==============================================================================
# 2. PREPARE DATASET (WITH DATA INTEGRITY CHECK)
# ==============================================================================
print("\n▶️ Step 3: Preparing Data...")

try:
    output_dir = "/kaggle/working/"
    os.makedirs(output_dir, exist_ok=True)
    print(f"Model checkpoints will be saved to: {output_dir}")

    # Using the correct Kaggle path provided
    drive_data_path = "/kaggle/input/flare22train/FLARE22Train"
    images_path = os.path.join(drive_data_path, "images")
    labels_path = os.path.join(drive_data_path, "labels")

    # Looking for .nii files as specified
    all_images = sorted(glob(os.path.join(images_path, "*.nii")))
    all_labels = sorted(glob(os.path.join(labels_path, "*.nii")))

    print("Verifying data integrity...")
    data_dicts = []
    for img_path, lbl_path in zip(all_images, all_labels):
        if os.path.exists(img_path) and os.path.exists(lbl_path) and os.path.getsize(img_path) > 0 and os.path.getsize(lbl_path) > 0:
            data_dicts.append({"image": img_path, "label": lbl_path})
        else:
            print(f"WARNING: Skipping corrupted or empty file pair: {os.path.basename(img_path)} and {os.path.basename(lbl_path)}")

    if len(data_dicts) == 0:
        raise FileNotFoundError(f"No valid, non-empty image/label pairs found. Please check dataset path and file extensions.")

    num_total = len(data_dicts)
    num_train = int(num_total * 0.8)
    train_files, val_files = data_dicts[:num_train], data_dicts[num_train:]

    print(f"✅ Data prepared: Found {len(data_dicts)} valid pairs.")
    print(f"   --> {len(train_files)} training files, {len(val_files)} validation files.")

except Exception as e:
    print(f"❌ FATAL ERROR in Data Preparation: {e}")
    raise e

# ==============================================================================
# 3. DEFINE TRANSFORMS, DATASET, AND DATALOADER
# ==============================================================================
print("\n▶️ Step 4: Defining MONAI transforms and dataloaders...")
roi_size = (96, 96, 96)
train_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-175, a_max=250, b_min=0.0, b_max=1.0, clip=True),
    SpatialPadD(keys=["image", "label"], spatial_size=roi_size, method="end"),
    RandCropByPosNegLabeld(
        keys=["image", "label"], label_key="label", spatial_size=roi_size,
        pos=1, neg=1, num_samples=4, image_key="image", image_threshold=0,
    ),
    RandRotate90d(keys=["image", "label"], prob=0.10, max_k=3),
    RandGaussianNoised(keys="image", prob=0.10, mean=0.0, std=0.1),
    EnsureTyped(keys=["image", "label"]),
])
val_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-175, a_max=250, b_min=0.0, b_max=1.0, clip=True),
    EnsureTyped(keys=["image", "label"]),
])

train_ds = Dataset(data=train_files, transform=train_transforms)
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=2)
val_ds = Dataset(data=val_files, transform=val_transforms)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=2)
print("✅ Dataloaders ready.")


# ==============================================================================
# 4. SET UP MODEL, LOSS, AND OPTIMIZER
# ==============================================================================
print("\n▶️ Step 5: Setting up Model, Loss, and Optimizer...")
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = UNet(
    spatial_dims=3, in_channels=1, out_channels=14,
    channels=(16, 32, 64, 128, 256), strides=(2, 2, 2, 2),
    num_res_units=2,
    # --- THIS IS THE ONLY CHANGE FOR EXPERIMENT 2 ---
    act="leakyrelu",
).to(device)

loss_function = DiceLoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4)
# No scheduler for this experiment to isolate the effect of LeakyReLU

dice_metric = DiceMetric(include_background=False, reduction="mean_batch")
organ_names = [
    "Spleen", "Right Kidney", "Left Kidney", "Gallbladder", "Liver", "Stomach",
    "Aorta", "Inferior Vena Cava", "Pancreas", "Right Adrenal Gland",
    "Left Adrenal Gland", "Duodenum", "Bladder"
]
print("✅ Model setup complete.")


# ==============================================================================
# 5. TRAINING LOOP
# ==============================================================================
print("\n▶️ Step 6: Starting Training...")
max_epochs = 100
val_interval = 2
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []
post_pred = Compose([Activations(softmax=True), AsDiscrete(argmax=True, to_onehot=14)])
post_label = Compose([AsDiscrete(to_onehot=14)])

for epoch in range(max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    if len(train_loader) == 0:
        print("❌ Training loader is empty. Cannot train. Check your data split.")
        break
    for batch_data in train_loader:
        step += 1
        inputs, labels = (batch_data["image"].to(device), batch_data["label"].to(device))
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print(f"{step*train_loader.batch_size}/{len(train_ds)}, train_loss: {loss.item():.4f}", end="\r")

    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0 and len(val_loader) > 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (val_data["image"].to(device), val_data["label"].to(device))
                sw_batch_size = 4
                val_outputs = sliding_window_inference(val_inputs, roi_size, sw_batch_size, model)
                val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                dice_metric(y_pred=val_outputs, y=val_labels)

            metric_batch = dice_metric.aggregate()
            metric = metric_batch.mean().item()
            dice_metric.reset()
            metric_values.append(metric)

            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(output_dir, "best_metric_model.pth"))
                print("saved new best metric model")
            print(f"current epoch: {epoch + 1} current mean dice: {metric:.4f}")
            print("Per-organ Dice scores:")
            for i, name in enumerate(organ_names):
                print(f"  - {name:<22}: {metric_batch[i].item():.4f}")
            print(f"best mean dice: {best_metric:.4f} at epoch: {best_metric_epoch}")

# No scheduler.step() in this version

print(f"\n✅ Training complete. Best mean dice: {best_metric:.4f} at epoch {best_metric_epoch}")


# ==============================================================================
# 6. ENHANCED VISUALIZATION
# ==============================================================================
print("\n▶️ Step 7: Evaluating and Visualizing Results...")
best_model_path = os.path.join(output_dir, "best_metric_model.pth")

if os.path.exists(best_model_path):
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()

    validation_mean_scores = {}
    validation_organ_scores = {}

    with torch.no_grad():
        for i, val_data in enumerate(val_loader):
            val_inputs = val_data["image"].to(device)
            val_labels = val_data["label"].to(device)
            sw_batch_size = 4
            val_outputs = sliding_window_inference(val_inputs, roi_size, sw_batch_size, model)
            val_outputs_post = [post_pred(i) for i in decollate_batch(val_outputs)]
            val_labels_post = [post_label(i) for i in decollate_batch(val_labels)]
            dice_metric(y_pred=val_outputs_post, y=val_labels_post)
            organ_scores = dice_metric.aggregate()
            mean_score = organ_scores.mean().item()
            dice_metric.reset()
            case_name = os.path.basename(val_files[i]['image'])
            validation_mean_scores[case_name] = mean_score
            validation_organ_scores[case_name] = organ_scores.cpu().numpy()

    sorted_scores = sorted(validation_mean_scores.items(), key=lambda item: item[1])
    best_case_name, best_score = sorted_scores[-1]
    worst_case_name, worst_score = sorted_scores[0]

    def plot_and_report_case(case_dict, title, mean_dice, organ_dice):
        case_name = os.path.basename(case_dict['image'])
        print("-" * 30)
        print(f"📊 {title}: {case_name}")
        print(f"Mean Dice: {mean_dice:.4f}")
        print("Per-Organ Dice Scores:")
        for i, name in enumerate(organ_names):
            print(f"  - {name:<22}: {organ_dice[i]:.4f}")

        with torch.no_grad():
            transformed_data = val_transforms(case_dict)
            val_input = transformed_data['image'].unsqueeze(0).to(device)
            sw_batch_size = 4
            val_output = sliding_window_inference(val_input, roi_size, sw_batch_size, model)
            val_output_processed = torch.argmax(val_output, dim=1).detach().cpu().numpy()[0, :, :, :]
            
            ground_truth = transformed_data['label'][0, :, :, :].numpy()
            original_image = transformed_data['image'][0, :, :, :].numpy()
            slice_idx = np.argmax([ground_truth[:, :, z].sum() for z in range(ground_truth.shape[2])])

            fig, axes = plt.subplots(1, 3, figsize=(18, 6))
            fig.suptitle(f"{title}\n{case_name}\nMean Dice: {mean_dice:.4f}", fontsize=16)
            axes[0].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[0].set_title("Original Image"); axes[0].axis('off')
            axes[1].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[1].imshow(np.rot90(ground_truth[:, :, slice_idx]), cmap="jet", alpha=0.6); axes[1].set_title("Ground Truth"); axes[1].axis('off')
            axes[2].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[2].imshow(np.rot90(val_output_processed[:, :, slice_idx]), cmap="jet", alpha=0.6); axes[2].set_title("MONAI Prediction"); axes[2].axis('off')
            plt.show()

    best_case_dict = next(item for item in val_files if best_case_name in item["image"])
    worst_case_dict = next(item for item in val_files if worst_case_name in item["image"])

    best_organ_scores = validation_organ_scores[best_case_name]
    worst_organ_scores = validation_organ_scores[worst_case_name]

    plot_and_report_case(best_case_dict, "Best Performing Case", best_score, best_organ_scores)
    plot_and_report_case(worst_case_dict, "Worst Performing Case", worst_score, worst_organ_scores)
else:
    print("Evaluation skipped because no model was saved (best_metric was likely never updated).")


print("\n✅ Pipeline complete!")
# Out:
# ▶️ Step 1: Installing MONAI...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 101.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 69.7 MB/s eta 0:00:00
# ✅ Installation complete.
#
# ▶️ Step 2: Importing libraries and setting up...
# <frozen importlib._bootstrap_external>:1241: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# 2025-08-11 13:13:08.925321: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754917989.418335      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754917989.530304      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# MONAI version: 1.5.0
# Numpy version: 1.26.4
# Pytorch version: 2.6.0+cu124
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: d388d1c6fec8cb3a0eebee5b5a0b9776ca59ca83
# MONAI __file__: /usr/local/lib/python3.11/dist-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.5.2
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 5.3.2
# scikit-image version: 0.25.2
# scipy version: 1.15.3
# Pillow version: 11.2.1
# Tensorboard version: 2.18.0
# gdown version: 5.2.0
# TorchVision version: 0.21.0+cu124
# tqdm version: 4.67.1
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 7.0.0
# pandas version: 2.2.3
# einops version: 0.8.1
# transformers version: 4.52.4
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies
#
# ✅ Setup complete.
#
# ▶️ Step 3: Preparing Data...
# Model checkpoints will be saved to: /kaggle/working/
# Verifying data integrity...
# ✅ Data prepared: Found 50 valid pairs.
#    --> 40 training files, 10 validation files.
#
# ▶️ Step 4: Defining MONAI transforms and dataloaders...
# ✅ Dataloaders ready.
#
# ▶️ Step 5: Setting up Model, Loss, and Optimizer...
# ✅ Model setup complete.
#
# ▶️ Step 6: Starting Training...
# ----------
# epoch 1/100
# epoch 1 average loss: 0.9704
# ----------
# epoch 2/100
# epoch 2 average loss: 0.9543
# saved new best metric model
# current epoch: 2 current mean dice: 0.0328
# Per-organ Dice scores:
#   - Spleen                : 0.2536
#   - Right Kidney          : 0.0665
#   - Left Kidney           : 0.0028
#   - Gallbladder           : 0.0049
#   - Liver                 : 0.0137
#   - Stomach               : 0.0113
#   - Aorta                 : 0.0001
#   - Inferior Vena Cava    : 0.0004
#   - Pancreas              : 0.0005
#   - Right Adrenal Gland   : 0.0008
#   - Left Adrenal Gland    : 0.0081
#   - Duodenum              : 0.0039
#   - Bladder               : 0.0601
# best mean dice: 0.0328 at epoch: 2
# ----------
# epoch 3/100
# epoch 3 average loss: 0.9374
# ----------
# epoch 4/100
# epoch 4 average loss: 0.9175
# saved new best metric model
# current epoch: 4 current mean dice: 0.0657
# Per-organ Dice scores:
#   - Spleen                : 0.4396
#   - Right Kidney          : 0.1406
#   - Left Kidney           : 0.0008
#   - Gallbladder           : 0.0040
#   - Liver                 : 0.0042
#   - Stomach               : 0.0126
#   - Aorta                 : 0.0001
#   - Inferior Vena Cava    : 0.0005
#   - Pancreas              : 0.0006
#   - Right Adrenal Gland   : 0.0012
#   - Left Adrenal Gland    : 0.0192
#   - Duodenum              : 0.0122
#   - Bladder               : 0.2185
# best mean dice: 0.0657 at epoch: 4
# ----------
# epoch 5/100
# epoch 5 average loss: 0.9043
# ----------
# epoch 6/100
# epoch 6 average loss: 0.8901
# saved new best metric model
# current epoch: 6 current mean dice: 0.0950
# Per-organ Dice scores:
#   - Spleen                : 0.5758
#   - Right Kidney          : 0.2898
#   - Left Kidney           : 0.0023
#   - Gallbladder           : 0.0001
#   - Liver                 : 0.0041
#   - Stomach               : 0.0071
#   - Aorta                 : 0.0001
#   - Inferior Vena Cava    : 0.0001
#   - Pancreas              : 0.0006
#   - Right Adrenal Gland   : 0.0017
#   - Left Adrenal Gland    : 0.0172
#   - Duodenum              : 0.0022
#   - Bladder               : 0.3338
# best mean dice: 0.0950 at epoch: 6
# ----------
# epoch 7/100
# epoch 7 average loss: 0.8802
# ----------
# epoch 8/100
# epoch 8 average loss: 0.8718
# saved new best metric model
# current epoch: 8 current mean dice: 0.1199
# Per-organ Dice scores:
#   - Spleen                : 0.7609
#   - Right Kidney          : 0.3597
#   - Left Kidney           : 0.0074
#   - Gallbladder           : 0.0000
#   - Liver                 : 0.0001
#   - Stomach               : 0.0022
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0000
#   - Right Adrenal Gland   : 0.0001
#   - Left Adrenal Gland    : 0.0268
#   - Duodenum              : 0.0008
#   - Bladder               : 0.4007
# best mean dice: 0.1199 at epoch: 8
# ----------
# epoch 9/100
# epoch 9 average loss: 0.8621
# ----------
# epoch 10/100
# epoch 10 average loss: 0.8629
# saved new best metric model
# current epoch: 10 current mean dice: 0.1279
# Per-organ Dice scores:
#   - Spleen                : 0.8111
#   - Right Kidney          : 0.3693
#   - Left Kidney           : 0.0273
#   - Gallbladder           : 0.0000
#   - Liver                 : 0.0074
#   - Stomach               : 0.0000
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0000
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.0216
#   - Duodenum              : 0.0001
#   - Bladder               : 0.4265
# best mean dice: 0.1279 at epoch: 10
# ----------
# epoch 11/100
# epoch 11 average loss: 0.8546
# ----------
# epoch 12/100
# epoch 12 average loss: 0.8474
# saved new best metric model
# current epoch: 12 current mean dice: 0.1417
# Per-organ Dice scores:
#   - Spleen                : 0.8432
#   - Right Kidney          : 0.4649
#   - Left Kidney           : 0.0147
#   - Gallbladder           : 0.0000
#   - Liver                 : 0.0546
#   - Stomach               : 0.0018
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0000
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.0371
#   - Duodenum              : 0.0000
#   - Bladder               : 0.4255
# best mean dice: 0.1417 at epoch: 12
# ----------
# epoch 13/100
# epoch 13 average loss: 0.8497
# ----------
# epoch 14/100
# epoch 14 average loss: 0.8448
# saved new best metric model
# current epoch: 14 current mean dice: 0.1554
# Per-organ Dice scores:
#   - Spleen                : 0.8606
#   - Right Kidney          : 0.5081
#   - Left Kidney           : 0.0007
#   - Gallbladder           : 0.0000
#   - Liver                 : 0.0760
#   - Stomach               : 0.0011
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0000
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.0812
#   - Duodenum              : 0.0000
#   - Bladder               : 0.4923
# best mean dice: 0.1554 at epoch: 14
# ----------
# epoch 15/100
# epoch 15 average loss: 0.8342
# ----------
# epoch 16/100
# epoch 16 average loss: 0.8342
# saved new best metric model
# current epoch: 16 current mean dice: 0.1870
# Per-organ Dice scores:
#   - Spleen                : 0.8943
#   - Right Kidney          : 0.5306
#   - Left Kidney           : 0.0049
#   - Gallbladder           : 0.0000
#   - Liver                 : 0.1312
#   - Stomach               : 0.0061
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0000
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.2473
#   - Duodenum              : 0.0176
#   - Bladder               : 0.5993
# best mean dice: 0.1870 at epoch: 16
# ----------
# epoch 17/100
# epoch 17 average loss: 0.8237
# ----------
# epoch 18/100
# epoch 18 average loss: 0.8242
# saved new best metric model
# current epoch: 18 current mean dice: 0.2229
# Per-organ Dice scores:
#   - Spleen                : 0.8974
#   - Right Kidney          : 0.5607
#   - Left Kidney           : 0.0823
#   - Gallbladder           : 0.0000
#   - Liver                 : 0.2301
#   - Stomach               : 0.0362
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0000
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3804
#   - Duodenum              : 0.1176
#   - Bladder               : 0.5930
# best mean dice: 0.2229 at epoch: 18
# ----------
# epoch 19/100
# epoch 19 average loss: 0.8063
# ----------
# epoch 20/100
# epoch 20 average loss: 0.7968
# saved new best metric model
# current epoch: 20 current mean dice: 0.2661
# Per-organ Dice scores:
#   - Spleen                : 0.9050
#   - Right Kidney          : 0.6566
#   - Left Kidney           : 0.1458
#   - Gallbladder           : 0.0384
#   - Liver                 : 0.2995
#   - Stomach               : 0.0644
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0000
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4855
#   - Duodenum              : 0.2173
#   - Bladder               : 0.6472
# best mean dice: 0.2661 at epoch: 20
# ----------
# epoch 21/100
# epoch 21 average loss: 0.7885
# ----------
# epoch 22/100
# epoch 22 average loss: 0.7826
# saved new best metric model
# current epoch: 22 current mean dice: 0.3203
# Per-organ Dice scores:
#   - Spleen                : 0.9139
#   - Right Kidney          : 0.7138
#   - Left Kidney           : 0.2572
#   - Gallbladder           : 0.1955
#   - Liver                 : 0.4926
#   - Stomach               : 0.0646
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0000
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5553
#   - Duodenum              : 0.2723
#   - Bladder               : 0.6987
# best mean dice: 0.3203 at epoch: 22
# ----------
# epoch 23/100
# epoch 23 average loss: 0.7694
# ----------
# epoch 24/100
# epoch 24 average loss: 0.7582
# saved new best metric model
# current epoch: 24 current mean dice: 0.3560
# Per-organ Dice scores:
#   - Spleen                : 0.8786
#   - Right Kidney          : 0.7290
#   - Left Kidney           : 0.4297
#   - Gallbladder           : 0.2292
#   - Liver                 : 0.6710
#   - Stomach               : 0.1406
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0017
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5652
#   - Duodenum              : 0.2875
#   - Bladder               : 0.6960
# best mean dice: 0.3560 at epoch: 24
# ----------
# epoch 25/100
# epoch 25 average loss: 0.7594
# ----------
# epoch 26/100
# epoch 26 average loss: 0.7389
# saved new best metric model
# current epoch: 26 current mean dice: 0.4256
# Per-organ Dice scores:
#   - Spleen                : 0.9175
#   - Right Kidney          : 0.8054
#   - Left Kidney           : 0.7233
#   - Gallbladder           : 0.2609
#   - Liver                 : 0.8080
#   - Stomach               : 0.2334
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0242
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6509
#   - Duodenum              : 0.2878
#   - Bladder               : 0.8218
# best mean dice: 0.4256 at epoch: 26
# ----------
# epoch 27/100
# epoch 27 average loss: 0.7401
# ----------
# epoch 28/100
# epoch 28 average loss: 0.7156
# saved new best metric model
# current epoch: 28 current mean dice: 0.4452
# Per-organ Dice scores:
#   - Spleen                : 0.9214
#   - Right Kidney          : 0.7929
#   - Left Kidney           : 0.7122
#   - Gallbladder           : 0.3053
#   - Liver                 : 0.8199
#   - Stomach               : 0.4514
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0793
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5921
#   - Duodenum              : 0.2959
#   - Bladder               : 0.8168
# best mean dice: 0.4452 at epoch: 28
# ----------
# epoch 29/100
# epoch 29 average loss: 0.7237
# ----------
# epoch 30/100
# epoch 30 average loss: 0.7209
# saved new best metric model
# current epoch: 30 current mean dice: 0.4779
# Per-organ Dice scores:
#   - Spleen                : 0.9183
#   - Right Kidney          : 0.8274
#   - Left Kidney           : 0.7413
#   - Gallbladder           : 0.3870
#   - Liver                 : 0.8298
#   - Stomach               : 0.6066
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.1430
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6214
#   - Duodenum              : 0.3185
#   - Bladder               : 0.8187
# best mean dice: 0.4779 at epoch: 30
# ----------
# epoch 31/100
# epoch 31 average loss: 0.7062
# ----------
# epoch 32/100
# epoch 32 average loss: 0.7113
# saved new best metric model
# current epoch: 32 current mean dice: 0.4792
# Per-organ Dice scores:
#   - Spleen                : 0.9031
#   - Right Kidney          : 0.8051
#   - Left Kidney           : 0.7596
#   - Gallbladder           : 0.4828
#   - Liver                 : 0.8351
#   - Stomach               : 0.6514
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.1463
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5354
#   - Duodenum              : 0.3410
#   - Bladder               : 0.7694
# best mean dice: 0.4792 at epoch: 32
# ----------
# epoch 33/100
# epoch 33 average loss: 0.6956
# ----------
# epoch 34/100
# epoch 34 average loss: 0.6712
# saved new best metric model
# current epoch: 34 current mean dice: 0.5271
# Per-organ Dice scores:
#   - Spleen                : 0.9210
#   - Right Kidney          : 0.8349
#   - Left Kidney           : 0.8476
#   - Gallbladder           : 0.5374
#   - Liver                 : 0.8596
#   - Stomach               : 0.6894
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.3010
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6180
#   - Duodenum              : 0.4090
#   - Bladder               : 0.8343
# best mean dice: 0.5271 at epoch: 34
# ----------
# epoch 35/100
# epoch 35 average loss: 0.6796
# ----------
# epoch 36/100
# epoch 36 average loss: 0.6506
# saved new best metric model
# current epoch: 36 current mean dice: 0.5425
# Per-organ Dice scores:
#   - Spleen                : 0.9275
#   - Right Kidney          : 0.8237
#   - Left Kidney           : 0.8258
#   - Gallbladder           : 0.5616
#   - Liver                 : 0.8756
#   - Stomach               : 0.6785
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.4408
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6448
#   - Duodenum              : 0.4395
#   - Bladder               : 0.8347
# best mean dice: 0.5425 at epoch: 36
# ----------
# epoch 37/100
# epoch 37 average loss: 0.6621
# ----------
# epoch 38/100
# epoch 38 average loss: 0.6505
# saved new best metric model
# current epoch: 38 current mean dice: 0.5644
# Per-organ Dice scores:
#   - Spleen                : 0.9333
#   - Right Kidney          : 0.7937
#   - Left Kidney           : 0.8700
#   - Gallbladder           : 0.5953
#   - Liver                 : 0.8744
#   - Stomach               : 0.7167
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5610
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6754
#   - Duodenum              : 0.4913
#   - Bladder               : 0.8258
# best mean dice: 0.5644 at epoch: 38
# ----------
# epoch 39/100
# epoch 39 average loss: 0.6592
# ----------
# epoch 40/100
# epoch 40 average loss: 0.6565
# saved new best metric model
# current epoch: 40 current mean dice: 0.5731
# Per-organ Dice scores:
#   - Spleen                : 0.9241
#   - Right Kidney          : 0.8399
#   - Left Kidney           : 0.8165
#   - Gallbladder           : 0.6024
#   - Liver                 : 0.8832
#   - Stomach               : 0.7509
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5729
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6839
#   - Duodenum              : 0.5302
#   - Bladder               : 0.8464
# best mean dice: 0.5731 at epoch: 40
# ----------
# epoch 41/100
# epoch 41 average loss: 0.6404
# ----------
# epoch 42/100
# epoch 42 average loss: 0.6391
# saved new best metric model
# current epoch: 42 current mean dice: 0.5898
# Per-organ Dice scores:
#   - Spleen                : 0.9397
#   - Right Kidney          : 0.8758
#   - Left Kidney           : 0.8707
#   - Gallbladder           : 0.6130
#   - Liver                 : 0.8742
#   - Stomach               : 0.7380
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6646
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7067
#   - Duodenum              : 0.5316
#   - Bladder               : 0.8526
# best mean dice: 0.5898 at epoch: 42
# ----------
# epoch 43/100
# epoch 43 average loss: 0.6119
# ----------
# epoch 44/100
# epoch 44 average loss: 0.6118
# saved new best metric model
# current epoch: 44 current mean dice: 0.5939
# Per-organ Dice scores:
#   - Spleen                : 0.9322
#   - Right Kidney          : 0.8578
#   - Left Kidney           : 0.8656
#   - Gallbladder           : 0.6189
#   - Liver                 : 0.8849
#   - Stomach               : 0.7661
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6785
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7110
#   - Duodenum              : 0.5625
#   - Bladder               : 0.8436
# best mean dice: 0.5939 at epoch: 44
# ----------
# epoch 45/100
# epoch 45 average loss: 0.6619
# ----------
# epoch 46/100
# epoch 46 average loss: 0.6555
# saved new best metric model
# current epoch: 46 current mean dice: 0.5983
# Per-organ Dice scores:
#   - Spleen                : 0.9419
#   - Right Kidney          : 0.8846
#   - Left Kidney           : 0.8860
#   - Gallbladder           : 0.6367
#   - Liver                 : 0.8760
#   - Stomach               : 0.7546
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6464
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7292
#   - Duodenum              : 0.5760
#   - Bladder               : 0.8470
# best mean dice: 0.5983 at epoch: 46
# ----------
# epoch 47/100
# epoch 47 average loss: 0.6318
# ----------
# epoch 48/100
# epoch 48 average loss: 0.6246
# current epoch: 48 current mean dice: 0.5965
# Per-organ Dice scores:
#   - Spleen                : 0.9401
#   - Right Kidney          : 0.8679
#   - Left Kidney           : 0.8784
#   - Gallbladder           : 0.6179
#   - Liver                 : 0.8891
#   - Stomach               : 0.7621
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6581
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7144
#   - Duodenum              : 0.5780
#   - Bladder               : 0.8481
# best mean dice: 0.5983 at epoch: 46
# ----------
# epoch 49/100
# epoch 49 average loss: 0.6270
# ----------
# epoch 50/100
# epoch 50 average loss: 0.6182
# current epoch: 50 current mean dice: 0.5926
# Per-organ Dice scores:
#   - Spleen                : 0.9305
#   - Right Kidney          : 0.8437
#   - Left Kidney           : 0.8195
#   - Gallbladder           : 0.6694
#   - Liver                 : 0.8931
#   - Stomach               : 0.7772
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6319
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6852
#   - Duodenum              : 0.6071
#   - Bladder               : 0.8462
# best mean dice: 0.5983 at epoch: 46
# ----------
# epoch 51/100
# epoch 51 average loss: 0.5911
# ----------
# epoch 52/100
# epoch 52 average loss: 0.6337
# saved new best metric model
# current epoch: 52 current mean dice: 0.6083
# Per-organ Dice scores:
#   - Spleen                : 0.9454
#   - Right Kidney          : 0.8580
#   - Left Kidney           : 0.8913
#   - Gallbladder           : 0.6554
#   - Liver                 : 0.8865
#   - Stomach               : 0.7821
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7050
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7481
#   - Duodenum              : 0.5793
#   - Bladder               : 0.8563
# best mean dice: 0.6083 at epoch: 52
# ----------
# epoch 53/100
# epoch 53 average loss: 0.6279
# ----------
# epoch 54/100
# epoch 54 average loss: 0.6273
# current epoch: 54 current mean dice: 0.5985
# Per-organ Dice scores:
#   - Spleen                : 0.9403
#   - Right Kidney          : 0.8391
#   - Left Kidney           : 0.8498
#   - Gallbladder           : 0.6715
#   - Liver                 : 0.8880
#   - Stomach               : 0.7937
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7009
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7249
#   - Duodenum              : 0.5642
#   - Bladder               : 0.8082
# best mean dice: 0.6083 at epoch: 52
# ----------
# epoch 55/100
# epoch 55 average loss: 0.6124
# ----------
# epoch 56/100
# epoch 56 average loss: 0.6344
# saved new best metric model
# current epoch: 56 current mean dice: 0.6102
# Per-organ Dice scores:
#   - Spleen                : 0.9315
#   - Right Kidney          : 0.8481
#   - Left Kidney           : 0.8625
#   - Gallbladder           : 0.6855
#   - Liver                 : 0.9025
#   - Stomach               : 0.7938
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7208
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7321
#   - Duodenum              : 0.6083
#   - Bladder               : 0.8469
# best mean dice: 0.6102 at epoch: 56
# ----------
# epoch 57/100
# epoch 57 average loss: 0.6149
# ----------
# epoch 58/100
# epoch 58 average loss: 0.6228
# current epoch: 58 current mean dice: 0.6017
# Per-organ Dice scores:
#   - Spleen                : 0.9371
#   - Right Kidney          : 0.8771
#   - Left Kidney           : 0.8582
#   - Gallbladder           : 0.6430
#   - Liver                 : 0.8977
#   - Stomach               : 0.7920
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6175
#   - Right Adrenal Gland   : 0.0002
#   - Left Adrenal Gland    : 0.7432
#   - Duodenum              : 0.6002
#   - Bladder               : 0.8565
# best mean dice: 0.6102 at epoch: 56
# ----------
# epoch 59/100
# epoch 59 average loss: 0.6128
# ----------
# epoch 60/100
# epoch 60 average loss: 0.6129
# saved new best metric model
# current epoch: 60 current mean dice: 0.6149
# Per-organ Dice scores:
#   - Spleen                : 0.9358
#   - Right Kidney          : 0.8741
#   - Left Kidney           : 0.8825
#   - Gallbladder           : 0.6630
#   - Liver                 : 0.8818
#   - Stomach               : 0.7877
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7425
#   - Right Adrenal Gland   : 0.0001
#   - Left Adrenal Gland    : 0.7765
#   - Duodenum              : 0.5984
#   - Bladder               : 0.8509
# best mean dice: 0.6149 at epoch: 60
# ----------
# epoch 61/100
# epoch 61 average loss: 0.6258
# ----------
# epoch 62/100
# epoch 62 average loss: 0.6157
# current epoch: 62 current mean dice: 0.6065
# Per-organ Dice scores:
#   - Spleen                : 0.9393
#   - Right Kidney          : 0.8782
#   - Left Kidney           : 0.8267
#   - Gallbladder           : 0.6860
#   - Liver                 : 0.9005
#   - Stomach               : 0.7652
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7486
#   - Right Adrenal Gland   : 0.0021
#   - Left Adrenal Gland    : 0.7633
#   - Duodenum              : 0.5533
#   - Bladder               : 0.8215
# best mean dice: 0.6149 at epoch: 60
# ----------
# epoch 63/100
# epoch 63 average loss: 0.5803
# ----------
# epoch 64/100
# epoch 64 average loss: 0.5975
# saved new best metric model
# current epoch: 64 current mean dice: 0.6150
# Per-organ Dice scores:
#   - Spleen                : 0.9386
#   - Right Kidney          : 0.8795
#   - Left Kidney           : 0.8575
#   - Gallbladder           : 0.6857
#   - Liver                 : 0.8880
#   - Stomach               : 0.7980
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7011
#   - Right Adrenal Gland   : 0.0291
#   - Left Adrenal Gland    : 0.7744
#   - Duodenum              : 0.5933
#   - Bladder               : 0.8500
# best mean dice: 0.6150 at epoch: 64
# ----------
# epoch 65/100
# epoch 65 average loss: 0.6063
# ----------
# epoch 66/100
# epoch 66 average loss: 0.6067
# saved new best metric model
# current epoch: 66 current mean dice: 0.6335
# Per-organ Dice scores:
#   - Spleen                : 0.9472
#   - Right Kidney          : 0.8787
#   - Left Kidney           : 0.8882
#   - Gallbladder           : 0.6847
#   - Liver                 : 0.9001
#   - Stomach               : 0.8115
#   - Aorta                 : 0.0322
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7211
#   - Right Adrenal Gland   : 0.1050
#   - Left Adrenal Gland    : 0.7850
#   - Duodenum              : 0.6260
#   - Bladder               : 0.8557
# best mean dice: 0.6335 at epoch: 66
# ----------
# epoch 67/100
# epoch 67 average loss: 0.5950
# ----------
# epoch 68/100
# epoch 68 average loss: 0.5974
# saved new best metric model
# current epoch: 68 current mean dice: 0.6562
# Per-organ Dice scores:
#   - Spleen                : 0.9503
#   - Right Kidney          : 0.8962
#   - Left Kidney           : 0.8996
#   - Gallbladder           : 0.6628
#   - Liver                 : 0.8936
#   - Stomach               : 0.7981
#   - Aorta                 : 0.2019
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6945
#   - Right Adrenal Gland   : 0.2777
#   - Left Adrenal Gland    : 0.7846
#   - Duodenum              : 0.6035
#   - Bladder               : 0.8676
# best mean dice: 0.6562 at epoch: 68
# ----------
# epoch 69/100
# epoch 69 average loss: 0.5697
# ----------
# epoch 70/100
# epoch 70 average loss: 0.5820
# saved new best metric model
# current epoch: 70 current mean dice: 0.6828
# Per-organ Dice scores:
#   - Spleen                : 0.9401
#   - Right Kidney          : 0.8773
#   - Left Kidney           : 0.8645
#   - Gallbladder           : 0.6822
#   - Liver                 : 0.8920
#   - Stomach               : 0.7966
#   - Aorta                 : 0.3801
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7240
#   - Right Adrenal Gland   : 0.4854
#   - Left Adrenal Gland    : 0.7626
#   - Duodenum              : 0.6166
#   - Bladder               : 0.8551
# best mean dice: 0.6828 at epoch: 70
# ----------
# epoch 71/100
# epoch 71 average loss: 0.5695
# ----------
# epoch 72/100
# epoch 72 average loss: 0.5731
# saved new best metric model
# current epoch: 72 current mean dice: 0.6921
# Per-organ Dice scores:
#   - Spleen                : 0.9438
#   - Right Kidney          : 0.8622
#   - Left Kidney           : 0.8704
#   - Gallbladder           : 0.7061
#   - Liver                 : 0.8795
#   - Stomach               : 0.8012
#   - Aorta                 : 0.4526
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7664
#   - Right Adrenal Gland   : 0.4820
#   - Left Adrenal Gland    : 0.7651
#   - Duodenum              : 0.6356
#   - Bladder               : 0.8320
# best mean dice: 0.6921 at epoch: 72
# ----------
# epoch 73/100
# epoch 73 average loss: 0.5902
# ----------
# epoch 74/100
# epoch 74 average loss: 0.5822
# saved new best metric model
# current epoch: 74 current mean dice: 0.6998
# Per-organ Dice scores:
#   - Spleen                : 0.9364
#   - Right Kidney          : 0.8228
#   - Left Kidney           : 0.8553
#   - Gallbladder           : 0.6984
#   - Liver                 : 0.8973
#   - Stomach               : 0.8026
#   - Aorta                 : 0.5226
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7095
#   - Right Adrenal Gland   : 0.5977
#   - Left Adrenal Gland    : 0.7855
#   - Duodenum              : 0.6172
#   - Bladder               : 0.8526
# best mean dice: 0.6998 at epoch: 74
# ----------
# epoch 75/100
# epoch 75 average loss: 0.5707
# ----------
# epoch 76/100
# epoch 76 average loss: 0.5671
# saved new best metric model
# current epoch: 76 current mean dice: 0.7001
# Per-organ Dice scores:
#   - Spleen                : 0.9339
#   - Right Kidney          : 0.8860
#   - Left Kidney           : 0.8275
#   - Gallbladder           : 0.6902
#   - Liver                 : 0.8856
#   - Stomach               : 0.7927
#   - Aorta                 : 0.5114
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7775
#   - Right Adrenal Gland   : 0.5764
#   - Left Adrenal Gland    : 0.7461
#   - Duodenum              : 0.6018
#   - Bladder               : 0.8723
# best mean dice: 0.7001 at epoch: 76
# ----------
# epoch 77/100
# epoch 77 average loss: 0.5806
# ----------
# epoch 78/100
# epoch 78 average loss: 0.5684
# saved new best metric model
# current epoch: 78 current mean dice: 0.7158
# Per-organ Dice scores:
#   - Spleen                : 0.9504
#   - Right Kidney          : 0.8887
#   - Left Kidney           : 0.9065
#   - Gallbladder           : 0.6955
#   - Liver                 : 0.8915
#   - Stomach               : 0.7945
#   - Aorta                 : 0.5476
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7614
#   - Right Adrenal Gland   : 0.6217
#   - Left Adrenal Gland    : 0.7950
#   - Duodenum              : 0.5849
#   - Bladder               : 0.8684
# best mean dice: 0.7158 at epoch: 78
# ----------
# epoch 79/100
# epoch 79 average loss: 0.5615
# ----------
# epoch 80/100
# epoch 80 average loss: 0.5615
# saved new best metric model
# current epoch: 80 current mean dice: 0.7249
# Per-organ Dice scores:
#   - Spleen                : 0.9528
#   - Right Kidney          : 0.8857
#   - Left Kidney           : 0.9003
#   - Gallbladder           : 0.6964
#   - Liver                 : 0.8873
#   - Stomach               : 0.8083
#   - Aorta                 : 0.5527
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7928
#   - Right Adrenal Gland   : 0.6544
#   - Left Adrenal Gland    : 0.8077
#   - Duodenum              : 0.6071
#   - Bladder               : 0.8779
# best mean dice: 0.7249 at epoch: 80
# ----------
# epoch 81/100
# epoch 81 average loss: 0.5794
# ----------
# epoch 82/100
# epoch 82 average loss: 0.5776
# current epoch: 82 current mean dice: 0.7139
# Per-organ Dice scores:
#   - Spleen                : 0.9476
#   - Right Kidney          : 0.8552
#   - Left Kidney           : 0.8853
#   - Gallbladder           : 0.6954
#   - Liver                 : 0.9010
#   - Stomach               : 0.8092
#   - Aorta                 : 0.5595
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7666
#   - Right Adrenal Gland   : 0.6276
#   - Left Adrenal Gland    : 0.7988
#   - Duodenum              : 0.5916
#   - Bladder               : 0.8425
# best mean dice: 0.7249 at epoch: 80
# ----------
# epoch 83/100
# epoch 83 average loss: 0.5690
# ----------
# epoch 84/100
# epoch 84 average loss: 0.5644
# current epoch: 84 current mean dice: 0.7163
# Per-organ Dice scores:
#   - Spleen                : 0.9429
#   - Right Kidney          : 0.8659
#   - Left Kidney           : 0.8865
#   - Gallbladder           : 0.7012
#   - Liver                 : 0.9032
#   - Stomach               : 0.8113
#   - Aorta                 : 0.5621
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7538
#   - Right Adrenal Gland   : 0.6479
#   - Left Adrenal Gland    : 0.7960
#   - Duodenum              : 0.6095
#   - Bladder               : 0.8316
# best mean dice: 0.7249 at epoch: 80
# ----------
# epoch 85/100
# epoch 85 average loss: 0.5461
# ----------
# epoch 86/100
# epoch 86 average loss: 0.5621
# current epoch: 86 current mean dice: 0.7159
# Per-organ Dice scores:
#   - Spleen                : 0.9521
#   - Right Kidney          : 0.8334
#   - Left Kidney           : 0.8956
#   - Gallbladder           : 0.6933
#   - Liver                 : 0.8850
#   - Stomach               : 0.8001
#   - Aorta                 : 0.5841
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7653
#   - Right Adrenal Gland   : 0.6514
#   - Left Adrenal Gland    : 0.7919
#   - Duodenum              : 0.5963
#   - Bladder               : 0.8578
# best mean dice: 0.7249 at epoch: 80
# ----------
# epoch 87/100
# epoch 87 average loss: 0.5573
# ----------
# epoch 88/100
# epoch 88 average loss: 0.5575
# current epoch: 88 current mean dice: 0.7189
# Per-organ Dice scores:
#   - Spleen                : 0.9475
#   - Right Kidney          : 0.8942
#   - Left Kidney           : 0.9026
#   - Gallbladder           : 0.6990
#   - Liver                 : 0.8975
#   - Stomach               : 0.8110
#   - Aorta                 : 0.5401
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7287
#   - Right Adrenal Gland   : 0.6121
#   - Left Adrenal Gland    : 0.8126
#   - Duodenum              : 0.6204
#   - Bladder               : 0.8795
# best mean dice: 0.7249 at epoch: 80
# ----------
# epoch 89/100
# epoch 89 average loss: 0.5433
# ----------
# epoch 90/100
# epoch 90 average loss: 0.5618
# saved new best metric model
# current epoch: 90 current mean dice: 0.7275
# Per-organ Dice scores:
#   - Spleen                : 0.9502
#   - Right Kidney          : 0.9085
#   - Left Kidney           : 0.8949
#   - Gallbladder           : 0.7100
#   - Liver                 : 0.8915
#   - Stomach               : 0.7733
#   - Aorta                 : 0.5898
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7850
#   - Right Adrenal Gland   : 0.6497
#   - Left Adrenal Gland    : 0.8137
#   - Duodenum              : 0.6239
#   - Bladder               : 0.8672
# best mean dice: 0.7275 at epoch: 90
# ----------
# epoch 91/100
# epoch 91 average loss: 0.5571
# ----------
# epoch 92/100
# epoch 92 average loss: 0.5530
# saved new best metric model
# current epoch: 92 current mean dice: 0.7283
# Per-organ Dice scores:
#   - Spleen                : 0.9485
#   - Right Kidney          : 0.8821
#   - Left Kidney           : 0.8804
#   - Gallbladder           : 0.7206
#   - Liver                 : 0.8962
#   - Stomach               : 0.8046
#   - Aorta                 : 0.5600
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7867
#   - Right Adrenal Gland   : 0.6611
#   - Left Adrenal Gland    : 0.8213
#   - Duodenum              : 0.6408
#   - Bladder               : 0.8663
# best mean dice: 0.7283 at epoch: 92
# ----------
# epoch 93/100
# epoch 93 average loss: 0.5476
# ----------
# epoch 94/100
# epoch 94 average loss: 0.5376
# saved new best metric model
# current epoch: 94 current mean dice: 0.7293
# Per-organ Dice scores:
#   - Spleen                : 0.9507
#   - Right Kidney          : 0.8913
#   - Left Kidney           : 0.8914
#   - Gallbladder           : 0.7125
#   - Liver                 : 0.9041
#   - Stomach               : 0.8204
#   - Aorta                 : 0.5853
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7365
#   - Right Adrenal Gland   : 0.6708
#   - Left Adrenal Gland    : 0.8217
#   - Duodenum              : 0.6205
#   - Bladder               : 0.8757
# best mean dice: 0.7293 at epoch: 94
# ----------
# epoch 95/100
# epoch 95 average loss: 0.5578
# ----------
# epoch 96/100
# epoch 96 average loss: 0.5448
# current epoch: 96 current mean dice: 0.7158
# Per-organ Dice scores:
#   - Spleen                : 0.9398
#   - Right Kidney          : 0.8799
#   - Left Kidney           : 0.8541
#   - Gallbladder           : 0.6859
#   - Liver                 : 0.9089
#   - Stomach               : 0.8217
#   - Aorta                 : 0.5757
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7416
#   - Right Adrenal Gland   : 0.6420
#   - Left Adrenal Gland    : 0.7888
#   - Duodenum              : 0.5999
#   - Bladder               : 0.8675
# best mean dice: 0.7293 at epoch: 94
# ----------
# epoch 97/100
# epoch 97 average loss: 0.5461
# ----------
# epoch 98/100
# epoch 98 average loss: 0.5568
# saved new best metric model
# current epoch: 98 current mean dice: 0.7310
# Per-organ Dice scores:
#   - Spleen                : 0.9505
#   - Right Kidney          : 0.8968
#   - Left Kidney           : 0.8923
#   - Gallbladder           : 0.7007
#   - Liver                 : 0.8979
#   - Stomach               : 0.7910
#   - Aorta                 : 0.5920
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7809
#   - Right Adrenal Gland   : 0.6759
#   - Left Adrenal Gland    : 0.8154
#   - Duodenum              : 0.6256
#   - Bladder               : 0.8843
# best mean dice: 0.7310 at epoch: 98
# ----------
# epoch 99/100
# epoch 99 average loss: 0.5604
# ----------
# epoch 100/100
# epoch 100 average loss: 0.5346
# current epoch: 100 current mean dice: 0.7260
# Per-organ Dice scores:
#   - Spleen                : 0.9472
#   - Right Kidney          : 0.8829
#   - Left Kidney           : 0.9029
#   - Gallbladder           : 0.7112
#   - Liver                 : 0.9035
#   - Stomach               : 0.8247
#   - Aorta                 : 0.5863
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7236
#   - Right Adrenal Gland   : 0.6550
#   - Left Adrenal Gland    : 0.8209
#   - Duodenum              : 0.6119
#   - Bladder               : 0.8672
# best mean dice: 0.7310 at epoch: 98
#
# ✅ Training complete. Best mean dice: 0.7310 at epoch 98
#
# ▶️ Step 7: Evaluating and Visualizing Results...
# ------------------------------
# 📊 Best Performing Case: FLARE22_Tr_0050_0000.nii
# Mean Dice: 0.8028
# Per-Organ Dice Scores:
#   - Spleen                : 0.9651
#   - Right Kidney          : 0.9650
#   - Left Kidney           : 0.9575
#   - Gallbladder           : 0.7854
#   - Liver                 : 0.9090
#   - Stomach               : 0.8416
#   - Aorta                 : 0.7446
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.8861
#   - Right Adrenal Gland   : 0.7394
#   - Left Adrenal Gland    : 0.8413
#   - Duodenum              : 0.8361
#   - Bladder               : 0.9649
# ------------------------------
# 📊 Worst Performing Case: FLARE22_Tr_0045_0000.nii
# Mean Dice: 0.6237
# Per-Organ Dice Scores:
#   - Spleen                : 0.9473
#   - Right Kidney          : 0.6584
#   - Left Kidney           : 0.9245
#   - Gallbladder           : 0.6089
#   - Liver                 : 0.8063
#   - Stomach               : 0.6634
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.8436
#   - Right Adrenal Gland   : 0.7046
#   - Left Adrenal Gland    : 0.8278
#   - Duodenum              : 0.7432
#   - Bladder               : 0.3798
# ✅ Pipeline complete!
