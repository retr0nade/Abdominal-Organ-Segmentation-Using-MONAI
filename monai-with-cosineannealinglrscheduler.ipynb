# %%
# ==============================================================================
# KAGGLE PIPELINE: EXPERIMENT 1 - ADDING ONLY THE LR SCHEDULER
# Corrected sliding_window_inference calls for compatibility with MONAI v1.0+
# ==============================================================================

print("▶️ Step 1: Installing MONAI...")
# !pip install -q "monai[nibabel, tqdm]"
print("✅ Installation complete.")

print("\n▶️ Step 2: Importing libraries and setting up...")
import os
import shutil
import time
from glob import glob

import torch
import monai
import numpy as np
from monai.config import print_config
from monai.data import DataLoader, Dataset, decollate_batch
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.metrics import DiceMetric
from monai.networks.nets import UNet
from monai.transforms import (
    Activations,
    AsDiscrete,
    Compose,
    EnsureChannelFirstd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    RandRotate90d,
    RandGaussianNoised,
    ScaleIntensityRanged,
    Spacingd,
    SpatialPadD,
    EnsureTyped,
)
import matplotlib.pyplot as plt

print_config()
print("✅ Setup complete.")

# ==============================================================================
# 2. PREPARE DATASET (WITH DATA INTEGRITY CHECK)
# ==============================================================================
print("\n▶️ Step 3: Preparing Data...")

try:
    output_dir = "/kaggle/working/"
    os.makedirs(output_dir, exist_ok=True)
    print(f"Model checkpoints will be saved to: {output_dir}")

    drive_data_path = "/kaggle/input/flare22train/FLARE22Train"
    images_path = os.path.join(drive_data_path, "images")
    labels_path = os.path.join(drive_data_path, "labels")

    all_images = sorted(glob(os.path.join(images_path, "*.nii")))
    all_labels = sorted(glob(os.path.join(labels_path, "*.nii")))

    print("Verifying data integrity...")
    data_dicts = []
    for img_path, lbl_path in zip(all_images, all_labels):
        if os.path.exists(img_path) and os.path.exists(lbl_path) and os.path.getsize(img_path) > 0 and os.path.getsize(lbl_path) > 0:
            data_dicts.append({"image": img_path, "label": lbl_path})
        else:
            print(f"WARNING: Skipping corrupted or empty file pair: {os.path.basename(img_path)} and {os.path.basename(lbl_path)}")

    if len(data_dicts) == 0:
        raise FileNotFoundError(f"No valid, non-empty image/label pairs found. Please check dataset path and file extensions.")

    num_total = len(data_dicts)
    num_train = int(num_total * 0.8)
    train_files, val_files = data_dicts[:num_train], data_dicts[num_train:]

    print(f"✅ Data prepared: Found {len(data_dicts)} valid pairs.")
    print(f"   --> {len(train_files)} training files, {len(val_files)} validation files.")

except Exception as e:
    print(f"❌ FATAL ERROR in Data Preparation: {e}")
    raise e

# ==============================================================================
# 3. DEFINE TRANSFORMS, DATASET, AND DATALOADER
# ==============================================================================
print("\n▶️ Step 4: Defining MONAI transforms and dataloaders...")
roi_size = (96, 96, 96)
train_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-175, a_max=250, b_min=0.0, b_max=1.0, clip=True),
    SpatialPadD(keys=["image", "label"], spatial_size=roi_size, method="end"),
    RandCropByPosNegLabeld(
        keys=["image", "label"], label_key="label", spatial_size=roi_size,
        pos=1, neg=1, num_samples=4, image_key="image", image_threshold=0,
    ),
    RandRotate90d(keys=["image", "label"], prob=0.10, max_k=3),
    RandGaussianNoised(keys="image", prob=0.10, mean=0.0, std=0.1),
    EnsureTyped(keys=["image", "label"]),
])
val_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-175, a_max=250, b_min=0.0, b_max=1.0, clip=True),
    EnsureTyped(keys=["image", "label"]),
])

train_ds = Dataset(data=train_files, transform=train_transforms)
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=2)
val_ds = Dataset(data=val_files, transform=val_transforms)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=2)
print("✅ Dataloaders ready.")


# ==============================================================================
# 4. SET UP MODEL, LOSS, AND OPTIMIZER
# ==============================================================================
print("\n▶️ Step 5: Setting up Model, Loss, and Optimizer...")
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = UNet(
    spatial_dims=3, in_channels=1, out_channels=14,
    channels=(16, 32, 64, 128, 256), strides=(2, 2, 2, 2),
    num_res_units=2,
).to(device)

loss_function = DiceLoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)

dice_metric = DiceMetric(include_background=False, reduction="mean_batch")
organ_names = [
    "Spleen", "Right Kidney", "Left Kidney", "Gallbladder", "Liver", "Stomach",
    "Aorta", "Inferior Vena Cava", "Pancreas", "Right Adrenal Gland",
    "Left Adrenal Gland", "Duodenum", "Bladder"
]
print("✅ Model setup complete.")


# ==============================================================================
# 5. TRAINING LOOP
# ==============================================================================
print("\n▶️ Step 6: Starting Training...")
max_epochs = 100
val_interval = 2
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []
post_pred = Compose([Activations(softmax=True), AsDiscrete(argmax=True, to_onehot=14)])
post_label = Compose([AsDiscrete(to_onehot=14)])

for epoch in range(max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    if len(train_loader) == 0:
        print("❌ Training loader is empty. Cannot train. Check your data split.")
        break
    for batch_data in train_loader:
        step += 1
        inputs, labels = (batch_data["image"].to(device), batch_data["label"].to(device))
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print(f"{step*train_loader.batch_size}/{len(train_ds)}, train_loss: {loss.item():.4f}", end="\r")

    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0 and len(val_loader) > 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (val_data["image"].to(device), val_data["label"].to(device))
                sw_batch_size = 4
                # --- MODIFIED: Corrected function call for new MONAI versions ---
                val_outputs = sliding_window_inference(val_inputs, roi_size, sw_batch_size, model)
                val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                dice_metric(y_pred=val_outputs, y=val_labels)

            metric_batch = dice_metric.aggregate()
            metric = metric_batch.mean().item()
            dice_metric.reset()
            metric_values.append(metric)

            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(output_dir, "best_metric_model.pth"))
                print("saved new best metric model")
            print(f"current epoch: {epoch + 1} current mean dice: {metric:.4f}")
            print("Per-organ Dice scores:")
            for i, name in enumerate(organ_names):
                print(f"  - {name:<22}: {metric_batch[i].item():.4f}")
            print(f"best mean dice: {best_metric:.4f} at epoch: {best_metric_epoch}")
            
    scheduler.step()

print(f"\n✅ Training complete. Best mean dice: {best_metric:.4f} at epoch {best_metric_epoch}")


# ==============================================================================
# 6. ENHANCED VISUALIZATION
# ==============================================================================
print("\n▶️ Step 7: Evaluating and Visualizing Results...")
best_model_path = os.path.join(output_dir, "best_metric_model.pth")

if os.path.exists(best_model_path):
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()

    validation_mean_scores = {}
    validation_organ_scores = {}

    with torch.no_grad():
        for i, val_data in enumerate(val_loader):
            val_inputs = val_data["image"].to(device)
            val_labels = val_data["label"].to(device)
            sw_batch_size = 4
            # --- MODIFIED: Corrected function call for new MONAI versions ---
            val_outputs = sliding_window_inference(val_inputs, roi_size, sw_batch_size, model)
            val_outputs_post = [post_pred(i) for i in decollate_batch(val_outputs)]
            val_labels_post = [post_label(i) for i in decollate_batch(val_labels)]
            dice_metric(y_pred=val_outputs_post, y=val_labels_post)
            organ_scores = dice_metric.aggregate()
            mean_score = organ_scores.mean().item()
            dice_metric.reset()
            case_name = os.path.basename(val_files[i]['image'])
            validation_mean_scores[case_name] = mean_score
            validation_organ_scores[case_name] = organ_scores.cpu().numpy()

    sorted_scores = sorted(validation_mean_scores.items(), key=lambda item: item[1])
    best_case_name, best_score = sorted_scores[-1]
    worst_case_name, worst_score = sorted_scores[0]

    def plot_and_report_case(case_dict, title, mean_dice, organ_dice):
        case_name = os.path.basename(case_dict['image'])
        print("-" * 30)
        print(f"📊 {title}: {case_name}")
        print(f"Mean Dice: {mean_dice:.4f}")
        print("Per-Organ Dice Scores:")
        for i, name in enumerate(organ_names):
            print(f"  - {name:<22}: {organ_dice[i]:.4f}")

        with torch.no_grad():
            transformed_data = val_transforms(case_dict)
            val_input = transformed_data['image'].unsqueeze(0).to(device)
            sw_batch_size = 4
            # --- MODIFIED: Corrected function call for new MONAI versions ---
            val_output = sliding_window_inference(val_input, roi_size, sw_batch_size, model)
            val_output_processed = torch.argmax(val_output, dim=1).detach().cpu().numpy()[0, :, :, :]
            
            ground_truth = transformed_data['label'][0, :, :, :].numpy()
            original_image = transformed_data['image'][0, :, :, :].numpy()
            slice_idx = np.argmax([ground_truth[:, :, z].sum() for z in range(ground_truth.shape[2])])

            fig, axes = plt.subplots(1, 3, figsize=(18, 6))
            fig.suptitle(f"{title}\n{case_name}\nMean Dice: {mean_dice:.4f}", fontsize=16)
            axes[0].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[0].set_title("Original Image"); axes[0].axis('off')
            axes[1].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[1].imshow(np.rot90(ground_truth[:, :, slice_idx]), cmap="jet", alpha=0.6); axes[1].set_title("Ground Truth"); axes[1].axis('off')
            axes[2].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[2].imshow(np.rot90(val_output_processed[:, :, slice_idx]), cmap="jet", alpha=0.6); axes[2].set_title("MONAI Prediction"); axes[2].axis('off')
            plt.show()

    best_case_dict = next(item for item in val_files if best_case_name in item["image"])
    worst_case_dict = next(item for item in val_files if worst_case_name in item["image"])

    best_organ_scores = validation_organ_scores[best_case_name]
    worst_organ_scores = validation_organ_scores[worst_case_name]

    plot_and_report_case(best_case_dict, "Best Performing Case", best_score, best_organ_scores)
    plot_and_report_case(worst_case_dict, "Worst Performing Case", worst_score, worst_organ_scores)
else:
    print("Evaluation skipped because no model was saved (best_metric was likely never updated).")


print("\n✅ Pipeline complete!")
# Out:
# ▶️ Step 1: Installing MONAI...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 95.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 67.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 81.8 MB/s eta 0:00:00
# ✅ Installation complete.
#
# ▶️ Step 2: Importing libraries and setting up...
# <frozen importlib._bootstrap_external>:1241: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# 2025-08-11 12:38:42.385732: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754915922.574390      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754915922.628454      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# MONAI version: 1.5.0
# Numpy version: 1.26.4
# Pytorch version: 2.6.0+cu124
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: d388d1c6fec8cb3a0eebee5b5a0b9776ca59ca83
# MONAI __file__: /usr/local/lib/python3.11/dist-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.5.2
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 5.3.2
# scikit-image version: 0.25.2
# scipy version: 1.15.3
# Pillow version: 11.2.1
# Tensorboard version: 2.18.0
# gdown version: 5.2.0
# TorchVision version: 0.21.0+cu124
# tqdm version: 4.67.1
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 7.0.0
# pandas version: 2.2.3
# einops version: 0.8.1
# transformers version: 4.52.4
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies
#
# ✅ Setup complete.
#
# ▶️ Step 3: Preparing Data...
# Model checkpoints will be saved to: /kaggle/working/
# Verifying data integrity...
# ✅ Data prepared: Found 50 valid pairs.
#    --> 40 training files, 10 validation files.
#
# ▶️ Step 4: Defining MONAI transforms and dataloaders...
# ✅ Dataloaders ready.
#
# ▶️ Step 5: Setting up Model, Loss, and Optimizer...
# ✅ Model setup complete.
#
# ▶️ Step 6: Starting Training...
# ----------
# epoch 1/100
# epoch 1 average loss: 0.9701
# ----------
# epoch 2/100
# epoch 2 average loss: 0.9519
# saved new best metric model
# current epoch: 2 current mean dice: 0.0366
# Per-organ Dice scores:
#   - Spleen                : 0.2700
#   - Right Kidney          : 0.0717
#   - Left Kidney           : 0.0524
#   - Gallbladder           : 0.0029
#   - Liver                 : 0.0183
#   - Stomach               : 0.0009
#   - Aorta                 : 0.0001
#   - Inferior Vena Cava    : 0.0004
#   - Pancreas              : 0.0006
#   - Right Adrenal Gland   : 0.0004
#   - Left Adrenal Gland    : 0.0176
#   - Duodenum              : 0.0034
#   - Bladder               : 0.0365
# best mean dice: 0.0366 at epoch: 2
# ----------
# epoch 3/100
# epoch 3 average loss: 0.9307
# ----------
# epoch 4/100
# epoch 4 average loss: 0.9131
# saved new best metric model
# current epoch: 4 current mean dice: 0.0557
# Per-organ Dice scores:
#   - Spleen                : 0.3738
#   - Right Kidney          : 0.1763
#   - Left Kidney           : 0.0396
#   - Gallbladder           : 0.0110
#   - Liver                 : 0.0192
#   - Stomach               : 0.0003
#   - Aorta                 : 0.0001
#   - Inferior Vena Cava    : 0.0008
#   - Pancreas              : 0.0001
#   - Right Adrenal Gland   : 0.0004
#   - Left Adrenal Gland    : 0.0325
#   - Duodenum              : 0.0055
#   - Bladder               : 0.0648
# best mean dice: 0.0557 at epoch: 4
# ----------
# epoch 5/100
# epoch 5 average loss: 0.8956
# ----------
# epoch 6/100
# epoch 6 average loss: 0.8877
# saved new best metric model
# current epoch: 6 current mean dice: 0.0738
# Per-organ Dice scores:
#   - Spleen                : 0.4055
#   - Right Kidney          : 0.3353
#   - Left Kidney           : 0.0496
#   - Gallbladder           : 0.0137
#   - Liver                 : 0.0390
#   - Stomach               : 0.0001
#   - Aorta                 : 0.0010
#   - Inferior Vena Cava    : 0.0002
#   - Pancreas              : 0.0001
#   - Right Adrenal Gland   : 0.0004
#   - Left Adrenal Gland    : 0.0445
#   - Duodenum              : 0.0040
#   - Bladder               : 0.0654
# best mean dice: 0.0738 at epoch: 6
# ----------
# epoch 7/100
# epoch 7 average loss: 0.8752
# ----------
# epoch 8/100
# epoch 8 average loss: 0.8679
# saved new best metric model
# current epoch: 8 current mean dice: 0.1107
# Per-organ Dice scores:
#   - Spleen                : 0.4497
#   - Right Kidney          : 0.4036
#   - Left Kidney           : 0.1229
#   - Gallbladder           : 0.0448
#   - Liver                 : 0.0557
#   - Stomach               : 0.0001
#   - Aorta                 : 0.0033
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0000
#   - Right Adrenal Gland   : 0.0004
#   - Left Adrenal Gland    : 0.1071
#   - Duodenum              : 0.0005
#   - Bladder               : 0.2515
# best mean dice: 0.1107 at epoch: 8
# ----------
# epoch 9/100
# epoch 9 average loss: 0.8562
# ----------
# epoch 10/100
# epoch 10 average loss: 0.8395
# saved new best metric model
# current epoch: 10 current mean dice: 0.1534
# Per-organ Dice scores:
#   - Spleen                : 0.4743
#   - Right Kidney          : 0.6596
#   - Left Kidney           : 0.1846
#   - Gallbladder           : 0.0519
#   - Liver                 : 0.0583
#   - Stomach               : 0.0001
#   - Aorta                 : 0.0010
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0001
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.2105
#   - Duodenum              : 0.0009
#   - Bladder               : 0.3526
# best mean dice: 0.1534 at epoch: 10
# ----------
# epoch 11/100
# epoch 11 average loss: 0.8286
# ----------
# epoch 12/100
# epoch 12 average loss: 0.8354
# saved new best metric model
# current epoch: 12 current mean dice: 0.1855
# Per-organ Dice scores:
#   - Spleen                : 0.5296
#   - Right Kidney          : 0.7612
#   - Left Kidney           : 0.2389
#   - Gallbladder           : 0.0778
#   - Liver                 : 0.0736
#   - Stomach               : 0.0000
#   - Aorta                 : 0.0001
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0004
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.2709
#   - Duodenum              : 0.0017
#   - Bladder               : 0.4567
# best mean dice: 0.1855 at epoch: 12
# ----------
# epoch 13/100
# epoch 13 average loss: 0.8265
# ----------
# epoch 14/100
# epoch 14 average loss: 0.8139
# saved new best metric model
# current epoch: 14 current mean dice: 0.2090
# Per-organ Dice scores:
#   - Spleen                : 0.5689
#   - Right Kidney          : 0.7426
#   - Left Kidney           : 0.3334
#   - Gallbladder           : 0.1290
#   - Liver                 : 0.0789
#   - Stomach               : 0.0000
#   - Aorta                 : 0.0001
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0050
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3347
#   - Duodenum              : 0.0043
#   - Bladder               : 0.5200
# best mean dice: 0.2090 at epoch: 14
# ----------
# epoch 15/100
# epoch 15 average loss: 0.8059
# ----------
# epoch 16/100
# epoch 16 average loss: 0.8025
# saved new best metric model
# current epoch: 16 current mean dice: 0.2509
# Per-organ Dice scores:
#   - Spleen                : 0.5507
#   - Right Kidney          : 0.7903
#   - Left Kidney           : 0.5797
#   - Gallbladder           : 0.1849
#   - Liver                 : 0.0922
#   - Stomach               : 0.0000
#   - Aorta                 : 0.0003
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0024
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3542
#   - Duodenum              : 0.0179
#   - Bladder               : 0.6896
# best mean dice: 0.2509 at epoch: 16
# ----------
# epoch 17/100
# epoch 17 average loss: 0.7972
# ----------
# epoch 18/100
# epoch 18 average loss: 0.7899
# saved new best metric model
# current epoch: 18 current mean dice: 0.2779
# Per-organ Dice scores:
#   - Spleen                : 0.7298
#   - Right Kidney          : 0.8193
#   - Left Kidney           : 0.6225
#   - Gallbladder           : 0.2380
#   - Liver                 : 0.1023
#   - Stomach               : 0.0003
#   - Aorta                 : 0.0001
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0070
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3649
#   - Duodenum              : 0.0183
#   - Bladder               : 0.7098
# best mean dice: 0.2779 at epoch: 18
# ----------
# epoch 19/100
# epoch 19 average loss: 0.7789
# ----------
# epoch 20/100
# epoch 20 average loss: 0.7608
# saved new best metric model
# current epoch: 20 current mean dice: 0.2854
# Per-organ Dice scores:
#   - Spleen                : 0.6994
#   - Right Kidney          : 0.8248
#   - Left Kidney           : 0.5294
#   - Gallbladder           : 0.3109
#   - Liver                 : 0.1760
#   - Stomach               : 0.0020
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0093
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4362
#   - Duodenum              : 0.0304
#   - Bladder               : 0.6913
# best mean dice: 0.2854 at epoch: 20
# ----------
# epoch 21/100
# epoch 21 average loss: 0.7786
# ----------
# epoch 22/100
# epoch 22 average loss: 0.7573
# saved new best metric model
# current epoch: 22 current mean dice: 0.3342
# Per-organ Dice scores:
#   - Spleen                : 0.7716
#   - Right Kidney          : 0.8444
#   - Left Kidney           : 0.7118
#   - Gallbladder           : 0.4052
#   - Liver                 : 0.3081
#   - Stomach               : 0.0241
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0330
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3604
#   - Duodenum              : 0.0743
#   - Bladder               : 0.8120
# best mean dice: 0.3342 at epoch: 22
# ----------
# epoch 23/100
# epoch 23 average loss: 0.7552
# ----------
# epoch 24/100
# epoch 24 average loss: 0.7511
# saved new best metric model
# current epoch: 24 current mean dice: 0.3595
# Per-organ Dice scores:
#   - Spleen                : 0.8281
#   - Right Kidney          : 0.8220
#   - Left Kidney           : 0.6968
#   - Gallbladder           : 0.3374
#   - Liver                 : 0.4437
#   - Stomach               : 0.2072
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0773
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3885
#   - Duodenum              : 0.1270
#   - Bladder               : 0.7452
# best mean dice: 0.3595 at epoch: 24
# ----------
# epoch 25/100
# epoch 25 average loss: 0.7433
# ----------
# epoch 26/100
# epoch 26 average loss: 0.7294
# saved new best metric model
# current epoch: 26 current mean dice: 0.3793
# Per-organ Dice scores:
#   - Spleen                : 0.8248
#   - Right Kidney          : 0.8050
#   - Left Kidney           : 0.6674
#   - Gallbladder           : 0.3601
#   - Liver                 : 0.5348
#   - Stomach               : 0.2490
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.1461
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4429
#   - Duodenum              : 0.1379
#   - Bladder               : 0.7629
# best mean dice: 0.3793 at epoch: 26
# ----------
# epoch 27/100
# epoch 27 average loss: 0.7258
# ----------
# epoch 28/100
# epoch 28 average loss: 0.6921
# saved new best metric model
# current epoch: 28 current mean dice: 0.3907
# Per-organ Dice scores:
#   - Spleen                : 0.8678
#   - Right Kidney          : 0.8220
#   - Left Kidney           : 0.6436
#   - Gallbladder           : 0.3154
#   - Liver                 : 0.4909
#   - Stomach               : 0.2641
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.2889
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4499
#   - Duodenum              : 0.1441
#   - Bladder               : 0.7929
# best mean dice: 0.3907 at epoch: 28
# ----------
# epoch 29/100
# epoch 29 average loss: 0.6991
# ----------
# epoch 30/100
# epoch 30 average loss: 0.7009
# saved new best metric model
# current epoch: 30 current mean dice: 0.4195
# Per-organ Dice scores:
#   - Spleen                : 0.8469
#   - Right Kidney          : 0.8417
#   - Left Kidney           : 0.7161
#   - Gallbladder           : 0.4264
#   - Liver                 : 0.5191
#   - Stomach               : 0.3564
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.2919
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4408
#   - Duodenum              : 0.2142
#   - Bladder               : 0.7998
# best mean dice: 0.4195 at epoch: 30
# ----------
# epoch 31/100
# epoch 31 average loss: 0.6853
# ----------
# epoch 32/100
# epoch 32 average loss: 0.6902
# saved new best metric model
# current epoch: 32 current mean dice: 0.4617
# Per-organ Dice scores:
#   - Spleen                : 0.8688
#   - Right Kidney          : 0.8387
#   - Left Kidney           : 0.7415
#   - Gallbladder           : 0.4922
#   - Liver                 : 0.6600
#   - Stomach               : 0.4752
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.3465
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4434
#   - Duodenum              : 0.3191
#   - Bladder               : 0.8160
# best mean dice: 0.4617 at epoch: 32
# ----------
# epoch 33/100
# epoch 33 average loss: 0.6923
# ----------
# epoch 34/100
# epoch 34 average loss: 0.6770
# saved new best metric model
# current epoch: 34 current mean dice: 0.4780
# Per-organ Dice scores:
#   - Spleen                : 0.8927
#   - Right Kidney          : 0.8423
#   - Left Kidney           : 0.7250
#   - Gallbladder           : 0.5391
#   - Liver                 : 0.7103
#   - Stomach               : 0.5437
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.3808
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4519
#   - Duodenum              : 0.3175
#   - Bladder               : 0.8104
# best mean dice: 0.4780 at epoch: 34
# ----------
# epoch 35/100
# epoch 35 average loss: 0.6658
# ----------
# epoch 36/100
# epoch 36 average loss: 0.6695
# current epoch: 36 current mean dice: 0.4723
# Per-organ Dice scores:
#   - Spleen                : 0.8796
#   - Right Kidney          : 0.8229
#   - Left Kidney           : 0.7340
#   - Gallbladder           : 0.5484
#   - Liver                 : 0.7325
#   - Stomach               : 0.4190
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.3850
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5368
#   - Duodenum              : 0.2699
#   - Bladder               : 0.8112
# best mean dice: 0.4780 at epoch: 34
# ----------
# epoch 37/100
# epoch 37 average loss: 0.6795
# ----------
# epoch 38/100
# epoch 38 average loss: 0.6698
# saved new best metric model
# current epoch: 38 current mean dice: 0.4888
# Per-organ Dice scores:
#   - Spleen                : 0.8938
#   - Right Kidney          : 0.8374
#   - Left Kidney           : 0.7235
#   - Gallbladder           : 0.5574
#   - Liver                 : 0.7267
#   - Stomach               : 0.5630
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.4476
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5342
#   - Duodenum              : 0.3012
#   - Bladder               : 0.7698
# best mean dice: 0.4888 at epoch: 38
# ----------
# epoch 39/100
# epoch 39 average loss: 0.6674
# ----------
# epoch 40/100
# epoch 40 average loss: 0.6538
# saved new best metric model
# current epoch: 40 current mean dice: 0.5019
# Per-organ Dice scores:
#   - Spleen                : 0.8961
#   - Right Kidney          : 0.8312
#   - Left Kidney           : 0.7822
#   - Gallbladder           : 0.4781
#   - Liver                 : 0.8045
#   - Stomach               : 0.6004
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.4274
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5129
#   - Duodenum              : 0.3717
#   - Bladder               : 0.8206
# best mean dice: 0.5019 at epoch: 40
# ----------
# epoch 41/100
# epoch 41 average loss: 0.6517
# ----------
# epoch 42/100
# epoch 42 average loss: 0.6559
# saved new best metric model
# current epoch: 42 current mean dice: 0.5169
# Per-organ Dice scores:
#   - Spleen                : 0.9101
#   - Right Kidney          : 0.8376
#   - Left Kidney           : 0.7730
#   - Gallbladder           : 0.5788
#   - Liver                 : 0.7891
#   - Stomach               : 0.6231
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5058
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5463
#   - Duodenum              : 0.3204
#   - Bladder               : 0.8356
# best mean dice: 0.5169 at epoch: 42
# ----------
# epoch 43/100
# epoch 43 average loss: 0.6363
# ----------
# epoch 44/100
# epoch 44 average loss: 0.6497
# saved new best metric model
# current epoch: 44 current mean dice: 0.5195
# Per-organ Dice scores:
#   - Spleen                : 0.9187
#   - Right Kidney          : 0.8432
#   - Left Kidney           : 0.7898
#   - Gallbladder           : 0.5804
#   - Liver                 : 0.7368
#   - Stomach               : 0.5930
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.4827
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5909
#   - Duodenum              : 0.3894
#   - Bladder               : 0.8280
# best mean dice: 0.5195 at epoch: 44
# ----------
# epoch 45/100
# epoch 45 average loss: 0.6553
# ----------
# epoch 46/100
# epoch 46 average loss: 0.6314
# saved new best metric model
# current epoch: 46 current mean dice: 0.5341
# Per-organ Dice scores:
#   - Spleen                : 0.9274
#   - Right Kidney          : 0.8608
#   - Left Kidney           : 0.7859
#   - Gallbladder           : 0.5895
#   - Liver                 : 0.7974
#   - Stomach               : 0.6551
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5650
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5592
#   - Duodenum              : 0.4146
#   - Bladder               : 0.7885
# best mean dice: 0.5341 at epoch: 46
# ----------
# epoch 47/100
# epoch 47 average loss: 0.6555
# ----------
# epoch 48/100
# epoch 48 average loss: 0.6343
# saved new best metric model
# current epoch: 48 current mean dice: 0.5450
# Per-organ Dice scores:
#   - Spleen                : 0.9267
#   - Right Kidney          : 0.8654
#   - Left Kidney           : 0.8623
#   - Gallbladder           : 0.5477
#   - Liver                 : 0.8225
#   - Stomach               : 0.7223
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.4913
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5723
#   - Duodenum              : 0.4282
#   - Bladder               : 0.8466
# best mean dice: 0.5450 at epoch: 48
# ----------
# epoch 49/100
# epoch 49 average loss: 0.6438
# ----------
# epoch 50/100
# epoch 50 average loss: 0.6353
# current epoch: 50 current mean dice: 0.5403
# Per-organ Dice scores:
#   - Spleen                : 0.9036
#   - Right Kidney          : 0.8581
#   - Left Kidney           : 0.7782
#   - Gallbladder           : 0.5594
#   - Liver                 : 0.8031
#   - Stomach               : 0.6866
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5548
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5831
#   - Duodenum              : 0.4665
#   - Bladder               : 0.8301
# best mean dice: 0.5450 at epoch: 48
# ----------
# epoch 51/100
# epoch 51 average loss: 0.6380
# ----------
# epoch 52/100
# epoch 52 average loss: 0.6247
# saved new best metric model
# current epoch: 52 current mean dice: 0.5512
# Per-organ Dice scores:
#   - Spleen                : 0.9176
#   - Right Kidney          : 0.8580
#   - Left Kidney           : 0.8277
#   - Gallbladder           : 0.5695
#   - Liver                 : 0.8036
#   - Stomach               : 0.7201
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5474
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6203
#   - Duodenum              : 0.4640
#   - Bladder               : 0.8375
# best mean dice: 0.5512 at epoch: 52
# ----------
# epoch 53/100
# epoch 53 average loss: 0.6445
# ----------
# epoch 54/100
# epoch 54 average loss: 0.6250
# saved new best metric model
# current epoch: 54 current mean dice: 0.5719
# Per-organ Dice scores:
#   - Spleen                : 0.9330
#   - Right Kidney          : 0.8476
#   - Left Kidney           : 0.8641
#   - Gallbladder           : 0.6032
#   - Liver                 : 0.8422
#   - Stomach               : 0.7524
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6219
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6787
#   - Duodenum              : 0.4455
#   - Bladder               : 0.8459
# best mean dice: 0.5719 at epoch: 54
# ----------
# epoch 55/100
# epoch 55 average loss: 0.6494
# ----------
# epoch 56/100
# epoch 56 average loss: 0.6250
# current epoch: 56 current mean dice: 0.5673
# Per-organ Dice scores:
#   - Spleen                : 0.9271
#   - Right Kidney          : 0.8663
#   - Left Kidney           : 0.8353
#   - Gallbladder           : 0.6064
#   - Liver                 : 0.8205
#   - Stomach               : 0.7567
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5813
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6374
#   - Duodenum              : 0.5092
#   - Bladder               : 0.8349
# best mean dice: 0.5719 at epoch: 54
# ----------
# epoch 57/100
# epoch 57 average loss: 0.6237
# ----------
# epoch 58/100
# epoch 58 average loss: 0.6236
# current epoch: 58 current mean dice: 0.5699
# Per-organ Dice scores:
#   - Spleen                : 0.9267
#   - Right Kidney          : 0.8653
#   - Left Kidney           : 0.8383
#   - Gallbladder           : 0.6291
#   - Liver                 : 0.8147
#   - Stomach               : 0.7564
#   - Aorta                 : 0.0007
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5960
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6622
#   - Duodenum              : 0.4820
#   - Bladder               : 0.8367
# best mean dice: 0.5719 at epoch: 54
# ----------
# epoch 59/100
# epoch 59 average loss: 0.6417
# ----------
# epoch 60/100
# epoch 60 average loss: 0.6228
# current epoch: 60 current mean dice: 0.5718
# Per-organ Dice scores:
#   - Spleen                : 0.9374
#   - Right Kidney          : 0.8550
#   - Left Kidney           : 0.8493
#   - Gallbladder           : 0.6154
#   - Liver                 : 0.8404
#   - Stomach               : 0.7510
#   - Aorta                 : 0.0007
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5927
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6572
#   - Duodenum              : 0.4999
#   - Bladder               : 0.8349
# best mean dice: 0.5719 at epoch: 54
# ----------
# epoch 61/100
# epoch 61 average loss: 0.6270
# ----------
# epoch 62/100
# epoch 62 average loss: 0.6146
# current epoch: 62 current mean dice: 0.5712
# Per-organ Dice scores:
#   - Spleen                : 0.9318
#   - Right Kidney          : 0.8685
#   - Left Kidney           : 0.8264
#   - Gallbladder           : 0.6113
#   - Liver                 : 0.8338
#   - Stomach               : 0.7457
#   - Aorta                 : 0.0016
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5940
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6745
#   - Duodenum              : 0.5014
#   - Bladder               : 0.8368
# best mean dice: 0.5719 at epoch: 54
# ----------
# epoch 63/100
# epoch 63 average loss: 0.6475
# ----------
# epoch 64/100
# epoch 64 average loss: 0.6177
# saved new best metric model
# current epoch: 64 current mean dice: 0.5816
# Per-organ Dice scores:
#   - Spleen                : 0.9344
#   - Right Kidney          : 0.8658
#   - Left Kidney           : 0.8463
#   - Gallbladder           : 0.6495
#   - Liver                 : 0.8359
#   - Stomach               : 0.7429
#   - Aorta                 : 0.0036
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5977
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7207
#   - Duodenum              : 0.5227
#   - Bladder               : 0.8415
# best mean dice: 0.5816 at epoch: 64
# ----------
# epoch 65/100
# epoch 65 average loss: 0.6081
# ----------
# epoch 66/100
# epoch 66 average loss: 0.6121
# current epoch: 66 current mean dice: 0.5798
# Per-organ Dice scores:
#   - Spleen                : 0.9347
#   - Right Kidney          : 0.8534
#   - Left Kidney           : 0.8607
#   - Gallbladder           : 0.6431
#   - Liver                 : 0.8354
#   - Stomach               : 0.7718
#   - Aorta                 : 0.0129
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5729
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6914
#   - Duodenum              : 0.5250
#   - Bladder               : 0.8355
# best mean dice: 0.5816 at epoch: 64
# ----------
# epoch 67/100
# epoch 67 average loss: 0.6200
# ----------
# epoch 68/100
# epoch 68 average loss: 0.6218
# saved new best metric model
# current epoch: 68 current mean dice: 0.5882
# Per-organ Dice scores:
#   - Spleen                : 0.9371
#   - Right Kidney          : 0.8649
#   - Left Kidney           : 0.8812
#   - Gallbladder           : 0.6643
#   - Liver                 : 0.8291
#   - Stomach               : 0.7627
#   - Aorta                 : 0.0306
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6010
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7158
#   - Duodenum              : 0.5168
#   - Bladder               : 0.8433
# best mean dice: 0.5882 at epoch: 68
# ----------
# epoch 69/100
# epoch 69 average loss: 0.6163
# ----------
# epoch 70/100
# epoch 70 average loss: 0.6209
# saved new best metric model
# current epoch: 70 current mean dice: 0.5900
# Per-organ Dice scores:
#   - Spleen                : 0.9340
#   - Right Kidney          : 0.8866
#   - Left Kidney           : 0.8543
#   - Gallbladder           : 0.6488
#   - Liver                 : 0.8511
#   - Stomach               : 0.7678
#   - Aorta                 : 0.0381
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6108
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7129
#   - Duodenum              : 0.5289
#   - Bladder               : 0.8369
# best mean dice: 0.5900 at epoch: 70
# ----------
# epoch 71/100
# epoch 71 average loss: 0.6179
# ----------
# epoch 72/100
# epoch 72 average loss: 0.6058
# current epoch: 72 current mean dice: 0.5826
# Per-organ Dice scores:
#   - Spleen                : 0.9306
#   - Right Kidney          : 0.8741
#   - Left Kidney           : 0.8526
#   - Gallbladder           : 0.6307
#   - Liver                 : 0.8401
#   - Stomach               : 0.7418
#   - Aorta                 : 0.0650
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6174
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6997
#   - Duodenum              : 0.4847
#   - Bladder               : 0.8375
# best mean dice: 0.5900 at epoch: 70
# ----------
# epoch 73/100
# epoch 73 average loss: 0.6031
# ----------
# epoch 74/100
# epoch 74 average loss: 0.6076
# current epoch: 74 current mean dice: 0.5879
# Per-organ Dice scores:
#   - Spleen                : 0.9286
#   - Right Kidney          : 0.8730
#   - Left Kidney           : 0.8621
#   - Gallbladder           : 0.6356
#   - Liver                 : 0.8434
#   - Stomach               : 0.7634
#   - Aorta                 : 0.0807
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5982
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6937
#   - Duodenum              : 0.5182
#   - Bladder               : 0.8459
# best mean dice: 0.5900 at epoch: 70
# ----------
# epoch 75/100
# epoch 75 average loss: 0.5956
# ----------
# epoch 76/100
# epoch 76 average loss: 0.6042
# saved new best metric model
# current epoch: 76 current mean dice: 0.5954
# Per-organ Dice scores:
#   - Spleen                : 0.9321
#   - Right Kidney          : 0.8742
#   - Left Kidney           : 0.8696
#   - Gallbladder           : 0.6384
#   - Liver                 : 0.8471
#   - Stomach               : 0.7679
#   - Aorta                 : 0.1191
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6158
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7085
#   - Duodenum              : 0.5245
#   - Bladder               : 0.8432
# best mean dice: 0.5954 at epoch: 76
# ----------
# epoch 77/100
# epoch 77 average loss: 0.6136
# ----------
# epoch 78/100
# epoch 78 average loss: 0.6043
# saved new best metric model
# current epoch: 78 current mean dice: 0.5985
# Per-organ Dice scores:
#   - Spleen                : 0.9307
#   - Right Kidney          : 0.8754
#   - Left Kidney           : 0.8490
#   - Gallbladder           : 0.6390
#   - Liver                 : 0.8476
#   - Stomach               : 0.7676
#   - Aorta                 : 0.1708
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6155
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7085
#   - Duodenum              : 0.5338
#   - Bladder               : 0.8421
# best mean dice: 0.5985 at epoch: 78
# ----------
# epoch 79/100
# epoch 79 average loss: 0.6227
# ----------
# epoch 80/100
# epoch 80 average loss: 0.6025
# saved new best metric model
# current epoch: 80 current mean dice: 0.6077
# Per-organ Dice scores:
#   - Spleen                : 0.9377
#   - Right Kidney          : 0.8678
#   - Left Kidney           : 0.8761
#   - Gallbladder           : 0.6526
#   - Liver                 : 0.8487
#   - Stomach               : 0.7731
#   - Aorta                 : 0.2052
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6262
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7232
#   - Duodenum              : 0.5473
#   - Bladder               : 0.8417
# best mean dice: 0.6077 at epoch: 80
# ----------
# epoch 81/100
# epoch 81 average loss: 0.6248
# ----------
# epoch 82/100
# epoch 82 average loss: 0.6187
# saved new best metric model
# current epoch: 82 current mean dice: 0.6078
# Per-organ Dice scores:
#   - Spleen                : 0.9337
#   - Right Kidney          : 0.8702
#   - Left Kidney           : 0.8647
#   - Gallbladder           : 0.6535
#   - Liver                 : 0.8539
#   - Stomach               : 0.7749
#   - Aorta                 : 0.2221
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6187
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7206
#   - Duodenum              : 0.5478
#   - Bladder               : 0.8417
# best mean dice: 0.6078 at epoch: 82
# ----------
# epoch 83/100
# epoch 83 average loss: 0.6075
# ----------
# epoch 84/100
# epoch 84 average loss: 0.6267
# saved new best metric model
# current epoch: 84 current mean dice: 0.6098
# Per-organ Dice scores:
#   - Spleen                : 0.9349
#   - Right Kidney          : 0.8780
#   - Left Kidney           : 0.8668
#   - Gallbladder           : 0.6529
#   - Liver                 : 0.8522
#   - Stomach               : 0.7741
#   - Aorta                 : 0.2318
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6193
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7228
#   - Duodenum              : 0.5540
#   - Bladder               : 0.8406
# best mean dice: 0.6098 at epoch: 84
# ----------
# epoch 85/100
# epoch 85 average loss: 0.6168
# ----------
# epoch 86/100
# epoch 86 average loss: 0.5903
# saved new best metric model
# current epoch: 86 current mean dice: 0.6122
# Per-organ Dice scores:
#   - Spleen                : 0.9361
#   - Right Kidney          : 0.8782
#   - Left Kidney           : 0.8721
#   - Gallbladder           : 0.6506
#   - Liver                 : 0.8577
#   - Stomach               : 0.7731
#   - Aorta                 : 0.2475
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6256
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7268
#   - Duodenum              : 0.5489
#   - Bladder               : 0.8425
# best mean dice: 0.6122 at epoch: 86
# ----------
# epoch 87/100
# epoch 87 average loss: 0.6229
# ----------
# epoch 88/100
# epoch 88 average loss: 0.6130
# saved new best metric model
# current epoch: 88 current mean dice: 0.6146
# Per-organ Dice scores:
#   - Spleen                : 0.9385
#   - Right Kidney          : 0.8757
#   - Left Kidney           : 0.8767
#   - Gallbladder           : 0.6533
#   - Liver                 : 0.8533
#   - Stomach               : 0.7738
#   - Aorta                 : 0.2704
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6311
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7305
#   - Duodenum              : 0.5453
#   - Bladder               : 0.8412
# best mean dice: 0.6146 at epoch: 88
# ----------
# epoch 89/100
# epoch 89 average loss: 0.6043
# ----------
# epoch 90/100
# epoch 90 average loss: 0.5902
# current epoch: 90 current mean dice: 0.6141
# Per-organ Dice scores:
#   - Spleen                : 0.9363
#   - Right Kidney          : 0.8761
#   - Left Kidney           : 0.8717
#   - Gallbladder           : 0.6501
#   - Liver                 : 0.8559
#   - Stomach               : 0.7764
#   - Aorta                 : 0.2746
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6257
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7291
#   - Duodenum              : 0.5452
#   - Bladder               : 0.8428
# best mean dice: 0.6146 at epoch: 88
# ----------
# epoch 91/100
# epoch 91 average loss: 0.6075
# ----------
# epoch 92/100
# epoch 92 average loss: 0.5716
# current epoch: 92 current mean dice: 0.6146
# Per-organ Dice scores:
#   - Spleen                : 0.9377
#   - Right Kidney          : 0.8732
#   - Left Kidney           : 0.8750
#   - Gallbladder           : 0.6537
#   - Liver                 : 0.8532
#   - Stomach               : 0.7760
#   - Aorta                 : 0.2828
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6225
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7279
#   - Duodenum              : 0.5446
#   - Bladder               : 0.8427
# best mean dice: 0.6146 at epoch: 88
# ----------
# epoch 93/100
# epoch 93 average loss: 0.5956
# ----------
# epoch 94/100
# epoch 94 average loss: 0.6069
# current epoch: 94 current mean dice: 0.6138
# Per-organ Dice scores:
#   - Spleen                : 0.9380
#   - Right Kidney          : 0.8743
#   - Left Kidney           : 0.8758
#   - Gallbladder           : 0.6504
#   - Liver                 : 0.8525
#   - Stomach               : 0.7749
#   - Aorta                 : 0.2821
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6220
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7262
#   - Duodenum              : 0.5406
#   - Bladder               : 0.8429
# best mean dice: 0.6146 at epoch: 88
# ----------
# epoch 95/100
# epoch 95 average loss: 0.5894
# ----------
# epoch 96/100
# epoch 96 average loss: 0.6164
# current epoch: 96 current mean dice: 0.6139
# Per-organ Dice scores:
#   - Spleen                : 0.9378
#   - Right Kidney          : 0.8747
#   - Left Kidney           : 0.8756
#   - Gallbladder           : 0.6501
#   - Liver                 : 0.8530
#   - Stomach               : 0.7749
#   - Aorta                 : 0.2838
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6211
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7264
#   - Duodenum              : 0.5402
#   - Bladder               : 0.8433
# best mean dice: 0.6146 at epoch: 88
# ----------
# epoch 97/100
# epoch 97 average loss: 0.6006
# ----------
# epoch 98/100
# epoch 98 average loss: 0.5825
# current epoch: 98 current mean dice: 0.6140
# Per-organ Dice scores:
#   - Spleen                : 0.9381
#   - Right Kidney          : 0.8750
#   - Left Kidney           : 0.8761
#   - Gallbladder           : 0.6501
#   - Liver                 : 0.8533
#   - Stomach               : 0.7755
#   - Aorta                 : 0.2835
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6203
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7265
#   - Duodenum              : 0.5406
#   - Bladder               : 0.8435
# best mean dice: 0.6146 at epoch: 88
# ----------
# epoch 99/100
# epoch 99 average loss: 0.6081
# ----------
# epoch 100/100
# epoch 100 average loss: 0.5968
# current epoch: 100 current mean dice: 0.6140
# Per-organ Dice scores:
#   - Spleen                : 0.9379
#   - Right Kidney          : 0.8750
#   - Left Kidney           : 0.8758
#   - Gallbladder           : 0.6499
#   - Liver                 : 0.8534
#   - Stomach               : 0.7753
#   - Aorta                 : 0.2842
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6201
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.7262
#   - Duodenum              : 0.5405
#   - Bladder               : 0.8435
# best mean dice: 0.6146 at epoch: 88
#
# ✅ Training complete. Best mean dice: 0.6146 at epoch 88
#
# ▶️ Step 7: Evaluating and Visualizing Results...
# ------------------------------
# 📊 Best Performing Case: FLARE22_Tr_0050_0000.nii
# Mean Dice: 0.6984
# Per-Organ Dice Scores:
#   - Spleen                : 0.9635
#   - Right Kidney          : 0.9547
#   - Left Kidney           : 0.9533
#   - Gallbladder           : 0.7025
#   - Liver                 : 0.8810
#   - Stomach               : 0.7900
#   - Aorta                 : 0.4437
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.8387
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.8146
#   - Duodenum              : 0.7765
#   - Bladder               : 0.9603
# ------------------------------
# 📊 Worst Performing Case: FLARE22_Tr_0045_0000.nii
# Mean Dice: 0.5344
# Per-Organ Dice Scores:
#   - Spleen                : 0.9429
#   - Right Kidney          : 0.6526
#   - Left Kidney           : 0.8861
#   - Gallbladder           : 0.5928
#   - Liver                 : 0.7801
#   - Stomach               : 0.8119
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7122
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6605
#   - Duodenum              : 0.6814
#   - Bladder               : 0.2263
# ✅ Pipeline complete!
