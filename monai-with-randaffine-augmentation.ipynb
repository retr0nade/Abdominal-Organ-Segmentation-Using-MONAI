# %%
# ==============================================================================
# KAGGLE PIPELINE: EXPERIMENT 4 - ADDING RandAffine AUGMENTATION (CORRECTED)
# ==============================================================================

print("▶️ Step 1: Installing MONAI...")
# !pip install -q "monai[nibabel, tqdm]"
print("✅ Installation complete.")

print("\n▶️ Step 2: Importing libraries and setting up...")
import os
import shutil
import time
from glob import glob

import torch
import monai
import numpy as np
from monai.config import print_config
from monai.data import DataLoader, Dataset, decollate_batch
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.metrics import DiceMetric
from monai.networks.nets import UNet
from monai.transforms import (
    Activations,
    AsDiscrete,
    Compose,
    EnsureChannelFirstd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    RandRotate90d,
    RandGaussianNoised,
    ScaleIntensityRanged,
    Spacingd,
    SpatialPadD,
    EnsureTyped,
    # --- CORRECTED: Import RandAffined (with a 'd') ---
    RandAffined,
)
import matplotlib.pyplot as plt

print_config()
print("✅ Setup complete.")

# ==============================================================================
# 2. PREPARE DATASET (WITH DATA INTEGRITY CHECK)
# ==============================================================================
print("\n▶️ Step 3: Preparing Data...")
try:
    output_dir = "/kaggle/working/"
    os.makedirs(output_dir, exist_ok=True)
    print(f"Model checkpoints will be saved to: {output_dir}")

    drive_data_path = "/kaggle/input/flare22train/FLARE22Train"
    images_path = os.path.join(drive_data_path, "images")
    labels_path = os.path.join(drive_data_path, "labels")

    all_images = sorted(glob(os.path.join(images_path, "*.nii")))
    all_labels = sorted(glob(os.path.join(labels_path, "*.nii")))

    print("Verifying data integrity...")
    data_dicts = []
    for img_path, lbl_path in zip(all_images, all_labels):
        if os.path.exists(img_path) and os.path.exists(lbl_path) and os.path.getsize(img_path) > 0 and os.path.getsize(lbl_path) > 0:
            data_dicts.append({"image": img_path, "label": lbl_path})
        else:
            print(f"WARNING: Skipping corrupted or empty file pair: {os.path.basename(img_path)} and {os.path.basename(lbl_path)}")

    if len(data_dicts) == 0:
        raise FileNotFoundError(f"No valid, non-empty image/label pairs found.")

    num_total = len(data_dicts)
    num_train = int(num_total * 0.8)
    train_files, val_files = data_dicts[:num_train], data_dicts[num_train:]

    print(f"✅ Data prepared: Found {len(data_dicts)} valid pairs.")
    print(f"   --> {len(train_files)} training files, {len(val_files)} validation files.")
except Exception as e:
    print(f"❌ FATAL ERROR in Data Preparation: {e}")
    raise e

# ==============================================================================
# 3. DEFINE TRANSFORMS, DATASET, AND DATALOADER
# ==============================================================================
print("\n▶️ Step 4: Defining MONAI transforms and dataloaders...")
roi_size = (96, 96, 96)
train_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-175, a_max=250, b_min=0.0, b_max=1.0, clip=True),
    SpatialPadD(keys=["image", "label"], spatial_size=roi_size, method="end"),
    RandCropByPosNegLabeld(
        keys=["image", "label"], label_key="label", spatial_size=roi_size,
        pos=1, neg=1, num_samples=4, image_key="image", image_threshold=0,
    ),
    # --- CORRECTED: Use RandAffined (with a 'd') ---
    RandAffined(
        keys=['image', 'label'],
        mode=('bilinear', 'nearest'),
        prob=0.2,
        rotate_range=(0, 0, np.pi/15),
        scale_range=(0.1, 0.1, 0.1),
        padding_mode="border",
    ),
    RandRotate90d(keys=["image", "label"], prob=0.10, max_k=3),
    RandGaussianNoised(keys="image", prob=0.10, mean=0.0, std=0.1),
    EnsureTyped(keys=["image", "label"]),
])
val_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-175, a_max=250, b_min=0.0, b_max=1.0, clip=True),
    EnsureTyped(keys=["image", "label"]),
])

train_ds = Dataset(data=train_files, transform=train_transforms)
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=2)
val_ds = Dataset(data=val_files, transform=val_transforms)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=2)
print("✅ Dataloaders ready.")

# ==============================================================================
# 4. SET UP MODEL, LOSS, AND OPTIMIZER
# ==============================================================================
print("\n▶️ Step 5: Setting up Model, Loss, and Optimizer...")
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = UNet(
    spatial_dims=3, in_channels=1, out_channels=14,
    channels=(16, 32, 64, 128, 256), strides=(2, 2, 2, 2),
    num_res_units=2,
).to(device)

loss_function = DiceLoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4)
dice_metric = DiceMetric(include_background=False, reduction="mean_batch")
organ_names = [
    "Spleen", "Right Kidney", "Left Kidney", "Gallbladder", "Liver", "Stomach",
    "Aorta", "Inferior Vena Cava", "Pancreas", "Right Adrenal Gland",
    "Left Adrenal Gland", "Duodenum", "Bladder"
]
print("✅ Model setup complete.")


# ==============================================================================
# 5. TRAINING LOOP
# ==============================================================================
print("\n▶️ Step 6: Starting Training...")
max_epochs = 100
val_interval = 2
best_metric = -1
best_metric_epoch = -1
post_pred = Compose([Activations(softmax=True), AsDiscrete(argmax=True, to_onehot=14)])
post_label = Compose([AsDiscrete(to_onehot=14)])

for epoch in range(max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    if len(train_loader) == 0: break
    for batch_data in train_loader:
        step += 1
        inputs, labels = (batch_data["image"].to(device), batch_data["label"].to(device))
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print(f"{step*train_loader.batch_size}/{len(train_ds)}, train_loss: {loss.item():.4f}", end="\r")

    epoch_loss /= step
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0 and len(val_loader) > 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (val_data["image"].to(device), val_data["label"].to(device))
                val_outputs = sliding_window_inference(val_inputs, roi_size, 4, model)
                val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                dice_metric(y_pred=val_outputs, y=val_labels)

            metric_batch = dice_metric.aggregate()
            metric = metric_batch.mean().item()
            dice_metric.reset()

            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(output_dir, "best_metric_model.pth"))
                print("saved new best metric model")
            print(f"current epoch: {epoch + 1} current mean dice: {metric:.4f}")
            print("Per-organ Dice scores:")
            for i, name in enumerate(organ_names):
                print(f"  - {name:<22}: {metric_batch[i].item():.4f}")
            print(f"best mean dice: {best_metric:.4f} at epoch: {best_metric_epoch}")

print(f"\n✅ Training complete. Best mean dice: {best_metric:.4f} at epoch {best_metric_epoch}")


# ==============================================================================
# 6. ENHANCED VISUALIZATION
# ==============================================================================
print("\n▶️ Step 7: Evaluating and Visualizing Results...")
best_model_path = os.path.join(output_dir, "best_metric_model.pth")

if os.path.exists(best_model_path):
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()

    validation_mean_scores = {}
    validation_organ_scores = {}

    with torch.no_grad():
        for i, val_data in enumerate(val_loader):
            val_inputs = val_data["image"].to(device)
            val_labels = val_data["label"].to(device)
            val_outputs = sliding_window_inference(val_inputs, roi_size, 4, model)
            val_outputs_post = [post_pred(i) for i in decollate_batch(val_outputs)]
            val_labels_post = [post_label(i) for i in decollate_batch(val_labels)]
            dice_metric(y_pred=val_outputs_post, y=val_labels_post)
            organ_scores = dice_metric.aggregate()
            mean_score = organ_scores.mean().item()
            dice_metric.reset()
            case_name = os.path.basename(val_files[i]['image'])
            validation_mean_scores[case_name] = mean_score
            validation_organ_scores[case_name] = organ_scores.cpu().numpy()

    sorted_scores = sorted(validation_mean_scores.items(), key=lambda item: item[1])
    best_case_name, best_score = sorted_scores[-1]
    worst_case_name, worst_score = sorted_scores[0]

    def plot_and_report_case(case_dict, title, mean_dice, organ_dice):
        case_name = os.path.basename(case_dict['image'])
        print("-" * 30)
        print(f"📊 {title}: {case_name}")
        print(f"Mean Dice: {mean_dice:.4f}")
        print("Per-Organ Dice Scores:")
        for i, name in enumerate(organ_names):
            print(f"  - {name:<22}: {organ_dice[i]:.4f}")

        with torch.no_grad():
            transformed_data = val_transforms(case_dict)
            val_input = transformed_data['image'].unsqueeze(0).to(device)
            val_output = sliding_window_inference(val_input, roi_size, 4, model)
            val_output_processed = torch.argmax(val_output, dim=1).detach().cpu().numpy()[0, :, :, :]

            ground_truth = transformed_data['label'][0, :, :, :].numpy()
            original_image = transformed_data['image'][0, :, :, :].numpy()
            slice_idx = np.argmax(np.sum(ground_truth, axis=(0, 1)))

            fig, axes = plt.subplots(1, 3, figsize=(18, 6))
            fig.suptitle(f"{title}\n{case_name}\nMean Dice: {mean_dice:.4f}", fontsize=16)
            axes[0].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[0].set_title("Original Image"); axes[0].axis('off')
            axes[1].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[1].imshow(np.rot90(ground_truth[:, :, slice_idx]), cmap="jet", alpha=0.6); axes[1].set_title("Ground Truth"); axes[1].axis('off')
            axes[2].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[2].imshow(np.rot90(val_output_processed[:, :, slice_idx]), cmap="jet", alpha=0.6); axes[2].set_title("MONAI Prediction"); axes[2].axis('off')
            plt.show()

    best_case_dict = next(item for item in val_files if best_case_name in item["image"])
    worst_case_dict = next(item for item in val_files if worst_case_name in item["image"])

    best_organ_scores = validation_organ_scores[best_case_name]
    worst_organ_scores = validation_organ_scores[worst_case_name]

    plot_and_report_case(best_case_dict, "Best Performing Case", best_score, best_organ_scores)
    plot_and_report_case(worst_case_dict, "Worst Performing Case", worst_score, worst_organ_scores)
else:
    print("Evaluation skipped because no model was saved.")

print("\n✅ Pipeline complete!")
# Out:
# ▶️ Step 1: Installing MONAI...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 60.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 76.7 MB/s eta 0:00:00
# ✅ Installation complete.
#
# ▶️ Step 2: Importing libraries and setting up...
# <frozen importlib._bootstrap_external>:1241: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# 2025-08-12 04:02:57.766280: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754971378.009958      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754971378.078056      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# MONAI version: 1.5.0
# Numpy version: 1.26.4
# Pytorch version: 2.6.0+cu124
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: d388d1c6fec8cb3a0eebee5b5a0b9776ca59ca83
# MONAI __file__: /usr/local/lib/python3.11/dist-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.5.2
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 5.3.2
# scikit-image version: 0.25.2
# scipy version: 1.15.3
# Pillow version: 11.2.1
# Tensorboard version: 2.18.0
# gdown version: 5.2.0
# TorchVision version: 0.21.0+cu124
# tqdm version: 4.67.1
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 7.0.0
# pandas version: 2.2.3
# einops version: 0.8.1
# transformers version: 4.52.4
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies
#
# ✅ Setup complete.
#
# ▶️ Step 3: Preparing Data...
# Model checkpoints will be saved to: /kaggle/working/
# Verifying data integrity...
# ✅ Data prepared: Found 50 valid pairs.
#    --> 40 training files, 10 validation files.
#
# ▶️ Step 4: Defining MONAI transforms and dataloaders...
# ✅ Dataloaders ready.
#
# ▶️ Step 5: Setting up Model, Loss, and Optimizer...
# ✅ Model setup complete.
#
# ▶️ Step 6: Starting Training...
# ----------
# epoch 1/100
# epoch 1 average loss: 0.9670
# ----------
# epoch 2/100
# epoch 2 average loss: 0.9517
# saved new best metric model
# current epoch: 2 current mean dice: 0.0380
# Per-organ Dice scores:
#   - Spleen                : 0.3139
#   - Right Kidney          : 0.0511
#   - Left Kidney           : 0.0344
#   - Gallbladder           : 0.0055
#   - Liver                 : 0.0072
#   - Stomach               : 0.0035
#   - Aorta                 : 0.0002
#   - Inferior Vena Cava    : 0.0003
#   - Pancreas              : 0.0041
#   - Right Adrenal Gland   : 0.0007
#   - Left Adrenal Gland    : 0.0349
#   - Duodenum              : 0.0029
#   - Bladder               : 0.0356
# best mean dice: 0.0380 at epoch: 2
# ----------
# epoch 3/100
# epoch 3 average loss: 0.9320
# ----------
# epoch 4/100
# epoch 4 average loss: 0.9160
# saved new best metric model
# current epoch: 4 current mean dice: 0.0506
# Per-organ Dice scores:
#   - Spleen                : 0.3814
#   - Right Kidney          : 0.1185
#   - Left Kidney           : 0.0048
#   - Gallbladder           : 0.0028
#   - Liver                 : 0.0143
#   - Stomach               : 0.0162
#   - Aorta                 : 0.0005
#   - Inferior Vena Cava    : 0.0002
#   - Pancreas              : 0.0095
#   - Right Adrenal Gland   : 0.0002
#   - Left Adrenal Gland    : 0.0416
#   - Duodenum              : 0.0062
#   - Bladder               : 0.0615
# best mean dice: 0.0506 at epoch: 4
# ----------
# epoch 5/100
# epoch 5 average loss: 0.9010
# ----------
# epoch 6/100
# epoch 6 average loss: 0.8874
# saved new best metric model
# current epoch: 6 current mean dice: 0.0741
# Per-organ Dice scores:
#   - Spleen                : 0.4415
#   - Right Kidney          : 0.2505
#   - Left Kidney           : 0.0023
#   - Gallbladder           : 0.0184
#   - Liver                 : 0.0172
#   - Stomach               : 0.0282
#   - Aorta                 : 0.0011
#   - Inferior Vena Cava    : 0.0004
#   - Pancreas              : 0.0151
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.1013
#   - Duodenum              : 0.0093
#   - Bladder               : 0.0777
# best mean dice: 0.0741 at epoch: 6
# ----------
# epoch 7/100
# epoch 7 average loss: 0.8719
# ----------
# epoch 8/100
# epoch 8 average loss: 0.8643
# saved new best metric model
# current epoch: 8 current mean dice: 0.0855
# Per-organ Dice scores:
#   - Spleen                : 0.4780
#   - Right Kidney          : 0.2554
#   - Left Kidney           : 0.0011
#   - Gallbladder           : 0.0234
#   - Liver                 : 0.0312
#   - Stomach               : 0.0304
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0136
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.1964
#   - Duodenum              : 0.0039
#   - Bladder               : 0.0782
# best mean dice: 0.0855 at epoch: 8
# ----------
# epoch 9/100
# epoch 9 average loss: 0.8596
# ----------
# epoch 10/100
# epoch 10 average loss: 0.8514
# saved new best metric model
# current epoch: 10 current mean dice: 0.1379
# Per-organ Dice scores:
#   - Spleen                : 0.5016
#   - Right Kidney          : 0.5514
#   - Left Kidney           : 0.0015
#   - Gallbladder           : 0.0402
#   - Liver                 : 0.0427
#   - Stomach               : 0.0301
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0054
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.2564
#   - Duodenum              : 0.0024
#   - Bladder               : 0.3612
# best mean dice: 0.1379 at epoch: 10
# ----------
# epoch 11/100
# epoch 11 average loss: 0.8380
# ----------
# epoch 12/100
# epoch 12 average loss: 0.8262
# saved new best metric model
# current epoch: 12 current mean dice: 0.1570
# Per-organ Dice scores:
#   - Spleen                : 0.4958
#   - Right Kidney          : 0.7291
#   - Left Kidney           : 0.0008
#   - Gallbladder           : 0.0821
#   - Liver                 : 0.0483
#   - Stomach               : 0.0433
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0076
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.2537
#   - Duodenum              : 0.0002
#   - Bladder               : 0.3808
# best mean dice: 0.1570 at epoch: 12
# ----------
# epoch 13/100
# epoch 13 average loss: 0.8122
# ----------
# epoch 14/100
# epoch 14 average loss: 0.8162
# saved new best metric model
# current epoch: 14 current mean dice: 0.1952
# Per-organ Dice scores:
#   - Spleen                : 0.5629
#   - Right Kidney          : 0.7820
#   - Left Kidney           : 0.0005
#   - Gallbladder           : 0.1623
#   - Liver                 : 0.0513
#   - Stomach               : 0.0589
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0175
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3465
#   - Duodenum              : 0.0056
#   - Bladder               : 0.5495
# best mean dice: 0.1952 at epoch: 14
# ----------
# epoch 15/100
# epoch 15 average loss: 0.7996
# ----------
# epoch 16/100
# epoch 16 average loss: 0.7861
# saved new best metric model
# current epoch: 16 current mean dice: 0.2300
# Per-organ Dice scores:
#   - Spleen                : 0.5583
#   - Right Kidney          : 0.8023
#   - Left Kidney           : 0.0012
#   - Gallbladder           : 0.2887
#   - Liver                 : 0.1334
#   - Stomach               : 0.2010
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0150
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3405
#   - Duodenum              : 0.0439
#   - Bladder               : 0.6061
# best mean dice: 0.2300 at epoch: 16
# ----------
# epoch 17/100
# epoch 17 average loss: 0.7869
# ----------
# epoch 18/100
# epoch 18 average loss: 0.7869
# saved new best metric model
# current epoch: 18 current mean dice: 0.2722
# Per-organ Dice scores:
#   - Spleen                : 0.5942
#   - Right Kidney          : 0.8262
#   - Left Kidney           : 0.0110
#   - Gallbladder           : 0.3045
#   - Liver                 : 0.2800
#   - Stomach               : 0.3242
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0294
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3993
#   - Duodenum              : 0.0671
#   - Bladder               : 0.7034
# best mean dice: 0.2722 at epoch: 18
# ----------
# epoch 19/100
# epoch 19 average loss: 0.7719
# ----------
# epoch 20/100
# epoch 20 average loss: 0.7683
# saved new best metric model
# current epoch: 20 current mean dice: 0.3069
# Per-organ Dice scores:
#   - Spleen                : 0.6356
#   - Right Kidney          : 0.8435
#   - Left Kidney           : 0.0610
#   - Gallbladder           : 0.3404
#   - Liver                 : 0.3233
#   - Stomach               : 0.3497
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0738
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4289
#   - Duodenum              : 0.1516
#   - Bladder               : 0.7819
# best mean dice: 0.3069 at epoch: 20
# ----------
# epoch 21/100
# epoch 21 average loss: 0.7435
# ----------
# epoch 22/100
# epoch 22 average loss: 0.7365
# saved new best metric model
# current epoch: 22 current mean dice: 0.3491
# Per-organ Dice scores:
#   - Spleen                : 0.6601
#   - Right Kidney          : 0.8289
#   - Left Kidney           : 0.2048
#   - Gallbladder           : 0.3185
#   - Liver                 : 0.5092
#   - Stomach               : 0.5067
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0862
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3911
#   - Duodenum              : 0.2514
#   - Bladder               : 0.7817
# best mean dice: 0.3491 at epoch: 22
# ----------
# epoch 23/100
# epoch 23 average loss: 0.7337
# ----------
# epoch 24/100
# epoch 24 average loss: 0.7165
# saved new best metric model
# current epoch: 24 current mean dice: 0.4165
# Per-organ Dice scores:
#   - Spleen                : 0.7282
#   - Right Kidney          : 0.8454
#   - Left Kidney           : 0.3595
#   - Gallbladder           : 0.4208
#   - Liver                 : 0.6373
#   - Stomach               : 0.6443
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.1545
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5082
#   - Duodenum              : 0.3400
#   - Bladder               : 0.7769
# best mean dice: 0.4165 at epoch: 24
# ----------
# epoch 25/100
# epoch 25 average loss: 0.7095
# ----------
# epoch 26/100
# epoch 26 average loss: 0.6988
# saved new best metric model
# current epoch: 26 current mean dice: 0.4294
# Per-organ Dice scores:
#   - Spleen                : 0.8229
#   - Right Kidney          : 0.8516
#   - Left Kidney           : 0.4752
#   - Gallbladder           : 0.4485
#   - Liver                 : 0.6255
#   - Stomach               : 0.5815
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.1597
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4942
#   - Duodenum              : 0.3538
#   - Bladder               : 0.7688
# best mean dice: 0.4294 at epoch: 26
# ----------
# epoch 27/100
# epoch 27 average loss: 0.6982
# ----------
# epoch 28/100
# epoch 28 average loss: 0.7091
# saved new best metric model
# current epoch: 28 current mean dice: 0.4482
# Per-organ Dice scores:
#   - Spleen                : 0.8730
#   - Right Kidney          : 0.8337
#   - Left Kidney           : 0.6224
#   - Gallbladder           : 0.3790
#   - Liver                 : 0.7180
#   - Stomach               : 0.5929
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.1732
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4787
#   - Duodenum              : 0.3479
#   - Bladder               : 0.8072
# best mean dice: 0.4482 at epoch: 28
# ----------
# epoch 29/100
# epoch 29 average loss: 0.7116
# ----------
# epoch 30/100
# epoch 30 average loss: 0.6966
# saved new best metric model
# current epoch: 30 current mean dice: 0.4644
# Per-organ Dice scores:
#   - Spleen                : 0.8773
#   - Right Kidney          : 0.8299
#   - Left Kidney           : 0.4724
#   - Gallbladder           : 0.5447
#   - Liver                 : 0.6786
#   - Stomach               : 0.6532
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.2353
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5726
#   - Duodenum              : 0.3963
#   - Bladder               : 0.7771
# best mean dice: 0.4644 at epoch: 30
# ----------
# epoch 31/100
# epoch 31 average loss: 0.6817
# ----------
# epoch 32/100
# epoch 32 average loss: 0.6763
# saved new best metric model
# current epoch: 32 current mean dice: 0.4962
# Per-organ Dice scores:
#   - Spleen                : 0.8997
#   - Right Kidney          : 0.8611
#   - Left Kidney           : 0.6881
#   - Gallbladder           : 0.5012
#   - Liver                 : 0.7072
#   - Stomach               : 0.7021
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.3011
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5768
#   - Duodenum              : 0.4054
#   - Bladder               : 0.8075
# best mean dice: 0.4962 at epoch: 32
# ----------
# epoch 33/100
# epoch 33 average loss: 0.6771
# ----------
# epoch 34/100
# epoch 34 average loss: 0.6611
# saved new best metric model
# current epoch: 34 current mean dice: 0.5150
# Per-organ Dice scores:
#   - Spleen                : 0.8993
#   - Right Kidney          : 0.8550
#   - Left Kidney           : 0.7270
#   - Gallbladder           : 0.5279
#   - Liver                 : 0.8127
#   - Stomach               : 0.7333
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.3792
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5708
#   - Duodenum              : 0.4015
#   - Bladder               : 0.7888
# best mean dice: 0.5150 at epoch: 34
# ----------
# epoch 35/100
# epoch 35 average loss: 0.6462
# ----------
# epoch 36/100
# epoch 36 average loss: 0.6731
# saved new best metric model
# current epoch: 36 current mean dice: 0.5161
# Per-organ Dice scores:
#   - Spleen                : 0.9131
#   - Right Kidney          : 0.8697
#   - Left Kidney           : 0.7307
#   - Gallbladder           : 0.4751
#   - Liver                 : 0.8277
#   - Stomach               : 0.7234
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.3793
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5412
#   - Duodenum              : 0.4333
#   - Bladder               : 0.8164
# best mean dice: 0.5161 at epoch: 36
# ----------
# epoch 37/100
# epoch 37 average loss: 0.6496
# ----------
# epoch 38/100
# epoch 38 average loss: 0.6425
# saved new best metric model
# current epoch: 38 current mean dice: 0.5430
# Per-organ Dice scores:
#   - Spleen                : 0.9020
#   - Right Kidney          : 0.8716
#   - Left Kidney           : 0.7277
#   - Gallbladder           : 0.5953
#   - Liver                 : 0.8440
#   - Stomach               : 0.7490
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.4213
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.6184
#   - Duodenum              : 0.5151
#   - Bladder               : 0.8143
# best mean dice: 0.5430 at epoch: 38
# ----------
# epoch 39/100
# epoch 39 average loss: 0.6487
# ----------
# epoch 40/100
# epoch 40 average loss: 0.6700
# current epoch: 40 current mean dice: 0.5389
# Per-organ Dice scores:
#   - Spleen                : 0.8973
#   - Right Kidney          : 0.8599
#   - Left Kidney           : 0.7190
#   - Gallbladder           : 0.5966
#   - Liver                 : 0.8383
#   - Stomach               : 0.7595
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.3819
#   - Right Adrenal Gland   : 0.0001
#   - Left Adrenal Gland    : 0.6230
#   - Duodenum              : 0.5110
#   - Bladder               : 0.8191
# best mean dice: 0.5430 at epoch: 38
# ----------
# epoch 41/100
# epoch 41 average loss: 0.6661
# ----------
# epoch 42/100
# epoch 42 average loss: 0.6307
# current epoch: 42 current mean dice: 0.5339
# Per-organ Dice scores:
#   - Spleen                : 0.9134
#   - Right Kidney          : 0.8779
#   - Left Kidney           : 0.6646
#   - Gallbladder           : 0.5951
#   - Liver                 : 0.8220
#   - Stomach               : 0.6256
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.4693
#   - Right Adrenal Gland   : 0.0005
#   - Left Adrenal Gland    : 0.6526
#   - Duodenum              : 0.4870
#   - Bladder               : 0.8329
# best mean dice: 0.5430 at epoch: 38
# ----------
# epoch 43/100
# epoch 43 average loss: 0.6194
# ----------
# epoch 44/100
# epoch 44 average loss: 0.6527
# saved new best metric model
# current epoch: 44 current mean dice: 0.5479
# Per-organ Dice scores:
#   - Spleen                : 0.9167
#   - Right Kidney          : 0.8833
#   - Left Kidney           : 0.6878
#   - Gallbladder           : 0.5693
#   - Liver                 : 0.8610
#   - Stomach               : 0.7304
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.4585
#   - Right Adrenal Gland   : 0.0119
#   - Left Adrenal Gland    : 0.6888
#   - Duodenum              : 0.4876
#   - Bladder               : 0.8275
# best mean dice: 0.5479 at epoch: 44
# ----------
# epoch 45/100
# epoch 45 average loss: 0.6397
# ----------
# epoch 46/100
# epoch 46 average loss: 0.6132
# saved new best metric model
# current epoch: 46 current mean dice: 0.5672
# Per-organ Dice scores:
#   - Spleen                : 0.9296
#   - Right Kidney          : 0.8868
#   - Left Kidney           : 0.7373
#   - Gallbladder           : 0.6101
#   - Liver                 : 0.8444
#   - Stomach               : 0.7731
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5436
#   - Right Adrenal Gland   : 0.0423
#   - Left Adrenal Gland    : 0.6841
#   - Duodenum              : 0.5207
#   - Bladder               : 0.8009
# best mean dice: 0.5672 at epoch: 46
# ----------
# epoch 47/100
# epoch 47 average loss: 0.6429
# ----------
# epoch 48/100
# epoch 48 average loss: 0.6196
# saved new best metric model
# current epoch: 48 current mean dice: 0.5754
# Per-organ Dice scores:
#   - Spleen                : 0.9111
#   - Right Kidney          : 0.8727
#   - Left Kidney           : 0.7923
#   - Gallbladder           : 0.6068
#   - Liver                 : 0.8625
#   - Stomach               : 0.7630
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.4956
#   - Right Adrenal Gland   : 0.1558
#   - Left Adrenal Gland    : 0.6883
#   - Duodenum              : 0.5114
#   - Bladder               : 0.8207
# best mean dice: 0.5754 at epoch: 48
# ----------
# epoch 49/100
# epoch 49 average loss: 0.6376
# ----------
# epoch 50/100
# epoch 50 average loss: 0.6525
# saved new best metric model
# current epoch: 50 current mean dice: 0.5797
# Per-organ Dice scores:
#   - Spleen                : 0.9177
#   - Right Kidney          : 0.8222
#   - Left Kidney           : 0.8281
#   - Gallbladder           : 0.6084
#   - Liver                 : 0.8488
#   - Stomach               : 0.7690
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5429
#   - Right Adrenal Gland   : 0.2101
#   - Left Adrenal Gland    : 0.6598
#   - Duodenum              : 0.5151
#   - Bladder               : 0.8139
# best mean dice: 0.5797 at epoch: 50
# ----------
# epoch 51/100
# epoch 51 average loss: 0.6250
# ----------
# epoch 52/100
# epoch 52 average loss: 0.6404
# saved new best metric model
# current epoch: 52 current mean dice: 0.5836
# Per-organ Dice scores:
#   - Spleen                : 0.9165
#   - Right Kidney          : 0.8407
#   - Left Kidney           : 0.7240
#   - Gallbladder           : 0.5757
#   - Liver                 : 0.8614
#   - Stomach               : 0.7627
#   - Aorta                 : 0.0003
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5875
#   - Right Adrenal Gland   : 0.3389
#   - Left Adrenal Gland    : 0.6622
#   - Duodenum              : 0.4982
#   - Bladder               : 0.8188
# best mean dice: 0.5836 at epoch: 52
# ----------
# epoch 53/100
# epoch 53 average loss: 0.6016
# ----------
# epoch 54/100
# epoch 54 average loss: 0.6138
# saved new best metric model
# current epoch: 54 current mean dice: 0.6239
# Per-organ Dice scores:
#   - Spleen                : 0.9341
#   - Right Kidney          : 0.8889
#   - Left Kidney           : 0.8289
#   - Gallbladder           : 0.5966
#   - Liver                 : 0.8533
#   - Stomach               : 0.7745
#   - Aorta                 : 0.0536
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6290
#   - Right Adrenal Gland   : 0.4608
#   - Left Adrenal Gland    : 0.7030
#   - Duodenum              : 0.5604
#   - Bladder               : 0.8276
# best mean dice: 0.6239 at epoch: 54
# ----------
# epoch 55/100
# epoch 55 average loss: 0.6021
# ----------
# epoch 56/100
# epoch 56 average loss: 0.6276
# current epoch: 56 current mean dice: 0.6212
# Per-organ Dice scores:
#   - Spleen                : 0.9118
#   - Right Kidney          : 0.8474
#   - Left Kidney           : 0.7817
#   - Gallbladder           : 0.6064
#   - Liver                 : 0.8513
#   - Stomach               : 0.7566
#   - Aorta                 : 0.3121
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5515
#   - Right Adrenal Gland   : 0.4055
#   - Left Adrenal Gland    : 0.6952
#   - Duodenum              : 0.5468
#   - Bladder               : 0.8091
# best mean dice: 0.6239 at epoch: 54
# ----------
# epoch 57/100
# epoch 57 average loss: 0.5820
# ----------
# epoch 58/100
# epoch 58 average loss: 0.6064
# saved new best metric model
# current epoch: 58 current mean dice: 0.6546
# Per-organ Dice scores:
#   - Spleen                : 0.9198
#   - Right Kidney          : 0.8638
#   - Left Kidney           : 0.7918
#   - Gallbladder           : 0.6238
#   - Liver                 : 0.8690
#   - Stomach               : 0.7955
#   - Aorta                 : 0.3920
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6542
#   - Right Adrenal Gland   : 0.5194
#   - Left Adrenal Gland    : 0.7152
#   - Duodenum              : 0.5574
#   - Bladder               : 0.8080
# best mean dice: 0.6546 at epoch: 58
# ----------
# epoch 59/100
# epoch 59 average loss: 0.5933
# ----------
# epoch 60/100
# epoch 60 average loss: 0.6022
# current epoch: 60 current mean dice: 0.6350
# Per-organ Dice scores:
#   - Spleen                : 0.8924
#   - Right Kidney          : 0.8746
#   - Left Kidney           : 0.7735
#   - Gallbladder           : 0.5982
#   - Liver                 : 0.8753
#   - Stomach               : 0.7582
#   - Aorta                 : 0.4557
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5376
#   - Right Adrenal Gland   : 0.4304
#   - Left Adrenal Gland    : 0.6943
#   - Duodenum              : 0.5257
#   - Bladder               : 0.8389
# best mean dice: 0.6546 at epoch: 58
# ----------
# epoch 61/100
# epoch 61 average loss: 0.6093
# ----------
# epoch 62/100
# epoch 62 average loss: 0.6159
# saved new best metric model
# current epoch: 62 current mean dice: 0.6620
# Per-organ Dice scores:
#   - Spleen                : 0.9288
#   - Right Kidney          : 0.8603
#   - Left Kidney           : 0.8295
#   - Gallbladder           : 0.6264
#   - Liver                 : 0.8889
#   - Stomach               : 0.7970
#   - Aorta                 : 0.4718
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5650
#   - Right Adrenal Gland   : 0.5354
#   - Left Adrenal Gland    : 0.7184
#   - Duodenum              : 0.5485
#   - Bladder               : 0.8362
# best mean dice: 0.6620 at epoch: 62
# ----------
# epoch 63/100
# epoch 63 average loss: 0.5572
# ----------
# epoch 64/100
# epoch 64 average loss: 0.5746
# saved new best metric model
# current epoch: 64 current mean dice: 0.6674
# Per-organ Dice scores:
#   - Spleen                : 0.9358
#   - Right Kidney          : 0.8768
#   - Left Kidney           : 0.8480
#   - Gallbladder           : 0.6032
#   - Liver                 : 0.8836
#   - Stomach               : 0.7897
#   - Aorta                 : 0.4808
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5962
#   - Right Adrenal Gland   : 0.5324
#   - Left Adrenal Gland    : 0.7574
#   - Duodenum              : 0.5275
#   - Bladder               : 0.8450
# best mean dice: 0.6674 at epoch: 64
# ----------
# epoch 65/100
# epoch 65 average loss: 0.5781
# ----------
# epoch 66/100
# epoch 66 average loss: 0.6013
# current epoch: 66 current mean dice: 0.6613
# Per-organ Dice scores:
#   - Spleen                : 0.9214
#   - Right Kidney          : 0.8578
#   - Left Kidney           : 0.7823
#   - Gallbladder           : 0.6004
#   - Liver                 : 0.8748
#   - Stomach               : 0.7892
#   - Aorta                 : 0.5465
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5797
#   - Right Adrenal Gland   : 0.5467
#   - Left Adrenal Gland    : 0.7462
#   - Duodenum              : 0.5054
#   - Bladder               : 0.8463
# best mean dice: 0.6674 at epoch: 64
# ----------
# epoch 67/100
# epoch 67 average loss: 0.5655
# ----------
# epoch 68/100
# epoch 68 average loss: 0.5962
# saved new best metric model
# current epoch: 68 current mean dice: 0.6769
# Per-organ Dice scores:
#   - Spleen                : 0.9418
#   - Right Kidney          : 0.8586
#   - Left Kidney           : 0.8504
#   - Gallbladder           : 0.6261
#   - Liver                 : 0.8611
#   - Stomach               : 0.7868
#   - Aorta                 : 0.5312
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6349
#   - Right Adrenal Gland   : 0.5844
#   - Left Adrenal Gland    : 0.7445
#   - Duodenum              : 0.5631
#   - Bladder               : 0.8163
# best mean dice: 0.6769 at epoch: 68
# ----------
# epoch 69/100
# epoch 69 average loss: 0.5979
# ----------
# epoch 70/100
# epoch 70 average loss: 0.5859
# current epoch: 70 current mean dice: 0.6741
# Per-organ Dice scores:
#   - Spleen                : 0.9290
#   - Right Kidney          : 0.8768
#   - Left Kidney           : 0.8438
#   - Gallbladder           : 0.6481
#   - Liver                 : 0.8839
#   - Stomach               : 0.7790
#   - Aorta                 : 0.5111
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6031
#   - Right Adrenal Gland   : 0.5705
#   - Left Adrenal Gland    : 0.7309
#   - Duodenum              : 0.5466
#   - Bladder               : 0.8406
# best mean dice: 0.6769 at epoch: 68
# ----------
# epoch 71/100
# epoch 71 average loss: 0.5960
# ----------
# epoch 72/100
# epoch 72 average loss: 0.5856
# saved new best metric model
# current epoch: 72 current mean dice: 0.6884
# Per-organ Dice scores:
#   - Spleen                : 0.9311
#   - Right Kidney          : 0.8856
#   - Left Kidney           : 0.8281
#   - Gallbladder           : 0.6634
#   - Liver                 : 0.8874
#   - Stomach               : 0.8019
#   - Aorta                 : 0.5745
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5976
#   - Right Adrenal Gland   : 0.6403
#   - Left Adrenal Gland    : 0.7476
#   - Duodenum              : 0.5499
#   - Bladder               : 0.8418
# best mean dice: 0.6884 at epoch: 72
# ----------
# epoch 73/100
# epoch 73 average loss: 0.5806
# ----------
# epoch 74/100
# epoch 74 average loss: 0.5841
# current epoch: 74 current mean dice: 0.6880
# Per-organ Dice scores:
#   - Spleen                : 0.9424
#   - Right Kidney          : 0.8891
#   - Left Kidney           : 0.8750
#   - Gallbladder           : 0.5855
#   - Liver                 : 0.8832
#   - Stomach               : 0.7934
#   - Aorta                 : 0.5080
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7011
#   - Right Adrenal Gland   : 0.6157
#   - Left Adrenal Gland    : 0.7585
#   - Duodenum              : 0.5613
#   - Bladder               : 0.8302
# best mean dice: 0.6884 at epoch: 72
# ----------
# epoch 75/100
# epoch 75 average loss: 0.5810
# ----------
# epoch 76/100
# epoch 76 average loss: 0.5750
# saved new best metric model
# current epoch: 76 current mean dice: 0.6983
# Per-organ Dice scores:
#   - Spleen                : 0.9384
#   - Right Kidney          : 0.9043
#   - Left Kidney           : 0.8797
#   - Gallbladder           : 0.6373
#   - Liver                 : 0.8789
#   - Stomach               : 0.8042
#   - Aorta                 : 0.5623
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7116
#   - Right Adrenal Gland   : 0.6211
#   - Left Adrenal Gland    : 0.7486
#   - Duodenum              : 0.5477
#   - Bladder               : 0.8435
# best mean dice: 0.6983 at epoch: 76
# ----------
# epoch 77/100
# epoch 77 average loss: 0.5725
# ----------
# epoch 78/100
# epoch 78 average loss: 0.5715
# saved new best metric model
# current epoch: 78 current mean dice: 0.7035
# Per-organ Dice scores:
#   - Spleen                : 0.9417
#   - Right Kidney          : 0.8831
#   - Left Kidney           : 0.8820
#   - Gallbladder           : 0.6691
#   - Liver                 : 0.8898
#   - Stomach               : 0.8118
#   - Aorta                 : 0.5826
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6494
#   - Right Adrenal Gland   : 0.6453
#   - Left Adrenal Gland    : 0.7525
#   - Duodenum              : 0.5911
#   - Bladder               : 0.8474
# best mean dice: 0.7035 at epoch: 78
# ----------
# epoch 79/100
# epoch 79 average loss: 0.5926
# ----------
# epoch 80/100
# epoch 80 average loss: 0.5775
# current epoch: 80 current mean dice: 0.6887
# Per-organ Dice scores:
#   - Spleen                : 0.9375
#   - Right Kidney          : 0.8405
#   - Left Kidney           : 0.8237
#   - Gallbladder           : 0.6605
#   - Liver                 : 0.8903
#   - Stomach               : 0.8019
#   - Aorta                 : 0.5510
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6821
#   - Right Adrenal Gland   : 0.6519
#   - Left Adrenal Gland    : 0.7409
#   - Duodenum              : 0.5573
#   - Bladder               : 0.8150
# best mean dice: 0.7035 at epoch: 78
# ----------
# epoch 81/100
# epoch 81 average loss: 0.5604
# ----------
# epoch 82/100
# epoch 82 average loss: 0.5475
# current epoch: 82 current mean dice: 0.7033
# Per-organ Dice scores:
#   - Spleen                : 0.9438
#   - Right Kidney          : 0.8937
#   - Left Kidney           : 0.8791
#   - Gallbladder           : 0.6512
#   - Liver                 : 0.9004
#   - Stomach               : 0.7874
#   - Aorta                 : 0.5779
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6583
#   - Right Adrenal Gland   : 0.6504
#   - Left Adrenal Gland    : 0.7769
#   - Duodenum              : 0.5672
#   - Bladder               : 0.8570
# best mean dice: 0.7035 at epoch: 78
# ----------
# epoch 83/100
# epoch 83 average loss: 0.5461
# ----------
# epoch 84/100
# epoch 84 average loss: 0.5571
# saved new best metric model
# current epoch: 84 current mean dice: 0.7082
# Per-organ Dice scores:
#   - Spleen                : 0.9440
#   - Right Kidney          : 0.8951
#   - Left Kidney           : 0.8707
#   - Gallbladder           : 0.6701
#   - Liver                 : 0.8955
#   - Stomach               : 0.8045
#   - Aorta                 : 0.5874
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6677
#   - Right Adrenal Gland   : 0.6729
#   - Left Adrenal Gland    : 0.7830
#   - Duodenum              : 0.5569
#   - Bladder               : 0.8581
# best mean dice: 0.7082 at epoch: 84
# ----------
# epoch 85/100
# epoch 85 average loss: 0.5584
# ----------
# epoch 86/100
# epoch 86 average loss: 0.5844
# current epoch: 86 current mean dice: 0.6978
# Per-organ Dice scores:
#   - Spleen                : 0.9446
#   - Right Kidney          : 0.8802
#   - Left Kidney           : 0.8883
#   - Gallbladder           : 0.6494
#   - Liver                 : 0.8948
#   - Stomach               : 0.7820
#   - Aorta                 : 0.5254
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6832
#   - Right Adrenal Gland   : 0.6461
#   - Left Adrenal Gland    : 0.7769
#   - Duodenum              : 0.5698
#   - Bladder               : 0.8302
# best mean dice: 0.7082 at epoch: 84
# ----------
# epoch 87/100
# epoch 87 average loss: 0.5583
# ----------
# epoch 88/100
# epoch 88 average loss: 0.5623
# current epoch: 88 current mean dice: 0.7076
# Per-organ Dice scores:
#   - Spleen                : 0.9409
#   - Right Kidney          : 0.8830
#   - Left Kidney           : 0.8634
#   - Gallbladder           : 0.6829
#   - Liver                 : 0.8988
#   - Stomach               : 0.8181
#   - Aorta                 : 0.5830
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6665
#   - Right Adrenal Gland   : 0.6619
#   - Left Adrenal Gland    : 0.7694
#   - Duodenum              : 0.5913
#   - Bladder               : 0.8400
# best mean dice: 0.7082 at epoch: 84
# ----------
# epoch 89/100
# epoch 89 average loss: 0.5753
# ----------
# epoch 90/100
# epoch 90 average loss: 0.5616
# current epoch: 90 current mean dice: 0.7062
# Per-organ Dice scores:
#   - Spleen                : 0.9464
#   - Right Kidney          : 0.8702
#   - Left Kidney           : 0.9017
#   - Gallbladder           : 0.6682
#   - Liver                 : 0.8864
#   - Stomach               : 0.8225
#   - Aorta                 : 0.5894
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6769
#   - Right Adrenal Gland   : 0.6175
#   - Left Adrenal Gland    : 0.7635
#   - Duodenum              : 0.5782
#   - Bladder               : 0.8601
# best mean dice: 0.7082 at epoch: 84
# ----------
# epoch 91/100
# epoch 91 average loss: 0.5534
# ----------
# epoch 92/100
# epoch 92 average loss: 0.5829
# current epoch: 92 current mean dice: 0.7061
# Per-organ Dice scores:
#   - Spleen                : 0.9387
#   - Right Kidney          : 0.8955
#   - Left Kidney           : 0.8731
#   - Gallbladder           : 0.6670
#   - Liver                 : 0.8982
#   - Stomach               : 0.8248
#   - Aorta                 : 0.5926
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6836
#   - Right Adrenal Gland   : 0.6178
#   - Left Adrenal Gland    : 0.7720
#   - Duodenum              : 0.5643
#   - Bladder               : 0.8516
# best mean dice: 0.7082 at epoch: 84
# ----------
# epoch 93/100
# epoch 93 average loss: 0.5648
# ----------
# epoch 94/100
# epoch 94 average loss: 0.5545
# saved new best metric model
# current epoch: 94 current mean dice: 0.7120
# Per-organ Dice scores:
#   - Spleen                : 0.9488
#   - Right Kidney          : 0.8964
#   - Left Kidney           : 0.9127
#   - Gallbladder           : 0.6299
#   - Liver                 : 0.8938
#   - Stomach               : 0.7906
#   - Aorta                 : 0.6032
#   - Inferior Vena Cava    : 0.0005
#   - Pancreas              : 0.6896
#   - Right Adrenal Gland   : 0.6688
#   - Left Adrenal Gland    : 0.7831
#   - Duodenum              : 0.5817
#   - Bladder               : 0.8565
# best mean dice: 0.7120 at epoch: 94
# ----------
# epoch 95/100
# epoch 95 average loss: 0.5359
# ----------
# epoch 96/100
# epoch 96 average loss: 0.5795
# saved new best metric model
# current epoch: 96 current mean dice: 0.7152
# Per-organ Dice scores:
#   - Spleen                : 0.9524
#   - Right Kidney          : 0.8923
#   - Left Kidney           : 0.8867
#   - Gallbladder           : 0.6873
#   - Liver                 : 0.8918
#   - Stomach               : 0.8105
#   - Aorta                 : 0.6044
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7356
#   - Right Adrenal Gland   : 0.6382
#   - Left Adrenal Gland    : 0.7730
#   - Duodenum              : 0.5775
#   - Bladder               : 0.8480
# best mean dice: 0.7152 at epoch: 96
# ----------
# epoch 97/100
# epoch 97 average loss: 0.5478
# ----------
# epoch 98/100
# epoch 98 average loss: 0.5660
# current epoch: 98 current mean dice: 0.7116
# Per-organ Dice scores:
#   - Spleen                : 0.9392
#   - Right Kidney          : 0.8916
#   - Left Kidney           : 0.8653
#   - Gallbladder           : 0.6719
#   - Liver                 : 0.9034
#   - Stomach               : 0.8074
#   - Aorta                 : 0.6300
#   - Inferior Vena Cava    : 0.0486
#   - Pancreas              : 0.7062
#   - Right Adrenal Gland   : 0.6149
#   - Left Adrenal Gland    : 0.7716
#   - Duodenum              : 0.5541
#   - Bladder               : 0.8468
# best mean dice: 0.7152 at epoch: 96
# ----------
# epoch 99/100
# epoch 99 average loss: 0.5714
# ----------
# epoch 100/100
# epoch 100 average loss: 0.5343
# saved new best metric model
# current epoch: 100 current mean dice: 0.7302
# Per-organ Dice scores:
#   - Spleen                : 0.9438
#   - Right Kidney          : 0.8890
#   - Left Kidney           : 0.8829
#   - Gallbladder           : 0.6677
#   - Liver                 : 0.8963
#   - Stomach               : 0.8080
#   - Aorta                 : 0.6084
#   - Inferior Vena Cava    : 0.2621
#   - Pancreas              : 0.6709
#   - Right Adrenal Gland   : 0.6645
#   - Left Adrenal Gland    : 0.7965
#   - Duodenum              : 0.5912
#   - Bladder               : 0.8119
# best mean dice: 0.7302 at epoch: 100
#
# ✅ Training complete. Best mean dice: 0.7302 at epoch 100
#
# ▶️ Step 7: Evaluating and Visualizing Results...
# ------------------------------
# 📊 Best Performing Case: FLARE22_Tr_0042_0000.nii
# Mean Dice: 0.8248
# Per-Organ Dice Scores:
#   - Spleen                : 0.9614
#   - Right Kidney          : 0.9427
#   - Left Kidney           : 0.9515
#   - Gallbladder           : 0.8440
#   - Liver                 : 0.9347
#   - Stomach               : 0.8560
#   - Aorta                 : 0.7139
#   - Inferior Vena Cava    : 0.4492
#   - Pancreas              : 0.7826
#   - Right Adrenal Gland   : 0.6923
#   - Left Adrenal Gland    : 0.8678
#   - Duodenum              : 0.7720
#   - Bladder               : 0.9542
# ------------------------------
# 📊 Worst Performing Case: FLARE22_Tr_0047_0000.nii
# Mean Dice: 0.6234
# Per-Organ Dice Scores:
#   - Spleen                : 0.9195
#   - Right Kidney          : 0.9042
#   - Left Kidney           : 0.8435
#   - Gallbladder           : 0.6651
#   - Liver                 : 0.8867
#   - Stomach               : 0.6377
#   - Aorta                 : 0.2385
#   - Inferior Vena Cava    : 0.0392
#   - Pancreas              : 0.5063
#   - Right Adrenal Gland   : 0.2846
#   - Left Adrenal Gland    : 0.7034
#   - Duodenum              : 0.5925
#   - Bladder               : 0.8828
# ✅ Pipeline complete!
