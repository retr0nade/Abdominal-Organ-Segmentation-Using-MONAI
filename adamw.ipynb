# %%
# ==============================================================================
# KAGGLE PIPELINE: EXPERIMENT 5 - ADDING AdamW + Weight Decay
# ==============================================================================

print("▶️ Step 1: Installing MONAI...")
# !pip install -q "monai[nibabel, tqdm]"
print("✅ Installation complete.")

print("\n▶️ Step 2: Importing libraries and setting up...")
import os
import shutil
import time
from glob import glob

import torch
import monai
import numpy as np
from monai.config import print_config
from monai.data import DataLoader, Dataset, decollate_batch
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.metrics import DiceMetric
from monai.networks.nets import UNet
from monai.transforms import (
    Activations,
    AsDiscrete,
    Compose,
    EnsureChannelFirstd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    RandRotate90d,
    RandGaussianNoised,
    ScaleIntensityRanged,
    Spacingd,
    SpatialPadD,
    EnsureTyped,
)
import matplotlib.pyplot as plt

print_config()
print("✅ Setup complete.")

# ==============================================================================
# 2. PREPARE DATASET (WITH DATA INTEGRITY CHECK)
# ==============================================================================
print("\n▶️ Step 3: Preparing Data...")
try:
    output_dir = "/kaggle/working/"
    os.makedirs(output_dir, exist_ok=True)
    print(f"Model checkpoints will be saved to: {output_dir}")

    drive_data_path = "/kaggle/input/flare22train/FLARE22Train"
    images_path = os.path.join(drive_data_path, "images")
    labels_path = os.path.join(drive_data_path, "labels")

    all_images = sorted(glob(os.path.join(images_path, "*.nii")))
    all_labels = sorted(glob(os.path.join(labels_path, "*.nii")))

    print("Verifying data integrity...")
    data_dicts = []
    for img_path, lbl_path in zip(all_images, all_labels):
        if os.path.exists(img_path) and os.path.exists(lbl_path) and os.path.getsize(img_path) > 0 and os.path.getsize(lbl_path) > 0:
            data_dicts.append({"image": img_path, "label": lbl_path})
        else:
            print(f"WARNING: Skipping corrupted or empty file pair: {os.path.basename(img_path)} and {os.path.basename(lbl_path)}")

    if len(data_dicts) == 0:
        raise FileNotFoundError(f"No valid, non-empty image/label pairs found.")

    num_total = len(data_dicts)
    num_train = int(num_total * 0.8)
    train_files, val_files = data_dicts[:num_train], data_dicts[num_train:]
    
    print(f"✅ Data prepared: Found {len(data_dicts)} valid pairs.")
    print(f"   --> {len(train_files)} training files, {len(val_files)} validation files.")
except Exception as e:
    print(f"❌ FATAL ERROR in Data Preparation: {e}")
    raise e

# ==============================================================================
# 3. DEFINE TRANSFORMS, DATASET, AND DATALOADER
# ==============================================================================
print("\n▶️ Step 4: Defining MONAI transforms and dataloaders...")
roi_size = (96, 96, 96)
train_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-175, a_max=250, b_min=0.0, b_max=1.0, clip=True),
    SpatialPadD(keys=["image", "label"], spatial_size=roi_size, method="end"),
    RandCropByPosNegLabeld(
        keys=["image", "label"], label_key="label", spatial_size=roi_size,
        pos=1, neg=1, num_samples=4, image_key="image", image_threshold=0,
    ),
    RandRotate90d(keys=["image", "label"], prob=0.10, max_k=3),
    RandGaussianNoised(keys="image", prob=0.10, mean=0.0, std=0.1),
    EnsureTyped(keys=["image", "label"]),
])
val_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-175, a_max=250, b_min=0.0, b_max=1.0, clip=True),
    EnsureTyped(keys=["image", "label"]),
])

train_ds = Dataset(data=train_files, transform=train_transforms)
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=2)
val_ds = Dataset(data=val_files, transform=val_transforms)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=2)
print("✅ Dataloaders ready.")


# ==============================================================================
# 4. SET UP MODEL, LOSS, AND OPTIMIZER
# ==============================================================================
print("\n▶️ Step 5: Setting up Model, Loss, and Optimizer...")
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = UNet(
    spatial_dims=3, in_channels=1, out_channels=14,
    channels=(16, 32, 64, 128, 256), strides=(2, 2, 2, 2),
    num_res_units=2,
).to(device)

loss_function = DiceLoss(to_onehot_y=True, softmax=True)

# --- THIS IS THE ONLY CHANGE FOR EXPERIMENT 5 ---
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-5)

dice_metric = DiceMetric(include_background=False, reduction="mean_batch")
organ_names = [
    "Spleen", "Right Kidney", "Left Kidney", "Gallbladder", "Liver", "Stomach",
    "Aorta", "Inferior Vena Cava", "Pancreas", "Right Adrenal Gland",
    "Left Adrenal Gland", "Duodenum", "Bladder"
]
print("✅ Model setup complete.")


# ==============================================================================
# 5. TRAINING LOOP
# ==============================================================================
print("\n▶️ Step 6: Starting Training...")
max_epochs = 100
val_interval = 2
best_metric = -1
best_metric_epoch = -1
post_pred = Compose([Activations(softmax=True), AsDiscrete(argmax=True, to_onehot=14)])
post_label = Compose([AsDiscrete(to_onehot=14)])

for epoch in range(max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    if len(train_loader) == 0: break
    for batch_data in train_loader:
        step += 1
        inputs, labels = (batch_data["image"].to(device), batch_data["label"].to(device))
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print(f"{step*train_loader.batch_size}/{len(train_ds)}, train_loss: {loss.item():.4f}", end="\r")

    epoch_loss /= step
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0 and len(val_loader) > 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (val_data["image"].to(device), val_data["label"].to(device))
                val_outputs = sliding_window_inference(val_inputs, roi_size, 4, model)
                val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                dice_metric(y_pred=val_outputs, y=val_labels)

            metric_batch = dice_metric.aggregate()
            metric = metric_batch.mean().item()
            dice_metric.reset()

            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(output_dir, "best_metric_model.pth"))
                print("saved new best metric model")
            print(f"current epoch: {epoch + 1} current mean dice: {metric:.4f}")
            print("Per-organ Dice scores:")
            for i, name in enumerate(organ_names):
                print(f"  - {name:<22}: {metric_batch[i].item():.4f}")
            print(f"best mean dice: {best_metric:.4f} at epoch: {best_metric_epoch}")

print(f"\n✅ Training complete. Best mean dice: {best_metric:.4f} at epoch {best_metric_epoch}")


# ==============================================================================
# 6. ENHANCED VISUALIZATION
# ==============================================================================
print("\n▶️ Step 7: Evaluating and Visualizing Results...")
best_model_path = os.path.join(output_dir, "best_metric_model.pth")

if os.path.exists(best_model_path):
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()

    validation_mean_scores = {}
    validation_organ_scores = {}

    with torch.no_grad():
        for i, val_data in enumerate(val_loader):
            val_inputs = val_data["image"].to(device)
            val_labels = val_data["label"].to(device)
            val_outputs = sliding_window_inference(val_inputs, roi_size, 4, model)
            val_outputs_post = [post_pred(i) for i in decollate_batch(val_outputs)]
            val_labels_post = [post_label(i) for i in decollate_batch(val_labels)]
            dice_metric(y_pred=val_outputs_post, y=val_labels_post)
            organ_scores = dice_metric.aggregate()
            mean_score = organ_scores.mean().item()
            dice_metric.reset()
            case_name = os.path.basename(val_files[i]['image'])
            validation_mean_scores[case_name] = mean_score
            validation_organ_scores[case_name] = organ_scores.cpu().numpy()

    sorted_scores = sorted(validation_mean_scores.items(), key=lambda item: item[1])
    best_case_name, best_score = sorted_scores[-1]
    worst_case_name, worst_score = sorted_scores[0]

    def plot_and_report_case(case_dict, title, mean_dice, organ_dice):
        case_name = os.path.basename(case_dict['image'])
        print("-" * 30)
        print(f"📊 {title}: {case_name}")
        print(f"Mean Dice: {mean_dice:.4f}")
        print("Per-Organ Dice Scores:")
        for i, name in enumerate(organ_names):
            print(f"  - {name:<22}: {organ_dice[i]:.4f}")

        with torch.no_grad():
            transformed_data = val_transforms(case_dict)
            val_input = transformed_data['image'].unsqueeze(0).to(device)
            val_output = sliding_window_inference(val_input, roi_size, 4, model)
            val_output_processed = torch.argmax(val_output, dim=1).detach().cpu().numpy()[0, :, :, :]
            
            ground_truth = transformed_data['label'][0, :, :, :].numpy()
            original_image = transformed_data['image'][0, :, :, :].numpy()
            slice_idx = np.argmax(np.sum(ground_truth, axis=(0, 1)))

            fig, axes = plt.subplots(1, 3, figsize=(18, 6))
            fig.suptitle(f"{title}\n{case_name}\nMean Dice: {mean_dice:.4f}", fontsize=16)
            axes[0].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[0].set_title("Original Image"); axes[0].axis('off')
            axes[1].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[1].imshow(np.rot90(ground_truth[:, :, slice_idx]), cmap="jet", alpha=0.6); axes[1].set_title("Ground Truth"); axes[1].axis('off')
            axes[2].imshow(np.rot90(original_image[:, :, slice_idx]), cmap="bone"); axes[2].imshow(np.rot90(val_output_processed[:, :, slice_idx]), cmap="jet", alpha=0.6); axes[2].set_title("MONAI Prediction"); axes[2].axis('off')
            plt.show()

    best_case_dict = next(item for item in val_files if best_case_name in item["image"])
    worst_case_dict = next(item for item in val_files if worst_case_name in item["image"])
    
    best_organ_scores = validation_organ_scores[best_case_name]
    worst_organ_scores = validation_organ_scores[worst_case_name]

    plot_and_report_case(best_case_dict, "Best Performing Case", best_score, best_organ_scores)
    plot_and_report_case(worst_case_dict, "Worst Performing Case", worst_score, worst_organ_scores)
else:
    print("Evaluation skipped because no model was saved.")

print("\n✅ Pipeline complete!")
# Out:
# ▶️ Step 1: Installing MONAI...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 83.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 30.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 4.9 MB/s eta 0:00:00
# ✅ Installation complete.
#
# ▶️ Step 2: Importing libraries and setting up...
# <frozen importlib._bootstrap_external>:1241: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# 2025-08-12 05:50:07.193662: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754977807.348515      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754977807.392368      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# MONAI version: 1.5.0
# Numpy version: 1.26.4
# Pytorch version: 2.6.0+cu124
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: d388d1c6fec8cb3a0eebee5b5a0b9776ca59ca83
# MONAI __file__: /usr/local/lib/python3.11/dist-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.5.2
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 5.3.2
# scikit-image version: 0.25.2
# scipy version: 1.15.3
# Pillow version: 11.2.1
# Tensorboard version: 2.18.0
# gdown version: 5.2.0
# TorchVision version: 0.21.0+cu124
# tqdm version: 4.67.1
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 7.0.0
# pandas version: 2.2.3
# einops version: 0.8.1
# transformers version: 4.52.4
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies
#
# ✅ Setup complete.
#
# ▶️ Step 3: Preparing Data...
# Model checkpoints will be saved to: /kaggle/working/
# Verifying data integrity...
# ✅ Data prepared: Found 50 valid pairs.
#    --> 40 training files, 10 validation files.
#
# ▶️ Step 4: Defining MONAI transforms and dataloaders...
# ✅ Dataloaders ready.
#
# ▶️ Step 5: Setting up Model, Loss, and Optimizer...
# ✅ Model setup complete.
#
# ▶️ Step 6: Starting Training...
# ----------
# epoch 1/100
# epoch 1 average loss: 0.9681
# ----------
# epoch 2/100
# epoch 2 average loss: 0.9497
# saved new best metric model
# current epoch: 2 current mean dice: 0.0342
# Per-organ Dice scores:
#   - Spleen                : 0.2897
#   - Right Kidney          : 0.0419
#   - Left Kidney           : 0.0459
#   - Gallbladder           : 0.0058
#   - Liver                 : 0.0007
#   - Stomach               : 0.0088
#   - Aorta                 : 0.0002
#   - Inferior Vena Cava    : 0.0001
#   - Pancreas              : 0.0015
#   - Right Adrenal Gland   : 0.0016
#   - Left Adrenal Gland    : 0.0121
#   - Duodenum              : 0.0087
#   - Bladder               : 0.0277
# best mean dice: 0.0342 at epoch: 2
# ----------
# epoch 3/100
# epoch 3 average loss: 0.9327
# ----------
# epoch 4/100
# epoch 4 average loss: 0.9193
# saved new best metric model
# current epoch: 4 current mean dice: 0.0432
# Per-organ Dice scores:
#   - Spleen                : 0.3922
#   - Right Kidney          : 0.0660
#   - Left Kidney           : 0.0125
#   - Gallbladder           : 0.0192
#   - Liver                 : 0.0046
#   - Stomach               : 0.0052
#   - Aorta                 : 0.0004
#   - Inferior Vena Cava    : 0.0001
#   - Pancreas              : 0.0002
#   - Right Adrenal Gland   : 0.0037
#   - Left Adrenal Gland    : 0.0074
#   - Duodenum              : 0.0181
#   - Bladder               : 0.0319
# best mean dice: 0.0432 at epoch: 4
# ----------
# epoch 5/100
# epoch 5 average loss: 0.9105
# ----------
# epoch 6/100
# epoch 6 average loss: 0.8970
# saved new best metric model
# current epoch: 6 current mean dice: 0.0566
# Per-organ Dice scores:
#   - Spleen                : 0.4611
#   - Right Kidney          : 0.0776
#   - Left Kidney           : 0.0191
#   - Gallbladder           : 0.0319
#   - Liver                 : 0.0292
#   - Stomach               : 0.0026
#   - Aorta                 : 0.0003
#   - Inferior Vena Cava    : 0.0001
#   - Pancreas              : 0.0022
#   - Right Adrenal Gland   : 0.0018
#   - Left Adrenal Gland    : 0.0307
#   - Duodenum              : 0.0212
#   - Bladder               : 0.0576
# best mean dice: 0.0566 at epoch: 6
# ----------
# epoch 7/100
# epoch 7 average loss: 0.8918
# ----------
# epoch 8/100
# epoch 8 average loss: 0.8801
# saved new best metric model
# current epoch: 8 current mean dice: 0.0760
# Per-organ Dice scores:
#   - Spleen                : 0.5317
#   - Right Kidney          : 0.0874
#   - Left Kidney           : 0.0589
#   - Gallbladder           : 0.0445
#   - Liver                 : 0.0261
#   - Stomach               : 0.0026
#   - Aorta                 : 0.0003
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0182
#   - Right Adrenal Gland   : 0.0001
#   - Left Adrenal Gland    : 0.0894
#   - Duodenum              : 0.0447
#   - Bladder               : 0.0834
# best mean dice: 0.0760 at epoch: 8
# ----------
# epoch 9/100
# epoch 9 average loss: 0.8736
# ----------
# epoch 10/100
# epoch 10 average loss: 0.8632
# saved new best metric model
# current epoch: 10 current mean dice: 0.1069
# Per-organ Dice scores:
#   - Spleen                : 0.5661
#   - Right Kidney          : 0.1156
#   - Left Kidney           : 0.1580
#   - Gallbladder           : 0.0698
#   - Liver                 : 0.0420
#   - Stomach               : 0.0059
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0265
#   - Right Adrenal Gland   : 0.0002
#   - Left Adrenal Gland    : 0.1801
#   - Duodenum              : 0.0867
#   - Bladder               : 0.1389
# best mean dice: 0.1069 at epoch: 10
# ----------
# epoch 11/100
# epoch 11 average loss: 0.8490
# ----------
# epoch 12/100
# epoch 12 average loss: 0.8399
# saved new best metric model
# current epoch: 12 current mean dice: 0.1520
# Per-organ Dice scores:
#   - Spleen                : 0.6353
#   - Right Kidney          : 0.2263
#   - Left Kidney           : 0.2542
#   - Gallbladder           : 0.1195
#   - Liver                 : 0.0488
#   - Stomach               : 0.0047
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.0512
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.2537
#   - Duodenum              : 0.1469
#   - Bladder               : 0.2349
# best mean dice: 0.1520 at epoch: 12
# ----------
# epoch 13/100
# epoch 13 average loss: 0.8326
# ----------
# epoch 14/100
# epoch 14 average loss: 0.8158
# saved new best metric model
# current epoch: 14 current mean dice: 0.2114
# Per-organ Dice scores:
#   - Spleen                : 0.6239
#   - Right Kidney          : 0.4061
#   - Left Kidney           : 0.4403
#   - Gallbladder           : 0.1320
#   - Liver                 : 0.0624
#   - Stomach               : 0.0084
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.1607
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3445
#   - Duodenum              : 0.1361
#   - Bladder               : 0.4336
# best mean dice: 0.2114 at epoch: 14
# ----------
# epoch 15/100
# epoch 15 average loss: 0.8014
# ----------
# epoch 16/100
# epoch 16 average loss: 0.7884
# saved new best metric model
# current epoch: 16 current mean dice: 0.2405
# Per-organ Dice scores:
#   - Spleen                : 0.6183
#   - Right Kidney          : 0.4629
#   - Left Kidney           : 0.4312
#   - Gallbladder           : 0.1618
#   - Liver                 : 0.1058
#   - Stomach               : 0.0191
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.2764
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3824
#   - Duodenum              : 0.1590
#   - Bladder               : 0.5097
# best mean dice: 0.2405 at epoch: 16
# ----------
# epoch 17/100
# epoch 17 average loss: 0.7761
# ----------
# epoch 18/100
# epoch 18 average loss: 0.7657
# saved new best metric model
# current epoch: 18 current mean dice: 0.2899
# Per-organ Dice scores:
#   - Spleen                : 0.7062
#   - Right Kidney          : 0.6570
#   - Left Kidney           : 0.4833
#   - Gallbladder           : 0.2005
#   - Liver                 : 0.1679
#   - Stomach               : 0.1054
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.3167
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3343
#   - Duodenum              : 0.1844
#   - Bladder               : 0.6125
# best mean dice: 0.2899 at epoch: 18
# ----------
# epoch 19/100
# epoch 19 average loss: 0.7632
# ----------
# epoch 20/100
# epoch 20 average loss: 0.7389
# saved new best metric model
# current epoch: 20 current mean dice: 0.3303
# Per-organ Dice scores:
#   - Spleen                : 0.7418
#   - Right Kidney          : 0.6913
#   - Left Kidney           : 0.5557
#   - Gallbladder           : 0.2266
#   - Liver                 : 0.3432
#   - Stomach               : 0.2291
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.3453
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3740
#   - Duodenum              : 0.1690
#   - Bladder               : 0.6176
# best mean dice: 0.3303 at epoch: 20
# ----------
# epoch 21/100
# epoch 21 average loss: 0.7375
# ----------
# epoch 22/100
# epoch 22 average loss: 0.7242
# saved new best metric model
# current epoch: 22 current mean dice: 0.3610
# Per-organ Dice scores:
#   - Spleen                : 0.7685
#   - Right Kidney          : 0.7121
#   - Left Kidney           : 0.5637
#   - Gallbladder           : 0.2083
#   - Liver                 : 0.4005
#   - Stomach               : 0.3123
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.4814
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.3748
#   - Duodenum              : 0.2014
#   - Bladder               : 0.6696
# best mean dice: 0.3610 at epoch: 22
# ----------
# epoch 23/100
# epoch 23 average loss: 0.7260
# ----------
# epoch 24/100
# epoch 24 average loss: 0.7102
# saved new best metric model
# current epoch: 24 current mean dice: 0.3983
# Per-organ Dice scores:
#   - Spleen                : 0.8232
#   - Right Kidney          : 0.6950
#   - Left Kidney           : 0.6112
#   - Gallbladder           : 0.3144
#   - Liver                 : 0.4042
#   - Stomach               : 0.3693
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5336
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5039
#   - Duodenum              : 0.2588
#   - Bladder               : 0.6636
# best mean dice: 0.3983 at epoch: 24
# ----------
# epoch 25/100
# epoch 25 average loss: 0.7185
# ----------
# epoch 26/100
# epoch 26 average loss: 0.7102
# saved new best metric model
# current epoch: 26 current mean dice: 0.4423
# Per-organ Dice scores:
#   - Spleen                : 0.8109
#   - Right Kidney          : 0.7326
#   - Left Kidney           : 0.6796
#   - Gallbladder           : 0.3939
#   - Liver                 : 0.6271
#   - Stomach               : 0.4694
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5068
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4940
#   - Duodenum              : 0.3761
#   - Bladder               : 0.6594
# best mean dice: 0.4423 at epoch: 26
# ----------
# epoch 27/100
# epoch 27 average loss: 0.6699
# ----------
# epoch 28/100
# epoch 28 average loss: 0.6966
# current epoch: 28 current mean dice: 0.4421
# Per-organ Dice scores:
#   - Spleen                : 0.8107
#   - Right Kidney          : 0.7987
#   - Left Kidney           : 0.6637
#   - Gallbladder           : 0.3610
#   - Liver                 : 0.6210
#   - Stomach               : 0.5056
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.4183
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.4993
#   - Duodenum              : 0.3551
#   - Bladder               : 0.7133
# best mean dice: 0.4423 at epoch: 26
# ----------
# epoch 29/100
# epoch 29 average loss: 0.6751
# ----------
# epoch 30/100
# epoch 30 average loss: 0.6764
# saved new best metric model
# current epoch: 30 current mean dice: 0.4658
# Per-organ Dice scores:
#   - Spleen                : 0.8250
#   - Right Kidney          : 0.7909
#   - Left Kidney           : 0.5912
#   - Gallbladder           : 0.5175
#   - Liver                 : 0.5698
#   - Stomach               : 0.4964
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6601
#   - Right Adrenal Gland   : 0.0000
#   - Left Adrenal Gland    : 0.5408
#   - Duodenum              : 0.3926
#   - Bladder               : 0.6709
# best mean dice: 0.4658 at epoch: 30
# ----------
# epoch 31/100
# epoch 31 average loss: 0.6750
# ----------
# epoch 32/100
# epoch 32 average loss: 0.6588
# current epoch: 32 current mean dice: 0.4561
# Per-organ Dice scores:
#   - Spleen                : 0.8180
#   - Right Kidney          : 0.8057
#   - Left Kidney           : 0.6322
#   - Gallbladder           : 0.4519
#   - Liver                 : 0.5970
#   - Stomach               : 0.4581
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.5275
#   - Right Adrenal Gland   : 0.0003
#   - Left Adrenal Gland    : 0.5167
#   - Duodenum              : 0.3994
#   - Bladder               : 0.7230
# best mean dice: 0.4658 at epoch: 30
# ----------
# epoch 33/100
# epoch 33 average loss: 0.6630
# ----------
# epoch 34/100
# epoch 34 average loss: 0.6730
# saved new best metric model
# current epoch: 34 current mean dice: 0.4949
# Per-organ Dice scores:
#   - Spleen                : 0.8709
#   - Right Kidney          : 0.7938
#   - Left Kidney           : 0.6796
#   - Gallbladder           : 0.4880
#   - Liver                 : 0.7401
#   - Stomach               : 0.5549
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6278
#   - Right Adrenal Gland   : 0.0036
#   - Left Adrenal Gland    : 0.5327
#   - Duodenum              : 0.4240
#   - Bladder               : 0.7189
# best mean dice: 0.4949 at epoch: 34
# ----------
# epoch 35/100
# epoch 35 average loss: 0.6743
# ----------
# epoch 36/100
# epoch 36 average loss: 0.6425
# current epoch: 36 current mean dice: 0.4920
# Per-organ Dice scores:
#   - Spleen                : 0.8668
#   - Right Kidney          : 0.8028
#   - Left Kidney           : 0.6287
#   - Gallbladder           : 0.5315
#   - Liver                 : 0.6856
#   - Stomach               : 0.4794
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6585
#   - Right Adrenal Gland   : 0.0113
#   - Left Adrenal Gland    : 0.5837
#   - Duodenum              : 0.4172
#   - Bladder               : 0.7306
# best mean dice: 0.4949 at epoch: 34
# ----------
# epoch 37/100
# epoch 37 average loss: 0.6482
# ----------
# epoch 38/100
# epoch 38 average loss: 0.6459
# saved new best metric model
# current epoch: 38 current mean dice: 0.5156
# Per-organ Dice scores:
#   - Spleen                : 0.8655
#   - Right Kidney          : 0.8094
#   - Left Kidney           : 0.6287
#   - Gallbladder           : 0.5573
#   - Liver                 : 0.7328
#   - Stomach               : 0.5262
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6919
#   - Right Adrenal Gland   : 0.1177
#   - Left Adrenal Gland    : 0.5820
#   - Duodenum              : 0.4824
#   - Bladder               : 0.7083
# best mean dice: 0.5156 at epoch: 38
# ----------
# epoch 39/100
# epoch 39 average loss: 0.6292
# ----------
# epoch 40/100
# epoch 40 average loss: 0.6519
# saved new best metric model
# current epoch: 40 current mean dice: 0.5340
# Per-organ Dice scores:
#   - Spleen                : 0.8843
#   - Right Kidney          : 0.7988
#   - Left Kidney           : 0.6089
#   - Gallbladder           : 0.5474
#   - Liver                 : 0.8005
#   - Stomach               : 0.6583
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6690
#   - Right Adrenal Gland   : 0.1874
#   - Left Adrenal Gland    : 0.5403
#   - Duodenum              : 0.4956
#   - Bladder               : 0.7522
# best mean dice: 0.5340 at epoch: 40
# ----------
# epoch 41/100
# epoch 41 average loss: 0.6479
# ----------
# epoch 42/100
# epoch 42 average loss: 0.6137
# saved new best metric model
# current epoch: 42 current mean dice: 0.5504
# Per-organ Dice scores:
#   - Spleen                : 0.8695
#   - Right Kidney          : 0.8140
#   - Left Kidney           : 0.7284
#   - Gallbladder           : 0.5414
#   - Liver                 : 0.7812
#   - Stomach               : 0.6013
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6371
#   - Right Adrenal Gland   : 0.3517
#   - Left Adrenal Gland    : 0.6187
#   - Duodenum              : 0.4385
#   - Bladder               : 0.7731
# best mean dice: 0.5504 at epoch: 42
# ----------
# epoch 43/100
# epoch 43 average loss: 0.6364
# ----------
# epoch 44/100
# epoch 44 average loss: 0.6110
# saved new best metric model
# current epoch: 44 current mean dice: 0.5540
# Per-organ Dice scores:
#   - Spleen                : 0.8712
#   - Right Kidney          : 0.8349
#   - Left Kidney           : 0.7780
#   - Gallbladder           : 0.5156
#   - Liver                 : 0.7620
#   - Stomach               : 0.5329
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6714
#   - Right Adrenal Gland   : 0.3926
#   - Left Adrenal Gland    : 0.5807
#   - Duodenum              : 0.4621
#   - Bladder               : 0.8006
# best mean dice: 0.5540 at epoch: 44
# ----------
# epoch 45/100
# epoch 45 average loss: 0.6203
# ----------
# epoch 46/100
# epoch 46 average loss: 0.6109
# saved new best metric model
# current epoch: 46 current mean dice: 0.5655
# Per-organ Dice scores:
#   - Spleen                : 0.8967
#   - Right Kidney          : 0.8417
#   - Left Kidney           : 0.7247
#   - Gallbladder           : 0.5606
#   - Liver                 : 0.7523
#   - Stomach               : 0.5048
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6635
#   - Right Adrenal Gland   : 0.5397
#   - Left Adrenal Gland    : 0.5861
#   - Duodenum              : 0.5028
#   - Bladder               : 0.7785
# best mean dice: 0.5655 at epoch: 46
# ----------
# epoch 47/100
# epoch 47 average loss: 0.6206
# ----------
# epoch 48/100
# epoch 48 average loss: 0.6233
# saved new best metric model
# current epoch: 48 current mean dice: 0.5813
# Per-organ Dice scores:
#   - Spleen                : 0.9219
#   - Right Kidney          : 0.8240
#   - Left Kidney           : 0.7317
#   - Gallbladder           : 0.6012
#   - Liver                 : 0.7804
#   - Stomach               : 0.6615
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7142
#   - Right Adrenal Gland   : 0.4367
#   - Left Adrenal Gland    : 0.6053
#   - Duodenum              : 0.5238
#   - Bladder               : 0.7560
# best mean dice: 0.5813 at epoch: 48
# ----------
# epoch 49/100
# epoch 49 average loss: 0.6103
# ----------
# epoch 50/100
# epoch 50 average loss: 0.6131
# saved new best metric model
# current epoch: 50 current mean dice: 0.6112
# Per-organ Dice scores:
#   - Spleen                : 0.9164
#   - Right Kidney          : 0.8366
#   - Left Kidney           : 0.8012
#   - Gallbladder           : 0.6336
#   - Liver                 : 0.8065
#   - Stomach               : 0.7167
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7007
#   - Right Adrenal Gland   : 0.5434
#   - Left Adrenal Gland    : 0.6555
#   - Duodenum              : 0.5296
#   - Bladder               : 0.8049
# best mean dice: 0.6112 at epoch: 50
# ----------
# epoch 51/100
# epoch 51 average loss: 0.6173
# ----------
# epoch 52/100
# epoch 52 average loss: 0.6071
# current epoch: 52 current mean dice: 0.5987
# Per-organ Dice scores:
#   - Spleen                : 0.9214
#   - Right Kidney          : 0.8450
#   - Left Kidney           : 0.7807
#   - Gallbladder           : 0.6025
#   - Liver                 : 0.7663
#   - Stomach               : 0.7007
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6941
#   - Right Adrenal Gland   : 0.5262
#   - Left Adrenal Gland    : 0.6499
#   - Duodenum              : 0.5052
#   - Bladder               : 0.7917
# best mean dice: 0.6112 at epoch: 50
# ----------
# epoch 53/100
# epoch 53 average loss: 0.6225
# ----------
# epoch 54/100
# epoch 54 average loss: 0.6350
# current epoch: 54 current mean dice: 0.6040
# Per-organ Dice scores:
#   - Spleen                : 0.9052
#   - Right Kidney          : 0.8596
#   - Left Kidney           : 0.7674
#   - Gallbladder           : 0.6144
#   - Liver                 : 0.7697
#   - Stomach               : 0.7183
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7072
#   - Right Adrenal Gland   : 0.5116
#   - Left Adrenal Gland    : 0.6324
#   - Duodenum              : 0.5426
#   - Bladder               : 0.8240
# best mean dice: 0.6112 at epoch: 50
# ----------
# epoch 55/100
# epoch 55 average loss: 0.6127
# ----------
# epoch 56/100
# epoch 56 average loss: 0.6246
# current epoch: 56 current mean dice: 0.6037
# Per-organ Dice scores:
#   - Spleen                : 0.9229
#   - Right Kidney          : 0.8653
#   - Left Kidney           : 0.7911
#   - Gallbladder           : 0.5992
#   - Liver                 : 0.7003
#   - Stomach               : 0.6669
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6895
#   - Right Adrenal Gland   : 0.5594
#   - Left Adrenal Gland    : 0.6745
#   - Duodenum              : 0.5531
#   - Bladder               : 0.8261
# best mean dice: 0.6112 at epoch: 50
# ----------
# epoch 57/100
# epoch 57 average loss: 0.6067
# ----------
# epoch 58/100
# epoch 58 average loss: 0.6068
# current epoch: 58 current mean dice: 0.6111
# Per-organ Dice scores:
#   - Spleen                : 0.9171
#   - Right Kidney          : 0.8167
#   - Left Kidney           : 0.7860
#   - Gallbladder           : 0.6449
#   - Liver                 : 0.8484
#   - Stomach               : 0.6658
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6860
#   - Right Adrenal Gland   : 0.5452
#   - Left Adrenal Gland    : 0.7073
#   - Duodenum              : 0.5469
#   - Bladder               : 0.7806
# best mean dice: 0.6112 at epoch: 50
# ----------
# epoch 59/100
# epoch 59 average loss: 0.6007
# ----------
# epoch 60/100
# epoch 60 average loss: 0.5960
# saved new best metric model
# current epoch: 60 current mean dice: 0.6393
# Per-organ Dice scores:
#   - Spleen                : 0.9026
#   - Right Kidney          : 0.8744
#   - Left Kidney           : 0.8172
#   - Gallbladder           : 0.6593
#   - Liver                 : 0.8528
#   - Stomach               : 0.7587
#   - Aorta                 : 0.0000
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6979
#   - Right Adrenal Gland   : 0.6229
#   - Left Adrenal Gland    : 0.6908
#   - Duodenum              : 0.5960
#   - Bladder               : 0.8389
# best mean dice: 0.6393 at epoch: 60
# ----------
# epoch 61/100
# epoch 61 average loss: 0.6055
# ----------
# epoch 62/100
# epoch 62 average loss: 0.6067
# current epoch: 62 current mean dice: 0.6340
# Per-organ Dice scores:
#   - Spleen                : 0.9283
#   - Right Kidney          : 0.8725
#   - Left Kidney           : 0.8021
#   - Gallbladder           : 0.6561
#   - Liver                 : 0.8641
#   - Stomach               : 0.7310
#   - Aorta                 : 0.0020
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6935
#   - Right Adrenal Gland   : 0.5802
#   - Left Adrenal Gland    : 0.7034
#   - Duodenum              : 0.5950
#   - Bladder               : 0.8143
# best mean dice: 0.6393 at epoch: 60
# ----------
# epoch 63/100
# epoch 63 average loss: 0.6052
# ----------
# epoch 64/100
# epoch 64 average loss: 0.5975
# saved new best metric model
# current epoch: 64 current mean dice: 0.6499
# Per-organ Dice scores:
#   - Spleen                : 0.9065
#   - Right Kidney          : 0.8507
#   - Left Kidney           : 0.7867
#   - Gallbladder           : 0.6563
#   - Liver                 : 0.8471
#   - Stomach               : 0.7615
#   - Aorta                 : 0.2023
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7152
#   - Right Adrenal Gland   : 0.6176
#   - Left Adrenal Gland    : 0.7011
#   - Duodenum              : 0.5794
#   - Bladder               : 0.8238
# best mean dice: 0.6499 at epoch: 64
# ----------
# epoch 65/100
# epoch 65 average loss: 0.5861
# ----------
# epoch 66/100
# epoch 66 average loss: 0.6049
# saved new best metric model
# current epoch: 66 current mean dice: 0.6600
# Per-organ Dice scores:
#   - Spleen                : 0.9210
#   - Right Kidney          : 0.8740
#   - Left Kidney           : 0.7798
#   - Gallbladder           : 0.6254
#   - Liver                 : 0.8423
#   - Stomach               : 0.7199
#   - Aorta                 : 0.4127
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6932
#   - Right Adrenal Gland   : 0.6177
#   - Left Adrenal Gland    : 0.6885
#   - Duodenum              : 0.5932
#   - Bladder               : 0.8120
# best mean dice: 0.6600 at epoch: 66
# ----------
# epoch 67/100
# epoch 67 average loss: 0.5815
# ----------
# epoch 68/100
# epoch 68 average loss: 0.5710
# saved new best metric model
# current epoch: 68 current mean dice: 0.6873
# Per-organ Dice scores:
#   - Spleen                : 0.9311
#   - Right Kidney          : 0.8743
#   - Left Kidney           : 0.8315
#   - Gallbladder           : 0.6735
#   - Liver                 : 0.8762
#   - Stomach               : 0.7674
#   - Aorta                 : 0.4907
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7241
#   - Right Adrenal Gland   : 0.6170
#   - Left Adrenal Gland    : 0.7046
#   - Duodenum              : 0.6034
#   - Bladder               : 0.8413
# best mean dice: 0.6873 at epoch: 68
# ----------
# epoch 69/100
# epoch 69 average loss: 0.5976
# ----------
# epoch 70/100
# epoch 70 average loss: 0.5756
# current epoch: 70 current mean dice: 0.6853
# Per-organ Dice scores:
#   - Spleen                : 0.9334
#   - Right Kidney          : 0.8753
#   - Left Kidney           : 0.8631
#   - Gallbladder           : 0.6546
#   - Liver                 : 0.8619
#   - Stomach               : 0.7521
#   - Aorta                 : 0.5125
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7278
#   - Right Adrenal Gland   : 0.6208
#   - Left Adrenal Gland    : 0.6797
#   - Duodenum              : 0.6247
#   - Bladder               : 0.8033
# best mean dice: 0.6873 at epoch: 68
# ----------
# epoch 71/100
# epoch 71 average loss: 0.5578
# ----------
# epoch 72/100
# epoch 72 average loss: 0.5601
# current epoch: 72 current mean dice: 0.6871
# Per-organ Dice scores:
#   - Spleen                : 0.9332
#   - Right Kidney          : 0.8843
#   - Left Kidney           : 0.8365
#   - Gallbladder           : 0.6277
#   - Liver                 : 0.8787
#   - Stomach               : 0.7700
#   - Aorta                 : 0.5209
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7065
#   - Right Adrenal Gland   : 0.6535
#   - Left Adrenal Gland    : 0.6902
#   - Duodenum              : 0.5969
#   - Bladder               : 0.8344
# best mean dice: 0.6873 at epoch: 68
# ----------
# epoch 73/100
# epoch 73 average loss: 0.5906
# ----------
# epoch 74/100
# epoch 74 average loss: 0.5802
# current epoch: 74 current mean dice: 0.6783
# Per-organ Dice scores:
#   - Spleen                : 0.9254
#   - Right Kidney          : 0.8591
#   - Left Kidney           : 0.7746
#   - Gallbladder           : 0.6828
#   - Liver                 : 0.8703
#   - Stomach               : 0.6882
#   - Aorta                 : 0.4875
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7066
#   - Right Adrenal Gland   : 0.6728
#   - Left Adrenal Gland    : 0.7378
#   - Duodenum              : 0.5901
#   - Bladder               : 0.8231
# best mean dice: 0.6873 at epoch: 68
# ----------
# epoch 75/100
# epoch 75 average loss: 0.5666
# ----------
# epoch 76/100
# epoch 76 average loss: 0.5604
# current epoch: 76 current mean dice: 0.6826
# Per-organ Dice scores:
#   - Spleen                : 0.9352
#   - Right Kidney          : 0.8702
#   - Left Kidney           : 0.8202
#   - Gallbladder           : 0.6527
#   - Liver                 : 0.8636
#   - Stomach               : 0.7416
#   - Aorta                 : 0.5562
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7363
#   - Right Adrenal Gland   : 0.5913
#   - Left Adrenal Gland    : 0.7074
#   - Duodenum              : 0.5779
#   - Bladder               : 0.8217
# best mean dice: 0.6873 at epoch: 68
# ----------
# epoch 77/100
# epoch 77 average loss: 0.5864
# ----------
# epoch 78/100
# epoch 78 average loss: 0.5790
# current epoch: 78 current mean dice: 0.6839
# Per-organ Dice scores:
#   - Spleen                : 0.9259
#   - Right Kidney          : 0.8339
#   - Left Kidney           : 0.8199
#   - Gallbladder           : 0.6737
#   - Liver                 : 0.8736
#   - Stomach               : 0.7552
#   - Aorta                 : 0.5899
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6815
#   - Right Adrenal Gland   : 0.5957
#   - Left Adrenal Gland    : 0.7191
#   - Duodenum              : 0.5943
#   - Bladder               : 0.8284
# best mean dice: 0.6873 at epoch: 68
# ----------
# epoch 79/100
# epoch 79 average loss: 0.5509
# ----------
# epoch 80/100
# epoch 80 average loss: 0.5555
# current epoch: 80 current mean dice: 0.6787
# Per-organ Dice scores:
#   - Spleen                : 0.9369
#   - Right Kidney          : 0.8632
#   - Left Kidney           : 0.7834
#   - Gallbladder           : 0.6461
#   - Liver                 : 0.8708
#   - Stomach               : 0.7886
#   - Aorta                 : 0.4865
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.6997
#   - Right Adrenal Gland   : 0.6462
#   - Left Adrenal Gland    : 0.6966
#   - Duodenum              : 0.5969
#   - Bladder               : 0.8085
# best mean dice: 0.6873 at epoch: 68
# ----------
# epoch 81/100
# epoch 81 average loss: 0.5824
# ----------
# epoch 82/100
# epoch 82 average loss: 0.5776
# current epoch: 82 current mean dice: 0.6836
# Per-organ Dice scores:
#   - Spleen                : 0.9402
#   - Right Kidney          : 0.8553
#   - Left Kidney           : 0.8083
#   - Gallbladder           : 0.6365
#   - Liver                 : 0.8767
#   - Stomach               : 0.7273
#   - Aorta                 : 0.5577
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7230
#   - Right Adrenal Gland   : 0.6511
#   - Left Adrenal Gland    : 0.7113
#   - Duodenum              : 0.5999
#   - Bladder               : 0.7993
# best mean dice: 0.6873 at epoch: 68
# ----------
# epoch 83/100
# epoch 83 average loss: 0.5615
# ----------
# epoch 84/100
# epoch 84 average loss: 0.5774
# saved new best metric model
# current epoch: 84 current mean dice: 0.6921
# Per-organ Dice scores:
#   - Spleen                : 0.9322
#   - Right Kidney          : 0.8777
#   - Left Kidney           : 0.7985
#   - Gallbladder           : 0.6791
#   - Liver                 : 0.8863
#   - Stomach               : 0.7592
#   - Aorta                 : 0.5881
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7108
#   - Right Adrenal Gland   : 0.6359
#   - Left Adrenal Gland    : 0.7387
#   - Duodenum              : 0.5836
#   - Bladder               : 0.8068
# best mean dice: 0.6921 at epoch: 84
# ----------
# epoch 85/100
# epoch 85 average loss: 0.5430
# ----------
# epoch 86/100
# epoch 86 average loss: 0.5551
# saved new best metric model
# current epoch: 86 current mean dice: 0.7164
# Per-organ Dice scores:
#   - Spleen                : 0.9486
#   - Right Kidney          : 0.8723
#   - Left Kidney           : 0.8881
#   - Gallbladder           : 0.6776
#   - Liver                 : 0.8901
#   - Stomach               : 0.8109
#   - Aorta                 : 0.5890
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7455
#   - Right Adrenal Gland   : 0.6995
#   - Left Adrenal Gland    : 0.7228
#   - Duodenum              : 0.6118
#   - Bladder               : 0.8577
# best mean dice: 0.7164 at epoch: 86
# ----------
# epoch 87/100
# epoch 87 average loss: 0.5664
# ----------
# epoch 88/100
# epoch 88 average loss: 0.5427
# current epoch: 88 current mean dice: 0.7084
# Per-organ Dice scores:
#   - Spleen                : 0.9462
#   - Right Kidney          : 0.8460
#   - Left Kidney           : 0.8650
#   - Gallbladder           : 0.6944
#   - Liver                 : 0.8904
#   - Stomach               : 0.8041
#   - Aorta                 : 0.5848
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7388
#   - Right Adrenal Gland   : 0.6897
#   - Left Adrenal Gland    : 0.7239
#   - Duodenum              : 0.5960
#   - Bladder               : 0.8304
# best mean dice: 0.7164 at epoch: 86
# ----------
# epoch 89/100
# epoch 89 average loss: 0.5589
# ----------
# epoch 90/100
# epoch 90 average loss: 0.5811
# current epoch: 90 current mean dice: 0.6967
# Per-organ Dice scores:
#   - Spleen                : 0.9294
#   - Right Kidney          : 0.8321
#   - Left Kidney           : 0.8395
#   - Gallbladder           : 0.6859
#   - Liver                 : 0.8862
#   - Stomach               : 0.7781
#   - Aorta                 : 0.5859
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7291
#   - Right Adrenal Gland   : 0.6475
#   - Left Adrenal Gland    : 0.7237
#   - Duodenum              : 0.6200
#   - Bladder               : 0.8001
# best mean dice: 0.7164 at epoch: 86
# ----------
# epoch 91/100
# epoch 91 average loss: 0.5409
# ----------
# epoch 92/100
# epoch 92 average loss: 0.5558
# current epoch: 92 current mean dice: 0.6879
# Per-organ Dice scores:
#   - Spleen                : 0.9127
#   - Right Kidney          : 0.8663
#   - Left Kidney           : 0.7731
#   - Gallbladder           : 0.6610
#   - Liver                 : 0.8689
#   - Stomach               : 0.7811
#   - Aorta                 : 0.5909
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7122
#   - Right Adrenal Gland   : 0.6452
#   - Left Adrenal Gland    : 0.6989
#   - Duodenum              : 0.6076
#   - Bladder               : 0.8245
# best mean dice: 0.7164 at epoch: 86
# ----------
# epoch 93/100
# epoch 93 average loss: 0.5500
# ----------
# epoch 94/100
# epoch 94 average loss: 0.5568
# current epoch: 94 current mean dice: 0.7081
# Per-organ Dice scores:
#   - Spleen                : 0.9390
#   - Right Kidney          : 0.8473
#   - Left Kidney           : 0.8720
#   - Gallbladder           : 0.6780
#   - Liver                 : 0.8819
#   - Stomach               : 0.7844
#   - Aorta                 : 0.6158
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7401
#   - Right Adrenal Gland   : 0.6505
#   - Left Adrenal Gland    : 0.7439
#   - Duodenum              : 0.6190
#   - Bladder               : 0.8334
# best mean dice: 0.7164 at epoch: 86
# ----------
# epoch 95/100
# epoch 95 average loss: 0.5494
# ----------
# epoch 96/100
# epoch 96 average loss: 0.5558
# current epoch: 96 current mean dice: 0.7077
# Per-organ Dice scores:
#   - Spleen                : 0.9349
#   - Right Kidney          : 0.8397
#   - Left Kidney           : 0.8374
#   - Gallbladder           : 0.7120
#   - Liver                 : 0.9012
#   - Stomach               : 0.7907
#   - Aorta                 : 0.5295
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7389
#   - Right Adrenal Gland   : 0.6892
#   - Left Adrenal Gland    : 0.7684
#   - Duodenum              : 0.6190
#   - Bladder               : 0.8392
# best mean dice: 0.7164 at epoch: 86
# ----------
# epoch 97/100
# epoch 97 average loss: 0.5466
# ----------
# epoch 98/100
# epoch 98 average loss: 0.5589
# current epoch: 98 current mean dice: 0.7131
# Per-organ Dice scores:
#   - Spleen                : 0.9415
#   - Right Kidney          : 0.8641
#   - Left Kidney           : 0.8876
#   - Gallbladder           : 0.6950
#   - Liver                 : 0.8973
#   - Stomach               : 0.7731
#   - Aorta                 : 0.5962
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7319
#   - Right Adrenal Gland   : 0.6970
#   - Left Adrenal Gland    : 0.7486
#   - Duodenum              : 0.6024
#   - Bladder               : 0.8352
# best mean dice: 0.7164 at epoch: 86
# ----------
# epoch 99/100
# epoch 99 average loss: 0.5459
# ----------
# epoch 100/100
# epoch 100 average loss: 0.5489
# current epoch: 100 current mean dice: 0.7081
# Per-organ Dice scores:
#   - Spleen                : 0.9451
#   - Right Kidney          : 0.8594
#   - Left Kidney           : 0.8845
#   - Gallbladder           : 0.6947
#   - Liver                 : 0.8782
#   - Stomach               : 0.7874
#   - Aorta                 : 0.5832
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7065
#   - Right Adrenal Gland   : 0.6676
#   - Left Adrenal Gland    : 0.7428
#   - Duodenum              : 0.6093
#   - Bladder               : 0.8471
# best mean dice: 0.7164 at epoch: 86
#
# ✅ Training complete. Best mean dice: 0.7164 at epoch 86
#
# ▶️ Step 7: Evaluating and Visualizing Results...
# ------------------------------
# 📊 Best Performing Case: FLARE22_Tr_0042_0000.nii
# Mean Dice: 0.7932
# Per-Organ Dice Scores:
#   - Spleen                : 0.9600
#   - Right Kidney          : 0.9522
#   - Left Kidney           : 0.9420
#   - Gallbladder           : 0.8284
#   - Liver                 : 0.9117
#   - Stomach               : 0.8698
#   - Aorta                 : 0.6901
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.7909
#   - Right Adrenal Gland   : 0.7210
#   - Left Adrenal Gland    : 0.8877
#   - Duodenum              : 0.7966
#   - Bladder               : 0.9609
# ------------------------------
# 📊 Worst Performing Case: FLARE22_Tr_0045_0000.nii
# Mean Dice: 0.6212
# Per-Organ Dice Scores:
#   - Spleen                : 0.9516
#   - Right Kidney          : 0.5285
#   - Left Kidney           : 0.8945
#   - Gallbladder           : 0.5204
#   - Liver                 : 0.8366
#   - Stomach               : 0.8421
#   - Aorta                 : 0.3115
#   - Inferior Vena Cava    : 0.0000
#   - Pancreas              : 0.8179
#   - Right Adrenal Gland   : 0.7112
#   - Left Adrenal Gland    : 0.5901
#   - Duodenum              : 0.6918
#   - Bladder               : 0.3794
# ✅ Pipeline complete!
